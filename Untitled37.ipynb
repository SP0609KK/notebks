# %%
import os
import zipfile
import mimetypes
import io
import csv
import re
from PIL import Image
import xml.etree.ElementTree as ET
from urllib.parse import unquote
import shutil

def process_embedded_excel_files(input_xlsx_path, output_folder):
    def extract_embedded_files(file_path, save_path):
        """
        Extracts arbitrary embedded files from an Excel (xlsx) file and saves them.

        Parameters:
        ----------
        file_path : str,
            The path to the xlsx file.

        save_path : str,
            Directory path to save the extracted files.
        """
            # Create the directory if it doesn't exist
        if not os.path.exists(save_path):
            os.makedirs(save_path)

        with zipfile.ZipFile(file_path, 'r') as zip_file:
            # List all files in the archive
            all_files = zip_file.namelist()

            # Iterate through all files in the archive
            for file_info in all_files:
                # Extract the file content
                file_content = zip_file.read(file_info)

                # Save the extracted file to the specified directory
                extracted_file_path = os.path.join(save_path, os.path.basename(file_info))
                with open(extracted_file_path, 'wb') as f:
                    f.write(file_content)

    def convert_files_to_txt(input_folder, output_folder):
        """
        Converts each file in the input folder to a plain text file and saves it in the output folder.

        Parameters:
        ----------
        input_folder : str,
            The path to the folder containing XML and RELS files.

        output_folder : str,
            The path to the folder where the converted text files will be saved.
        """
        # Create the output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        for filename in os.listdir(input_folder):
            input_file_path = os.path.join(input_folder, filename)
            output_file_path = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}.txt")

            try:
                with open(input_file_path, 'r', encoding='utf-8') as input_file:
                    # Read the content of the input file
                    file_content = input_file.read()

                # Optionally, you can parse XML content if needed
                # For example, if the file is in XML format
                # tree = ET.fromstring(file_content)
                # parsed_content = ET.tostring(tree, encoding='utf-8').decode('utf-8')

            # Write the content to the output text file
                with open(output_file_path, 'w', encoding='utf-8') as output_file:
                    output_file.write(file_content)
            except Exception as e:
                print(f"Error processing file {input_file_path}: {e}")
    def extract_text_from_folder(folder_path):
        """
        Extracts text content matching the pattern from text files within a folder.

        Parameters:
        ----------
        folder_path : str,
            The path to the folder containing text files.

        Returns:
        -------
        matching_paths : list,
            A list of concatenated file paths found within the text files.
        """
        matching_paths = []

        # Iterate through each file in the folder
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)

            # Check if it's a text file
            if os.path.isfile(file_path) and filename.lower().endswith('.txt'):
                try:
                    # Read the content of the text file
                    with open(file_path, 'r', encoding='utf-8') as file:
                        file_content = file.read()

                    # Use format() to build the string
                    matches = re.findall(r'file:///C:\\Users\\([^"]+)', file_content)
                    matching_paths.extend(["C:/Users/{}".format(match.replace('\\', '/')) for match in matches])
                except Exception as e:
                    print(f"Error processing file {file_path}: {e}")

        return matching_paths

    def fetch_files(matching_paths, output_folder):
        # Create the output folder if it doesn't exist
        os.makedirs(output_folder, exist_ok=True)

        for file_path in matching_paths:
            try:
                file_name = os.path.basename(unquote(file_path))
                shutil.copy(unquote(file_path), os.path.join(output_folder, file_name))
            except Exception as e:
                print(f"Error fetching file {file_path}: {e}")

    # Create output folders
    extracted_folder = os.path.join(output_folder, 'extracted_embedded_files')
    converted_folder = os.path.join(output_folder, 'converted_text_files')
    fetched_folder = os.path.join(output_folder, 'fetched_excel_files')

    # Extract embedded files
    extract_embedded_files(input_xlsx_path, extracted_folder)

    # Convert files to text
    convert_files_to_txt(extracted_folder, converted_folder)

    # Extract matching paths from text files
    matching_paths = extract_text_from_folder(converted_folder)

    # Fetch and copy Excel files
    fetch_files(matching_paths, fetched_folder)

    # Delete 'converted_text_files' and 'extracted_embedded_files' folders
    shutil.rmtree(converted_folder)
    shutil.rmtree(extracted_folder)
    
    

# Example usage:
input_xlsx_path = "C:/Users/Shreshtha/Downloads/Sample Source of Truth.xlsx"
output_folder = "C:/Users/Shreshtha/Downloads/output_final2"
process_embedded_excel_files(input_xlsx_path, output_folder)
# Out:
# Error processing file C:/Users/Shreshtha/Downloads/output_final2\extracted_embedded_files\image1.jpeg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Error processing file C:/Users/Shreshtha/Downloads/output_final2\extracted_embedded_files\image2.emf: 'utf-8' codec can't decode byte 0x8e in position 16: invalid start byte
# Error processing file C:/Users/Shreshtha/Downloads/output_final2\extracted_embedded_files\image3.emf: 'utf-8' codec can't decode byte 0x8e in position 16: invalid start byte
# Error processing file C:/Users/Shreshtha/Downloads/output_final2\extracted_embedded_files\image4.emf: 'utf-8' codec can't decode byte 0x8e in position 16: invalid start byte
# Error processing file C:/Users/Shreshtha/Downloads/output_final2\extracted_embedded_files\image5.png: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Error processing file C:/Users/Shreshtha/Downloads/output_final2\extracted_embedded_files\image6.jpeg: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte

# %%
import pandas as pd

def extract_and_print_table(excel_path):
    xls = pd.ExcelFile(excel_path)

    for sheet_name in xls.sheet_names:
        # Read each sheet from the Excel file
        df = pd.read_excel(xls, sheet_name)

        # Print the tabular data for each sheet
        print(f"\nSheet: {sheet_name}")
        print(df)

# Example usage
excel_path = "C:/Users/Shreshtha/Downloads/Sample Source of Truth.xlsx"
extract_and_print_table(excel_path)
# Out:
# Sheet: Sheet1
# Empty DataFrame
# Columns: []
# Index: []
#
# Sheet: Sheet2
#                   Group Name              ABC Ltd
# 0               Group Number                  123
# 1               Renewal Date  2024-01-01 00:00:00
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4   No of employees enrolled                   20
# 5                Group State                   CT
# 6                     Market                Large
# 7           In Network (IN):                  NaN
# 8                      Copay                30/45
# 9           IN Coinsurance %                100/0
# 10             IN Deductible            2500/5000
# 11     Out of Network (OON):                  NaN
# 12         OON Coinsurance %                100/0
# 13            OON Deductible            2500/5000
#
# Sheet: Sheet3
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 17     Adult Coloring Book: Stress Relieving Patterns
# 18  Adult Coloring Books: A Coloring Book for Adul...
# 19                                 Alexander Hamilton
# 20                        All the Light We Cannot See
# 21                        All the Light We Cannot See
# 22                                          Allegiant
# 23  American Sniper: The Autobiography of the Most...
# 24                           And the Mountains Echoed
# 25  Arguing with Idiots: How to Stop Small Minds a...
# 26                 Astrophysics for People in a Hurry
# 27                Autobiography of Mark Twain, Vol. 1
# 28                       Baby Touch and Feel: Animals
# 29           Balance (Angie's Extreme Stress Menders)
# 30  Barefoot Contessa Foolproof: Recipes You Can T...
# 31  Barefoot Contessa, How Easy Is That?: Fabulous...
# 32                                           Becoming
# 33                                           Becoming
# 34  Being Mortal: Medicine and What Matters in the...
# 35                           Between the World and Me
# 36                           Between the World and Me
# 37                                        Born to Run
# 38          Breaking Dawn (The Twilight Saga, Book 4)
# 39  Broke: The Plan to Restore Our Trust, Truth an...
# 40           Brown Bear, Brown Bear, What Do You See?
# 41           Brown Bear, Brown Bear, What Do You See?
# 42         Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 43  Calm the F*ck Down: An Irreverent Adult Colori...
# 44  Can't Hurt Me: Master Your Mind and Defy the Odds
#
#                          Author  User Rating  Reviews  Price  Year  \
# 0                      JJ Smith          4.7    17350      8  2016
# 1                  Stephen King          4.6     2052     22  2011
# 2            Jordan B. Peterson          4.7    18979     15  2018
# 3                 George Orwell          4.7    21424      6  2017
# 4      National Geographic Kids          4.8     7665     12  2019
# 5           George R. R. Martin          4.4    12643     11  2011
# 6           George R. R. Martin          4.7    19735     30  2014
# 7                   Amor Towles          4.7    19699     15  2017
# 8                   James Comey          4.7     5983      3  2018
# 9               Fredrik Backman          4.6    23848      8  2016
# 10              Fredrik Backman          4.6    23848      8  2017
# 11             Larry Schweikart          4.6      460      2  2010
# 12                Jaycee Dugard          4.6     4149     32  2011
# 13            Madeleine L'Engle          4.5     5153      5  2018
# 14                 Steve Harvey          4.6     5013     17  2009
# 15  Adult Coloring Book Designs          4.5     2313      4  2016
# 16           Blue Star Coloring          4.6     2925      6  2015
# 17           Blue Star Coloring          4.4     2951      6  2015
# 18    Coloring Books for Adults          4.5     2426      8  2015
# 19                  Ron Chernow          4.8     9198     13  2016
# 20                Anthony Doerr          4.6    36348     14  2014
# 21                Anthony Doerr          4.6    36348     14  2015
# 22                Veronica Roth          3.9     6310     13  2013
# 23                   Chris Kyle          4.6    15921      9  2015
# 24              Khaled Hosseini          4.3    12159     13  2013
# 25                   Glenn Beck          4.6      798      5  2009
# 26          Neil deGrasse Tyson          4.7     9374      9  2017
# 27                   Mark Twain          4.2      491     14  2010
# 28                           DK          4.6     5360      5  2015
# 29                  Angie Grace          4.6     1909     11  2015
# 30                   Ina Garten          4.8     1296     24  2012
# 31                   Ina Garten          4.7      615     21  2010
# 32               Michelle Obama          4.8    61133     11  2018
# 33               Michelle Obama          4.8    61133     11  2019
# 34                 Atul Gawande          4.8    11113     15  2015
# 35             Ta-Nehisi Coates          4.7    10070     13  2015
# 36             Ta-Nehisi Coates          4.7    10070     13  2016
# 37            Bruce Springsteen          4.7     3729     18  2016
# 38              Stephenie Meyer          4.6     9769     13  2009
# 39                   Glenn Beck          4.5      471      8  2010
# 40              Bill Martin Jr.          4.9    14344      5  2017
# 41              Bill Martin Jr.          4.9    14344      5  2019
# 42                  Jeff Kinney          4.8     4505      0  2011
# 43                 Sasha O'Hara          4.6    10369      4  2016
# 44                David Goggins          4.8    16244     18  2019
#
#           Genre
# 0   Non Fiction
# 1       Fiction
# 2   Non Fiction
# 3       Fiction
# 4   Non Fiction
# 5       Fiction
# 6       Fiction
# 7       Fiction
# 8   Non Fiction
# 9       Fiction
# 10      Fiction
# 11  Non Fiction
# 12  Non Fiction
# 13      Fiction
# 14  Non Fiction
# 15  Non Fiction
# 16  Non Fiction
# 17  Non Fiction
# 18  Non Fiction
# 19  Non Fiction
# 20      Fiction
# 21      Fiction
# 22      Fiction
# 23  Non Fiction
# 24      Fiction
# 25  Non Fiction
# 26  Non Fiction
# 27  Non Fiction
# 28  Non Fiction
# 29  Non Fiction
# 30  Non Fiction
# 31  Non Fiction
# 32  Non Fiction
# 33  Non Fiction
# 34  Non Fiction
# 35  Non Fiction
# 36  Non Fiction
# 37  Non Fiction
# 38      Fiction
# 39  Non Fiction
# 40      Fiction
# 41      Fiction
# 42      Fiction
# 43  Non Fiction
# 44  Non Fiction
#
# Sheet: Sheet4
# Empty DataFrame
# Columns: []
# Index: []
#
# Sheet: Sheet5
# Empty DataFrame
# Columns: []
# Index: []
#
# Sheet: Sheet6
# Empty DataFrame
# Columns: []
# Index: []
#
# Sheet: Sheet7
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
from IPython.display import display

def extract_and_print_table(excel_path):
    xls = pd.ExcelFile(excel_path)

    for sheet_name in xls.sheet_names:
        # Read each sheet from the Excel file
        df = pd.read_excel(xls, sheet_name)

        # Print the tabular data for each sheet using display for better formatting
        print(f"\nSheet: {sheet_name}")
        display(df)

# Example usage
excel_path = "C:/Users/Shreshtha/Downloads/Sample Source of Truth.xlsx"
extract_and_print_table(excel_path)
# Out:
# Sheet: Sheet1
# Empty DataFrame
# Columns: []
# Index: []
# Sheet: Sheet2
#                   Group Name              ABC Ltd
# 0               Group Number                  123
# 1               Renewal Date  2024-01-01 00:00:00
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4   No of employees enrolled                   20
# 5                Group State                   CT
# 6                     Market                Large
# 7           In Network (IN):                  NaN
# 8                      Copay                30/45
# 9           IN Coinsurance %                100/0
# 10             IN Deductible            2500/5000
# 11     Out of Network (OON):                  NaN
# 12         OON Coinsurance %                100/0
# 13            OON Deductible            2500/5000
# Sheet: Sheet3
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 16  Adult Coloring Book: Stress Relieving Animal D...
# 17     Adult Coloring Book: Stress Relieving Patterns
# 18  Adult Coloring Books: A Coloring Book for Adul...
# 19                                 Alexander Hamilton
# 20                        All the Light We Cannot See
# 21                        All the Light We Cannot See
# 22                                          Allegiant
# 23  American Sniper: The Autobiography of the Most...
# 24                           And the Mountains Echoed
# 25  Arguing with Idiots: How to Stop Small Minds a...
# 26                 Astrophysics for People in a Hurry
# 27                Autobiography of Mark Twain, Vol. 1
# 28                       Baby Touch and Feel: Animals
# 29           Balance (Angie's Extreme Stress Menders)
# 30  Barefoot Contessa Foolproof: Recipes You Can T...
# 31  Barefoot Contessa, How Easy Is That?: Fabulous...
# 32                                           Becoming
# 33                                           Becoming
# 34  Being Mortal: Medicine and What Matters in the...
# 35                           Between the World and Me
# 36                           Between the World and Me
# 37                                        Born to Run
# 38          Breaking Dawn (The Twilight Saga, Book 4)
# 39  Broke: The Plan to Restore Our Trust, Truth an...
# 40           Brown Bear, Brown Bear, What Do You See?
# 41           Brown Bear, Brown Bear, What Do You See?
# 42         Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 43  Calm the F*ck Down: An Irreverent Adult Colori...
# 44  Can't Hurt Me: Master Your Mind and Defy the Odds
#
#                          Author  User Rating  Reviews  Price  Year  \
# 0                      JJ Smith          4.7    17350      8  2016
# 1                  Stephen King          4.6     2052     22  2011
# 2            Jordan B. Peterson          4.7    18979     15  2018
# 3                 George Orwell          4.7    21424      6  2017
# 4      National Geographic Kids          4.8     7665     12  2019
# 5           George R. R. Martin          4.4    12643     11  2011
# 6           George R. R. Martin          4.7    19735     30  2014
# 7                   Amor Towles          4.7    19699     15  2017
# 8                   James Comey          4.7     5983      3  2018
# 9               Fredrik Backman          4.6    23848      8  2016
# 10              Fredrik Backman          4.6    23848      8  2017
# 11             Larry Schweikart          4.6      460      2  2010
# 12                Jaycee Dugard          4.6     4149     32  2011
# 13            Madeleine L'Engle          4.5     5153      5  2018
# 14                 Steve Harvey          4.6     5013     17  2009
# 15  Adult Coloring Book Designs          4.5     2313      4  2016
# 16           Blue Star Coloring          4.6     2925      6  2015
# 17           Blue Star Coloring          4.4     2951      6  2015
# 18    Coloring Books for Adults          4.5     2426      8  2015
# 19                  Ron Chernow          4.8     9198     13  2016
# 20                Anthony Doerr          4.6    36348     14  2014
# 21                Anthony Doerr          4.6    36348     14  2015
# 22                Veronica Roth          3.9     6310     13  2013
# 23                   Chris Kyle          4.6    15921      9  2015
# 24              Khaled Hosseini          4.3    12159     13  2013
# 25                   Glenn Beck          4.6      798      5  2009
# 26          Neil deGrasse Tyson          4.7     9374      9  2017
# 27                   Mark Twain          4.2      491     14  2010
# 28                           DK          4.6     5360      5  2015
# 29                  Angie Grace          4.6     1909     11  2015
# 30                   Ina Garten          4.8     1296     24  2012
# 31                   Ina Garten          4.7      615     21  2010
# 32               Michelle Obama          4.8    61133     11  2018
# 33               Michelle Obama          4.8    61133     11  2019
# 34                 Atul Gawande          4.8    11113     15  2015
# 35             Ta-Nehisi Coates          4.7    10070     13  2015
# 36             Ta-Nehisi Coates          4.7    10070     13  2016
# 37            Bruce Springsteen          4.7     3729     18  2016
# 38              Stephenie Meyer          4.6     9769     13  2009
# 39                   Glenn Beck          4.5      471      8  2010
# 40              Bill Martin Jr.          4.9    14344      5  2017
# 41              Bill Martin Jr.          4.9    14344      5  2019
# 42                  Jeff Kinney          4.8     4505      0  2011
# 43                 Sasha O'Hara          4.6    10369      4  2016
# 44                David Goggins          4.8    16244     18  2019
#
#           Genre
# 0   Non Fiction
# 1       Fiction
# 2   Non Fiction
# 3       Fiction
# 4   Non Fiction
# 5       Fiction
# 6       Fiction
# 7       Fiction
# 8   Non Fiction
# 9       Fiction
# 10      Fiction
# 11  Non Fiction
# 12  Non Fiction
# 13      Fiction
# 14  Non Fiction
# 15  Non Fiction
# 16  Non Fiction
# 17  Non Fiction
# 18  Non Fiction
# 19  Non Fiction
# 20      Fiction
# 21      Fiction
# 22      Fiction
# 23  Non Fiction
# 24      Fiction
# 25  Non Fiction
# 26  Non Fiction
# 27  Non Fiction
# 28  Non Fiction
# 29  Non Fiction
# 30  Non Fiction
# 31  Non Fiction
# 32  Non Fiction
# 33  Non Fiction
# 34  Non Fiction
# 35  Non Fiction
# 36  Non Fiction
# 37  Non Fiction
# 38      Fiction
# 39  Non Fiction
# 40      Fiction
# 41      Fiction
# 42      Fiction
# 43  Non Fiction
# 44  Non Fiction
# Sheet: Sheet4
# Empty DataFrame
# Columns: []
# Index: []
# Sheet: Sheet5
# Empty DataFrame
# Columns: []
# Index: []
# Sheet: Sheet6
# Empty DataFrame
# Columns: []
# Index: []
# Sheet: Sheet7
# Empty DataFrame
# Columns: []
# Index: []

# %%
import fitz  # PyMuPDF
from PIL import Image
import pytesseract

def extract_text_from_pdf(pdf_path):
    text_content = []

    # Open the PDF file
    pdf_document = fitz.open(pdf_path)

    for page_number in range(pdf_document.page_count):
        # Get the page
        page = pdf_document[page_number]

        # Convert the page to an image
        image_list = page.get_pixmap()

        # Convert the image to a PIL Image
        pil_image = Image.frombytes("RGB", [image_list.width, image_list.height], image_list.samples)

        # Use Tesseract OCR to extract text from the image
        text = pytesseract.image_to_string(pil_image, lang='eng')

        # Append the extracted text to the result list
        text_content.append(text)

    # Close the PDF document
    pdf_document.close()

    return text_content

# Example usage
pdf_path = "C:/Users/Shreshtha/Downloads/Sample Source of Truth.pdf"
result = extract_text_from_pdf(pdf_path)

# Print the extracted text for each page
for i, page_text in enumerate(result):
    print(f"Page {i + 1} Text:\n{page_text}\n{'='*50}\n")
# Out:
# Page 1 Text:
# TEC Lombard Wax Bupa ‘poli
# theath Heartbeat Gold opti
# Gasiesuminsured a0laes a0lacs a
# Premium 10,643 72,656 1
# | Aitesptatization benefits [PP
# Pre-existing diseases: | Pre-existing disesres: | Pre-existi
# 2years 2ysars fi
# specific ilnesses/ Specific specifi
# alWatting periog treatments:2years __|itinesses/treatments: None| _treatme
# No restriction ‘No restriction Nor
# 2|Hospital accomodation sibel Zsub-timts Jsu
# [Pre-hospitalization a0days 20days a
# <4lpost hospitalization codays after 0 days after 18
# onivine,
# Rs 800perd
# [Hospital eash/Daily Cash No Not applicable ot
# “tual cost at Network
# Rs. 1500 per hospital, Re2000 per Rei
# Emergency ambulance hospitalization | hosptalization otherwice hospi
# Tlorgan donor expense Not covered ‘Covered a
# [co-payment feature
# |/Annual deductible Not applicable Not applicable Nota
# Ta0 daycare procedures | Allday care procedures | All day ca
# s|Day care procedures covered covered ce
# 40|Domiciliary hospitalization No Yes, upto Rs 50,000
# 11)atternative treatments No No
# ‘Waiting period of
# months. Expenses for2
# deliveries,
# ‘upto Rs 50000 per year
# Husband and wite tobe
# Maternity benefits covered under the same
# 12] (delivery expenses) | Waiting period of 36 months policy '
#
# |automatic covered (without|
# ‘additional charge) tll the
# ‘expiry of policy yearin
# which the baby was born.
# Vaccination expenses
#
#
# ==================================================
#
# Page 2 Text:
# 13]New born baby cov
#
# Noch
# Jaddlitional 10% sum insured!
# atthe time of renewal for
# ‘every claim free year.
# Incase of aclaim,
# cumulative additional sum
#
# covered
#
# Irrespective of whether the
# claim was made :
# Gift rewards worth 10% of
# last paid premium or
#
# Ne
# Bonus of 5)
# sum
# Incas:
# ‘accumulat
# by 50% of
#
# 14)Renewal benefits Insured to go down by 50% | additional 10% sum insured in
# 15|Loading on claims NA NA
#
# 16|Health checkup ves Yes (annual)
#
# Ti[Claim settlement record 36% am i
#
# ‘Source Poe aocuments forte respective poles (December 2014) Fer aim setement at: Mint Meili ratings, Cm
#
# months)
#
# ==================================================
#
# Page 3 Text:
# iomanich Tata AiG
#
# waRestore Medirime Star Health Comprehensive!
# lacs 3Olacs 30 acs
#
# 3,607 12,205 | 17483
#
# ingdiseases:3
#
# Pre-existing diseases:
#
# Pre-existing diseases:
#
# ayears ayears
# specifcilinesses/ Specificilinesses/
# treatments: 2years treatments: 2years
# ‘No restriction ‘No restriction,
# Jsubsliits /sub-lmits
# 60 days if informed of
# hospitalization 5 days in
# Days advance, else 30 days 30days
# 90 days if informed of
# hospitalization 5 days in
# ‘Odays advance, else 60 days sodays
# ase ofshared | _ Only for accompanying
# nodation,
#
# ay for maximum|
#
# insured child. Rs 500 per day |Rs 750 per day upto 120 days|
# subjecttoa maximum of Rs | with a maximum of 7 days
#
# Gdays 115000 per occurrence
# Rs 2500 per Rs 3500 per
#
# hospitalization policy period,
#
# svered Covered Not covered
#
# ble Not applicable
#
# re procedures | 140day care procedures
#
# wered covered procedures covered
#
# Yes Yes ‘No.
#
# No. = Rs 25000 No.
#
# None
#
# Waiting period of 36
# months.
#
# Upto Rs. 40000 per delivery
# for 2deliveries
#
# [Automatically covered upto|
# Rs 1 lac (without additional
# charge) tll the expiry of
# policy year in which the
# ‘baby was born,
# Vaccination expenses upto
#
#
# ==================================================
#
# Page 4 Text:
# None
#
# Rs 1000 covered
#
# claim:
# 0% of the
# sured ‘No claim: Sum insured
# eofclaim, enhanced by 10% (bonus) | No claim: bonus sum
# ed bonus tobe each year. Insured at 100% of basic
# duced incase of claim: Cumulative: sum insured.
# ‘the asicsum | bonus reduced by 10% of | n case of claim: bonus sum
# sured. thebasicsuminsured | _ insured becomes 2er0
# NA NA NA
#
# ‘Once every four years ‘Once every three
# No claim free years claim free years
# ET mam Boe
#
# ‘etiement ratio clot as 100% Fins repudiated = cline pending Jor over six
#
#
# ==================================================
#
# Page 5 Text:
# Group Name aac tte
#
# Group Number 123
# Renewal Date 01-01-2028
# No of employees enrolled 20
# Group State a
#
# Market Large
#
# Copay 30/45
#
# IN Coinsurance % 00/0
#
# IN Deductible 2500/5000
#
# ‘OON Coinsurance % 10/0
#
# 0N Deductible 2500/5000
#
# ==================================================
#
# Page 6 Text:
# Name ‘Author
#
# 10-Day Green Smoothie Cleanse Us Senith
# 11/22/63: ANovel Stephen King
# 12 Rules for Life: An Antidote to Chaos Jordan 8. Peterson
# 1984 (Signet Classics) George Orwell,
#
# 5,000 Awesome Facts (About Everything!) (NatiNational Geographic Kids
# [ADance with Dragons (ASongof Ice and Fire) George R.R. Martin
# [AGame of Thrones / A Clash of Kings /A Storm George R.R. Martin
#
# [AGentleman in Moscow A Novel ‘Amor Towies
# [AWigher Loyalty: Truth Lies, and Leadership James Comey
# [Anan Called Ove: A Novel Fredrik Backman
# [Anan Called Ove: A Novel Fredrik Backman
# [A Patriot's History ofthe United States: From CeLarrySchweikart
# {Stolen Life: A Memoir Jaycee Dugard
# [A.Wrinkl in Time (Time Quintet) Madeleine UEngle
#
# ‘Act Like a Lady, Think Like a Man: What Men Re Stove Harvey
# ‘Adult Coloring Book Designs: Stress Relief Color Adult Coloring Bok Designs
# [Adult Coloring Book: Stress Relieving Animal De Blue Star Coloring
#
# [Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring
#
# ‘Adult Coloring Books: Coloring Book for Adult: Coloring Books fr Adults
#
# Alexander Hamilton Ron Chernow
# All the Light We Cannot See Anthony Doerr
#
# All the Light We Cannot See Anthony Doerr
# Allegiant Veronica Roth
# ‘American Sniper: The Autobiography of the Mo:Chris Kyle
#
# [and the Mountains Echoed Khaled Hosseini
# ‘Arguing with ldits: How to Stop Small Minds ar Glenn Beck
# [Astrophysics for People in a Hurry Neil deGrasse Tyson
# ‘Autobiography of Mark Twain, Vol. 2 Mark Twain
#
# Baby Touch and Fee: Animals ok
#
# Balance (Angie's Extreme Stress Menders) Angie Grace
#
# Barefoot Contessa Foolproof: Recipes You Can TIna Garten
# Barefoot Contessa, How Easy Is That? Fabulous Ina Garten
#
# Becoming Michelle Obama
# Becoming Michelle Obama
# Being Mortal: Medicine and What Matters in th Atul Gawande
# Between the World and Me Ta-Nehisi Coates
# Between the World and Me ‘Ta-Nehisi Coates
# orm to Run Bruce Springsteen
# Breaking Dawn (The Twilight Saga, Book 4) Stephenie Meyer
#
# Broke: The Plan to Restore Our Trust, Truth and Glenn Beck
# Brown Bear, Grown Bear, What D0 You See? Bil Martini.
# Brown Bear, Grown Bear, What D0 You See? Bil Martini.
# CCabin Fever (Diary of a Wimpy Kid, 800k 6) Jeff Kinney
# Calm the Ftck Dovin: An lreverent Adult ColriSasha O'Hara
# Can't Hurt Me: Master Your Mind and Defy the ‘David Goggins
#
# User Ratin Reviews
#
# 47
# 46
# 47
# 47
# 48
# 4a
# 47
# 47
# 47
# 46
# 46
# 46
# 46
# 45
# 46
# 45
# 46
# 4a
# 45
# 48
# 46
# 46
# 39
# 46
# 43
# 46
# 47
# 42
# 46
# 46
# 48
# 47
# 43
# 48
# 48
# ar
# 47
# 47
# 46
# 45
# 49
# 49
# 48
# 46
# 48
#
# 17350
# 2052
# 18979
# zara
# 7665
# 12683
# 19738,
# 19699
# 5983
# 2aese
# 2388
# 460
# au
# 5153
# 5013
# bere}
# 2025
# 2951,
# 2026
# 9198
# 368
# 368
# 6210
# ase2a
# 12159
# 738
# 9374
# aa
# 5360
# 1909
# 1296
# 61s
# 133
# 13
# prety
# 30070
# 30070
# 3729
# 9769
# an
# saa
# uaa
# 4505,
# 10369
# e244
#
# ==================================================
#
# Page 7 Text:
# Price
#
# 8
# 2
# 5
#
# 6
# 2
# n
# 30
# 5
#
# a
#
# Year
#
# Genre
# 2016 Non Fiction
# 2011 Fition
# 2018 Non Fiction
# 2017 Fition
# 2019 Non Fiction
# 2011 Fietion
# 2014 Fiction
# 2017 Fiction
# 2018 Non Fiction
# 2016 Fition
# 2017 Fiction
# 2010 Non Fiction
# 2011 Non Fiction
# 2018 Fition
# 12009 Non Fiction
# 2016 Non Fiction
# 2015 Non Fiction
# 2015 Non Fiction
# 2015 Non Fiction
# 2016 Non Fiction
# 2014 Fition
# 2015 Fiction
# 2013 Fition
# 2015 Non Fiction
# 2013 Fition
# 12009 Non Fiction
# 2017 Non Fiction
# 2010 Non Fiction
# 2015 Non Fiction
# 2015 Non Fiction
# 2012 Non Fiction
# 2010 Non Fiction
# 2018 Non Fiction
# 2019 Non Fiction
# 2015 Non Fiction
# 2015 Non Fiction
# 2016 Non Fiction
# 2016 Non Fiction
# 12009 Fiction
# 2010 Non Fiction
# 2017 Fietion
# 2019 Fiction
# 2011 Fition
# 2016 Non Fiction
# 2019 Non Fiction
#
# ==================================================
#
# Page 8 Text:
# eves
#
# i
# BS
#
# ‘Weersshresinal Usenet
# ‘Donnas ‘Domicatsorse"
# at Deal
#
#
# ==================================================
#
# Page 9 Text:
#
# ==================================================
#
# Page 10 Text:
#
# ==================================================
#
# Page 11 Text:
# vailable plan combinations
#
#
# ==================================================

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:/Users/Shreshtha/Downloads/balmy-outcome-412805-e9aa761e058c.json"

# %%
from typing import Optional, Sequence

from google.api_core.client_options import ClientOptions
from google.cloud import documentai

# Replace the placeholder values with your actual project and processor information
project_id = 'balmy-outcome-412805'
location = "us"  # Format is "us" or "eu"
processor_id = '1c327dd87f42b98b'  # Create processor before running sample
processor_version = "rc"  # Refer to https://cloud.google.com/document-ai/docs/manage-processor-versions for more information
file_path = "C:/Users/Shreshtha/Downloads/4F82B400.pdf"
mime_type = "application/pdf"  # Refer to https://cloud.google.com/document-ai/docs/file-types for supported file types


def process_document_form_sample(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
) -> documentai.Document:
    # Online processing request to Document AI
    document = process_document(
        project_id, location, processor_id, processor_version, file_path, mime_type
    )

    # Read the table and form fields output from the processor
    # The form processor also contains OCR data. For more information
    # on how to parse OCR data please see the OCR sample.

    text = document.text
    print(f"Full document text: {repr(text)}\n")
    print(f"There are {len(document.pages)} page(s) in this document.")

    # Read the form fields and tables output from the processor
    for page in document.pages:
        print(f"\n\n**** Page {page.page_number} ****")

        print(f"\nFound {len(page.tables)} table(s):")
        for table in page.tables:
            num_columns = len(table.header_rows[0].cells)
            num_rows = len(table.body_rows)
            print(f"Table with {num_columns} columns and {num_rows} rows:")

            # Print header rows
            print("Columns:")
            print_table_rows(table.header_rows, text)
            # Print body rows
            print("Table body data:")
            print_table_rows(table.body_rows, text)

        print(f"\nFound {len(page.form_fields)} form field(s):")
        for field in page.form_fields:
            name = layout_to_text(field.field_name, text)
            value = layout_to_text(field.field_value, text)
            print(f"    * {repr(name.strip())}: {repr(value.strip())}")

    # Supported in version `pretrained-form-parser-v2.0-2022-11-10` and later.
    # For more information: https://cloud.google.com/document-ai/docs/form-parser
    if document.entities:
        print(f"Found {len(document.entities)} generic entities:")
        for entity in document.entities:
            print_entity(entity)
            # Print Nested Entities
            for prop in entity.properties:
                print_entity(prop)

    return document


def print_table_rows(
    table_rows: Sequence[documentai.Document.Page.Table.TableRow], text: str
) -> None:
    for table_row in table_rows:
        row_text = ""
        for cell in table_row.cells:
            cell_text = layout_to_text(cell.layout, text)
            row_text += f"{repr(cell_text.strip())} | "
        print(row_text)


def print_entity(entity: documentai.Document.Entity) -> None:
    # Fields detected. For a full list of fields for each processor see
    # the processor documentation:
    # https://cloud.google.com/document-ai/docs/processors-list
    key = entity.type_

    # Some other value formats in addition to text are available
    # e.g. dates: `entity.normalized_value.date_value.year`
    text_value = entity.text_anchor.content
    confidence = entity.confidence
    normalized_value = entity.normalized_value.text
    print(f"    * {repr(key)}: {repr(text_value)}({confidence:.1%} confident)")

    if normalized_value:
        print(f"    * Normalized Value: {repr(normalized_value)}")


def process_document(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
    process_options: Optional[documentai.ProcessOptions] = None,
) -> documentai.Document:
    # You must set the `api_endpoint` if you use a location other than "us".
    client = documentai.DocumentProcessorServiceClient(
        client_options=ClientOptions(
            api_endpoint=f"{location}-documentai.googleapis.com"
        )
    )

    # The full resource name of the processor version, e.g.:
    # `projects/{project_id}/locations/{location}/processors/{processor_id}/processorVersions/{processor_version_id}`
    # You must create a processor before running this sample.
    name = client.processor_version_path(
        project_id, location, processor_id, processor_version
    )

    # Read the file into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    # Configure the process request
    request = documentai.ProcessRequest(
        name=name,
        raw_document=documentai.RawDocument(content=image_content, mime_type=mime_type),
        # Only supported for Document OCR processor
        process_options=process_options,
    )

    result = client.process_document(request=request)

    # For a full list of `Document` object attributes, reference this page:
    # https://cloud.google.com/document-ai/docs/reference/rest/v1/Document
    return result.document


def layout_to_text(layout: documentai.Document.Page.Layout, text: str) -> str:
    """
    Document AI identifies text in different parts of the document by their
    offsets in the entirety of the document"s text. This function converts
    offsets to a string.
    """
    # If a text segment spans several lines, it will
    # be stored in different text segments.
    return "".join(
        text[int(segment.start_index) : int(segment.end_index)]
        for segment in layout.text_anchor.text_segments
    )


# Call the main function to process the document
document_result = process_document_form_sample(project_id, location, processor_id, processor_version, file_path, mime_type)

# The result is a `documentai.Document` object. You can access its attributes as needed.
# For example, you can print the extracted text and form fields using the provided functions.
print(f"Full document text: {repr(document_result.text)}")
print(f"There are {len(document_result.pages)} page(s) in this document.")

# Print form fields and tables
for page in document_result.pages:
    # ... (print form fields and tables as needed)
    pass

# Print generic entities (supported in version `pretrained-form-parser-v2.0-2022-11-10` and later)
if document_result.entities:
    print(f"Found {len(document_result.entities)} generic entities:")
    for entity in document_result.entities:
        print_entity(entity)
        # Print Nested Entities
        for prop in entity.properties:
            print_entity(prop)
# Out:
# Full document text: "ICICI Lombard\nMax Bupa\nApoll\nIhealth\nHeartbeat Gold\nOptin\nBasic sum insured\n10 lacs\n10 lacs\nPremium\n10,643\n22,696\n1\nHosptalization benefits\nPre-existing diseases:\nPre-existing diseases:\nPre-existi\n2 years\n2 years\n}Specifi\nSpecific illnesses/\nSpecificillnesses/treatments: None\n1 Waiting period\ntreatments: 2 years\ntreatme\nNo restriction\nNo restriction\nNo re\n2 Hospital accomodation\n/sub-limits\n/sub-limits\n/su\n3 Pre-hospitalization\n30 days\n30 days\n60\n4 Post hospitalization\n60 days after\n60 days after\n18\nOnly in c\naccon\nRs 800 per d\n5 Hospital cash/Daily Cash\nNo\nNot applicable\nof\nActual cost at Network\nRs. 1500 per\nhospital, Rs 2000 per\nRs 2\nhospitalization\nhosptalization otherwise\nhospi\nNot covered\nCovered\nCc\n6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible\nNot applicable\nNot applicable\nNot a\n140 day care procedures\nAll day care procedures\nAll day cal\ncovered\ncovered\nCO\n9 Day care procedures10 Domicilliary hospitalization\nNo\nYes, upto Rs 50,000\n11 Alternative treatments\nNo\nNo\nMaternity Benefits\nWaiting period of 24\nmonths. Expenses for 2\ndeliveries,upto Rs 50000 per year\nHusband and wife to be\nMaternity benefits\ncovered under the same\n12 (delivery expenses)\nWaiting period of 36 months\npolicy\nAutomatic covered (withoutadditional charge) till the\nexpiry of policy year inwhich the baby was born.\nVaccination expenses\nPREVERSIONS\nCORSNES\n13 | New born baby cover\nNone\ncovered\nRenewal benefits\nNo\nNo Claim:\nBonus of 51\nAdditional 10% sum insured\nSum\nIn cas\naccumulat\nat the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured\nre\nby 50% of\n14 Renewal benefits\nin\n15 Loading on claims\nNA\nΝΑ\n16 Health checkup\nYes\nYes (Annual)\n17 Claim settlement record\n96.9%\n82.2%\nSource: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim\nmonths)\nlo Munich\nTata AIG\nna Restore\nMediPrime\nStar Health Comprehensive\n.0 lacs\n10 lacs\n10 lacs\n13,607\n12,205\n17,483\ning diseases: 3\nPre-existing diseases:\nPre-existing diseases:\nyears\n4 years\n4 yearsSpecific illnesses/\nic illnesses/\nSpecific illnesses/\nents: 2 years\ntreatments: 2 years\ntreatments: 2 years\nestriction\nNo restriction\nNo restriction\nb-limits\n/sub-limits\n/sub-limits\n60 days if informed of\nhospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days\n6 days\n15000\nper occurrence\n2000 per\nRs 2500 per\nRs 3500 per\nitalization\nhospitalization\npolicy period\novered\nCovered\nNot covered\napplicable\nNot applicable\nNot applicable140 day care procedures\nre procedures\n101 day care\n>vered\ncovered\nprocedures covered\nYes\nYes\nNo\nNo\nUpto Rs 25000\nNo\nWaiting period of 36\nmonths.\nUpto Rs 40000 per delivery\nNone\nNone\nfor 2 deliveries\nAutomatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.\nVaccination expenses upto\nKRPERA\nBRESS\nNone\nNone\nRs 1000 covered\n> claim:\n0% of the Basic\nInsured\nNo claim: Sum insured\ne of claim,\nenhanced by 10% (bonus)\nNo claim: bonus sum\ned bonus to be\neach year.\ninsured at 100% of basic\neduced\nIn case of claim: Cumulative\nsum insured.\nthe basic sum\nbonus reduced by 10% of In case of claim: bonus sum\nsured.\nthe basic sum insured\ninsured becomes zero\nNA\nΝΑ\nNA\nOnce every four years\nOnce every three\nNo\nclaim free years\nclaim free years\n79.0%\n84.8%\n69.0%\nsettlement ratio calculated as 100% -(%claims repudiated + ...
#
# There are 12 page(s) in this document.
#
#
# **** Page 1 ****
#
# Found 2 table(s):
# Table with 4 columns and 21 rows:
# Columns:
# '' | 'ICICI Lombard\nIhealth' | 'Max Bupa\nHeartbeat Gold' | 'Apoll\nOptin' |
# Table body data:
# 'Basic sum insured' | '10 lacs' | '10 lacs' | '' |
# 'Premium' | '10,643' | '22,696' | '1' |
# 'Hosptalization benefits' | '' | '' | '' |
# '' | 'Pre-existing diseases:' | 'Pre-existing diseases:' | 'Pre-existi' |
# '' | '2 years' | '2 years' | '}' |
# '' | 'Specific illnesses/' | 'Specific' | 'Specifi' |
# '1 Waiting period\n2 Hospital accomodation' | 'treatments: 2 years\nNo restriction\n/sub-limits' | 'illnesses/treatments: None\nNo restriction\n/sub-limits' | 'treatme\nNo re\n/su' |
# '3 Pre-hospitalization\n4 Post hospitalization' | '30 days\n60 days after' | '30 days\n60 days after' | '60\n18' |
# 'Hospital cash/Daily Cash' | 'No' | 'Not applicable' | 'Only in c\naccon\nRs 800 per d\nof' |
# '5' | 'Rs. 1500 per' | 'Actual cost at Network\nhospital, Rs 2000 per' | 'Rs 2' |
# '6 Emergency ambulance' | 'hospitalization' | 'hosptalization otherwise' | 'hospi' |
# '7 Organ donor expense' | 'Not covered' | 'Covered' | 'Cc' |
# 'Co-payment feature8/Annual deductible' | 'Not applicable' | 'Not applicable' | 'Not a' |
# '' | '140 day care procedures' | 'All day care procedures' | 'All day cal' |
# '9 Day care procedures10 Domicilliary hospitalization' | 'covered\nNo' | 'covered\nYes, upto Rs 50,000' | 'CO' |
# '11 Alternative treatments' | 'No' | 'No' | '' |
# 'Maternity Benefits' | '' | '' | '' |
# '' | '' | 'Waiting period of 24\nmonths. Expenses for 2' | '' |
# 'Maternity benefits' | '' | 'deliveries,upto Rs 50000 per year\nHusband and wife to be\ncovered under the same' | '' |
# '12 (delivery expenses)' | 'Waiting period of 36 months' | 'policy' | '' |
# '' | '' | 'Automatic covered (withoutadditional charge) till the\nexpiry of policy year inwhich the baby was born.' | '' |
# Table with 4 columns and 2 rows:
# Columns:
# '' | 'ICICI Lombard\nIhealth' | 'Max Bupa\nHeartbeat Gold' | 'Apoll\nOptin' |
# Table body data:
# 'Basic sum insured' | '10 lacs' | '10 lacs' | '' |
# 'Premium' | '10,643' | '22,696' | '1' |
#
# Found 2 form field(s):
#     * 'Premium': ''
#     * 'Basic sum insured': ''
#
#
# **** Page 2 ****
#
# Found 1 table(s):
# Table with 3 columns and 5 rows:
# Columns:
# '13 | New born baby cover' | 'None' | 'covered' |
# Table body data:
# 'Renewal benefits' | '' | '' |
# '14 Renewal benefits' | 'No Claim:\nAdditional 10% sum insured\nat the time of renewal for every claim free year.In case of a claim,cumulative additional sum insured to go down by 50%' | 'No\nBonus of 51\nSum\nIn cas\naccumulat\nIrrespective of whether theclaim was made:Gift rewards worth 10% oflast paid premium oradditional 10% sum insured\nre\nby 50% of\nin' |
# '15 Loading on claims' | 'NA' | 'ΝΑ' |
# '16 Health checkup' | 'Yes' | 'Yes (Annual)' |
# '17 Claim settlement record' | '96.9%' | '82.2%' |
#
# Found 0 form field(s):
#
#
# **** Page 3 ****
#
# Found 3 table(s):
# Table with 3 columns and 2 rows:
# Columns:
# 'lo Munich\nna Restore' | 'Tata AIG\nMediPrime' | 'Star Health Comprehensive' |
# Table body data:
# '.0 lacs' | '10 lacs' | '10 lacs' |
# '13,607' | '12,205' | '17,483' |
# Table with 3 columns and 17 rows:
# Columns:
# 'na Restore' | 'MediPrime' | 'Star Health Comprehensive' |
# Table body data:
# '.0 lacs' | '10 lacs' | '10 lacs' |
# '13,607' | '12,205' | '17,483' |
# 'ing diseases: 3' | 'Pre-existing diseases:' | 'Pre-existing diseases:' |
# 'years\nic illnesses/' | '4 yearsSpecific illnesses/' | '4 years\nSpecific illnesses/' |
# 'ents: 2 years' | 'treatments: 2 years' | 'treatments: 2 years' |
# 'estriction\nb-limits' | 'No restriction\n/sub-limits' | 'No restriction\n/sub-limits' |
# '0 days' | '60 days if informed of\nhospitalization 5 days inadvance, else 30 days' | '30 days' |
# '10 days' | '90 days if informed ofhospitalization 5 days inadvance, else 60 days' | '60 days' |
# 'ase of sharednodation.' | 'Only for accompanyinginsured child. Rs 500 per day' | 'Rs 750 per day upto 120 days' |
# 'lay for maximum 6 days' | 'subject to a maximum of Rs 15000' | 'with a maximum of 7 days\nper occurrence' |
# '2000 per' | 'Rs 2500 per' | 'Rs 3500 per' |
# 'italization' | 'hospitalization' | 'policy period' |
# 'overed' | 'Covered' | 'Not covered' |
# 'applicable' | 'Not applicable' | 'Not applicable' |
# 're procedures\n>vered' | '140 day care procedures\ncovered' | '101 day care\nprocedures covered' |
# 'Yes' | 'Yes' | 'No' |
# 'No' | 'Upto Rs 25000' | 'No' |
# Table with 3 columns and 5 rows:
# Columns:
# 'applicable\nre procedures\n>vered' | 'Not applicable140 day care procedures\ncovered' | 'Not applicable\n101 day care\nprocedures covered' |
# Table body data:
# 'Yes' | 'Yes' | 'No' |
# 'No' | 'Upto Rs 25000' | 'No' |
# 'None' | 'None' | 'Waiting period of 36\nmonths.\nUpto Rs 40000 per delivery\nfor 2 deliveries' |
# '' | '' | 'Automatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.\nVaccination expenses' |
# 'KRPERA' | '' | 'upto\nBRESS' |
#
# Found 3 form field(s):
#     * 'Star Health Comprehensive': 'MediPrime'
#     * '10 lacs': '17,483'
#     * 'MediPrime': 'Restore'
#
#
# **** Page 4 ****
#
# Found 1 table(s):
# Table with 3 columns and 9 rows:
# Columns:
# 'None' | 'None' | 'Rs 1000 covered' |
# Table body data:
# '> claim:\n0% of the Basic\nInsured' | 'No claim: Sum insured' | '' |
# 'e of claim,\ned bonus to be\neduced' | 'enhanced by 10% (bonus)\neach year.\nIn case of claim: Cumulative' | 'No claim: bonus sum\ninsured at 100% of basic\nsum insured.' |
# 'the basic sum' | 'bonus reduced by 10% of' | 'In case of claim: bonus sum' |
# 'sured.' | 'the basic sum insured' | 'insured becomes zero' |
# 'NA' | 'ΝΑ' | 'NA' |
# '' | 'Once every four years' | 'Once every three' |
# 'No' | 'claim free years' | 'claim free years' |
# '79.0%' | '84.8%' | '69.0%' |
# 'settlement ratio' | 'calculated as 100% -(%claims repudiated' | '+% claims pending for over six' |
#
# Found 5 form field(s):
#     * 'No claim:': 'bonus sum'
#     * 'In case of claim:': 'bonus sum'
#     * 'No claim:': 'Sum insured'
#     * 'insured at': '100% of basic\nsum insured.'
#     * '> claim:': '0% of the Basic\nInsured\ne of claim,\ned bonus to be\neduced\nthe basic sum\nsured.'
#
#
# **** Page 5 ****
#
# Found 2 table(s):
# Table with 2 columns and 2 rows:
# Columns:
# 'Group Name' | 'ABC Ltd' |
# Table body data:
# 'Group Number' | '123' |
# 'Renewal Date' | '01-01-2024' |
# Table with 2 columns and 8 rows:
# Columns:
# 'No of employees enrolled' | '20' |
# Table body data:
# 'Group State' | 'CT' |
# 'Market' | 'Large' |
# 'In Network (IN):' | '' |
# 'Copay' | '30/45' |
# 'IN Coinsurance %' | '100/0' |
# 'IN Deductible' | '2500/5000' |
# 'Out of Network (OON):' | '' |
# 'OON Coinsurance %' | '100/0' |
#
# Found 10 form field(s):
#     * 'Group Number': '123'
#     * 'Renewal Date': '01-01-2024'
#     * 'OON Coinsurance %': '100/0'
#     * 'Group Name': 'ABC Ltd'
#     * 'OON Deductible': '2500/5000'
#     * 'IN Coinsurance %': '100/0'
#     * 'IN Deductible': '2500/5000'
#     * 'Copay': '30/45'
#     * 'Market': 'Large'
#     * 'Group State': 'CT'
#
#
# **** Page 6 ****
#
# Found 1 table(s):
# Table with 2 columns and 45 rows:
# Columns:
# 'Name\nAuthor\nUser RatingReviews' | '' |
# Table body data:
# '10-Day Green Smoothie Cleanse\nJJ Smith\n4.7' | '17350' |
# '11/22/63: A Novel\nStephen King\n4.6' | '2052' |
# '12 Rules for Life: An Antidote to Chaos\nJordan B. Peterson\n4.7' | '18979' |
# '1984 (Signet Classics)\nGeorge Orwell\n4.7' | '21424' |
# '5,000 Awesome Facts (About Everything!) (National\nNational\nGeographic Kids) Kids\n4.8' | '7665' |
# 'A Dance with Dragons (A Song of Ice and Fire) George R. R. Martin\n4.4' | '12643' |
# 'A Game of Thrones / A Clash of Kings / A Storm\nof Swords / A Feast o\nh Drs' | '19735' |
# 'A Gentleman in Moscow: A Novel\nAmor Towles\n4.7' | '19699' |
# 'A Higher Loyalty: Truth, Lies, and Leadership\nJames Comey\n4.7' | '5983' |
# 'A Man Called Ove: A Novel\nFredrik Backman\n4.6' | '23848' |
# 'A Man Called Ove: A Novel\nFredrik Backman\n4.6' | '23848' |
# "A Patriot's History of the United States: From Columbus's Great D\nrror4.6" | '460' |
# 'A Stolen Life: A Memoir\nJaycee Dugard\n4.6' | '4149' |
# "A Wrinkle in Time (Time Quintet)\nMadeleine L'Engle\n4.5" | '5153' |
# 'Act Like a Lady, Think Like a Man: What Men\nReally Think Abo\ncy,\n4.6' | 'omm\n5013' |
# 'Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, M\n4.5ls\n, a' | 'aisley' |
# 'Adult Coloring Book: Stress Relieving Animal DesignsBlue \nStar Coloring\n4.6' | '2925' |
# 'Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring\n4.4' | '2951' |
# 'Adult Coloring Books: A Coloring Book for Adults\nFeaturing Mandalas and\nowe' | 'nimals' |
# 'Alexander Hamilton\nRon Chernow\n4.8' | '9198' |
# 'All the Light We Cannot See\nAnthony Doerr\n4.6' | '36348' |
# 'All the Light We Cannot See\nAnthony Doerr\n4.6' | '36348' |
# 'Allegiant\nVeronica Roth\n3.9' | '6310' |
# 'American Sniper: The Autobiography of the Most Lethal SnChris Kyle\n4.6' | '15921' |
# 'And the Mountains Echoed\nKhaled Hosseini\n4.3' | '12159' |
# 'Arguing with Idiots: How to Stop Small Minds and Big GoverGlenn Beck\n4.6' | '798' |
# 'Astrophysics for People in a Hurry\nNeil deGrasse Tyson\n4.7' | '9374' |
# 'Autobiography of Mark Twain, Vol. 1\nMark Twain\n4.2' | '491' |
# 'Baby Touch and Feel: Animals\nDK\n4.6' | '5360' |
# "Balance (Angie's Extreme Stress Menders)\nAngie Grace\n4.6" | '1909' |
# 'Barefoot Contessa Foolproof: Recipes You Can Trust: A CooIna Garten\n4.8' | '1296' |
# 'Barefoot Contessa, How Easy Is That?: Fabulous Recipes &Ina Garten\n4.7' | '615' |
# 'Becoming\nMichelle Obama\n4.8' | '61133' |
# 'Becoming\nMichelle Obama\n4.8' | '61133' |
# 'Being Mortal: Medicine and What Matters in the EndAtul \nGawande\n4.8' | '11113' |
# 'Between the World and Me\nTa-Nehisi Coates\n4.7' | '10070' |
# 'Between the World and Me\nTa-Nehisi Coates\n4.7' | '10070' |
# 'Born to Run\nBruce Springsteen\n4.7' | '3729' |
# 'Breaking Dawn (The Twilight Saga, Book 4)\nStephenie Meyer\n4.6' | '9769' |
# 'Broke: The Plan to Restore Our Trust, Truth and\nTreasureGlenn \nBeck\n4.5' | '471' |
# 'Brown Bear, Brown Bear, What Do You See?\nBill Martin Jr.\n4.9' | '14344' |
# 'Brown Bear, Brown Bear, What Do You See?\nBill Martin Jr.\n4.9' | '14344' |
# 'Cabin Fever (Diary of a Wimpy Kid, Book 6)\nJeff Kinney\n4.8' | '4505' |
# "Calm the F*ck Down: An Irreverent Adult Coloring Book (IrrevSasha O'Hara\n4.6" | '10369' |
# "Can't Hurt Me: Master Your Mind and Defy the OddsDavid \nGoggins\n4.8" | '16244' |
#
# Found 1 form field(s):
#     * '12 Rules for Life:': 'An Antidote to Chaos'
#
#
# **** Page 7 ****
#
# Found 1 table(s):
# Table with 1 columns and 44 rows:
# Columns:
# 'Price\nYear\nGenre\n8\n2016 Non Fiction' |
# Table body data:
# '22\n2011 Fiction' |
# '15\n2018 Non Fiction' |
# '6\n2017 Fiction' |
# '12\n2019 Non Fiction' |
# '11\n2011 Fiction' |
# '30\n2014 Fiction' |
# '15\n2017 Fiction' |
# '3\n2018 Non Fiction' |
# '8\n2016 Fiction' |
# '8\n2017 Fiction' |
# '2\n2010 Non Fiction' |
# '32\n2011 Non Fiction' |
# '5\n2018 Fiction' |
# '17\n2009 Non Fiction' |
# '4\n2016 Non Fiction' |
# '6\n2015 Non Fiction' |
# '6\n2015 Non Fiction' |
# '8\n2015 Non Fiction' |
# '13\n2016 Non Fiction' |
# '14\n2014 Fiction' |
# '14\n2015 Fiction' |
# '13\n2013 Fiction' |
# '9\n2015 Non Fiction' |
# '13\n2013 Fiction' |
# '5\n2009 Non Fiction' |
# '9\n2017 Non Fiction' |
# '14\n2010 Non Fiction' |
# '5\n2015 Non Fiction' |
# '11\n2015 Non Fiction' |
# '24\n2012 Non Fiction' |
# '21\n2010 Non Fiction' |
# '11\n2018 Non Fiction' |
# '11\n2019 Non Fiction' |
# '15\n2015 Non Fiction' |
# '13\n2015 Non Fiction' |
# '13\n2016 Non Fiction' |
# '18\n2016 Non Fiction' |
# '13\n2009 Fiction' |
# '8\n2010 Non Fiction' |
# '5\n2017 Fiction' |
# '5\n2019 Fiction' |
# '0\n2011 Fiction' |
# '4\n2016 Non Fiction' |
# '18\n2019 Non Fiction' |
#
# Found 0 form field(s):
#
#
# **** Page 8 ****
#
# Found 0 table(s):
#
# Found 0 form field(s):
#
#
# **** Page 9 ****
#
# Found 0 table(s):
#
# Found 0 form field(s):
#
#
# **** Page 10 ****
#
# Found 2 table(s):
# Table with 2 columns and 2 rows:
# Columns:
# 'Group Name' | 'ABC Ltd' |
# Table body data:
# 'Group Number' | '123' |
# 'Renewal Date' | '01-01-2024' |
# Table with 1 columns and 11 rows:
# Columns:
# 'ABC Ltd\nGroup Name' |
# Table body data:
# 'Group Number\n123' |
# 'Renewal Date\n01-01-2024' |
# 'No of employees enrolled\n20\nGroup State\nCT' |
# 'Market\nLarge' |
# 'In Network (IN):' |
# 'Copay\n30/45' |
# 'IN Coinsurance %\n100/0' |
# 'IN Deductible\n2500/5000' |
# 'Out of Network (OON):' |
# 'OON Coinsurance %\n100/0' |
# 'OON Deductible\n2500/5000' |
#
# Found 12 form field(s):
#     * 'Group Number': '123'
#     * 'Renewal Date': '01-01-2024'
#     * 'Group Name': 'ABC Ltd'
#     * 'OON Deductible': '2500/5000'
#     * 'OON Coinsurance %': '100/0'
#     * 'IN Deductible': '2500/5000'
#     * 'IN Coinsurance %': '100/0'
#     * 'Copay': '30/45'
#     * 'Market': 'Large'
#     * 'Company Name-': 'ABC Ltd.'
#     * 'Group State': 'CT'
#     * 'No of employees enrolled': '20'
#
#
# **** Page 11 ****
#
# Found 1 table(s):
# Table with 1 columns and 9 rows:
# Columns:
# 'Plan Design:\nKACTOHP63RD\nIn-Network' |
# Table body data:
# 'Office Copay:\nPCP:\nNo Charge after Deductible\nSpecialist:\nNo Charge after Deductible\nER Copay:\nNo Charge after Deductible\nHospital Copay' |
# 'Inpatient:\nNo Charge after Deductible' |
# 'Outpatient Freestanding:\nNo Charge after Deductible' |
# 'Outpatient Hospital Setting:\nNo Charge after Deductible' |
# 'Single Deductible:\n$2,850' |
# 'Family Deductible:\n$5,700' |
# 'Coinsurance:\nNone' |
# 'Single M.O.O.P.\n$4,000' |
# 'Family M.O.O.P.\n$8,000' |
#
# Found 14 form field(s):
#     * 'Specialist:': 'No Charge after Deductible'
#     * 'PCP:': 'No Charge after Deductible'
#     * 'Single Deductible:': '$2,850'
#     * 'Family Deductible:': '$5,700'
#     * 'Single M.O.O.P.': '$4,000'
#     * 'Outpatient Freestanding:': 'No Charge after Deductible'
#     * 'Coinsurance:': 'None'
#     * 'Inpatient:': 'No Charge after Deductible'
#     * 'Plan Design:': 'KACTOHP63RD'
#     * 'Family M.O.O.P.': '$8,000'
#     * 'ER Copay:': 'No Charge after Deductible'
#     * 'Outpatient Hospital Setting:': 'No Charge after Deductible'
#     * 'Hospital Copay': 'Copay:'
#     * 'Financial Accumulation Period:': 'Calendar Year'
#
#
# **** Page 12 ****
#
# Found 2 table(s):
# Table with 3 columns and 4 rows:
# Columns:
# 'Single Deductible:' | '$2,850' | 'Modified Cost Share:' |
# Table body data:
# 'Family Deductible:' | '$5,700' | '' |
# 'Coinsurance:' | '30%' | '' |
# 'Single M.O.O.P.' | '$5,850' | '' |
# 'Family M.O.O.P.' | '$11,700' | '' |
# Table with 1 columns and 3 rows:
# Columns:
# 'Modified UCR:Standard\nUCR:\n100% of Medicare\nModified Cost Share:\nSingle Deductible:\n$2,850\nFamily Deductible:\n$5,700\nПППП' |
# Table body data:
# 'Coinsurance:\n30%' |
# 'Ain\nSingle M.O.O.P.\n$5,850' |
# 'Family M.O.O.P.\n$11,700' |
#
# Found 8 form field(s):
#     * 'UCR:': '100% of Medicare'
#     * 'Family Deductible:': '$5,700'
#     * 'Single Deductible:': '$2,850'
#     * 'Family M.O.O.P.': '$11,700'
#     * 'Single M.O.O.P.': '$5,850'
#     * 'Link to PDML:': 'http://pdml/'
#     * 'Coinsurance:': '30%'
#     * 'Modified UCR:': 'Standard'
# Found 11 generic entities:
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(38.9% confident)
#     * 'organization': ''(90.5% confident)
#     * 'quantity': ''(72.7% confident)
#     * 'quantity': ''(89.5% confident)
#     * 'quantity': ''(35.0% confident)
#     * 'quantity': ''(51.2% confident)
#     * 'quantity': ''(31.1% confident)
#     * 'quantity': ''(97.0% confident)
#     * 'quantity': ''(98.1% confident)
#     * 'quantity': ''(97.6% confident)
#     * 'quantity': ''(96.4% confident)
#     * 'quantity': ''(97.9% confident)
#     * 'quantity': ''(97.3% confident)
#     * 'quantity': ''(97.4% confident)
#     * 'quantity': ''(88.7% confident)
#     * 'date_time': ''(45.4% confident)
#     * 'date_time': ''(24.8% confident)
#     * 'quantity': ''(47.3% confident)
#     * 'quantity': ''(95.7% confident)
#     * 'quantity': ''(96.8% confident)
#     * 'quantity': ''(23.6% confident)
#     * 'quantity': ''(59.4% confident)
#     * 'quantity': ''(88.9% confident)
#     * 'quantity': ''(46.1% confident)
#     * 'quantity': ''(96.4% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(76.8% confident)
#     * 'quantity': ''(96.5% confident)
#     * 'quantity': ''(96.9% confident)
#     * 'quantity': ''(97.6% confident)
#     * 'quantity': ''(96.0% confident)
#     * 'quantity': ''(97.2% confident)
#     * 'quantity': ''(99.2% confident)
#     * 'quantity': ''(99.4% confident)
#     * 'date_time': ''(90.1% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(84.9% confident)
#     * 'quantity': ''(42.2% confident)
#     * 'quantity': ''(89.6% confident)
#     * 'quantity': ''(89.5% confident)
#     * 'quantity': ''(32.1% confident)
#     * 'quantity': ''(37.3% confident)
#     * 'quantity': ''(84.4% confident)
#     * 'quantity': ''(97.6% confident)
#     * 'quantity': ''(98.1% confident)
#     * 'quantity': ''(95.3% confident)
#     * 'quantity': ''(97.1% confident)
#     * 'quantity': ''(97.7% confident)
#     * 'quantity': ''(95.8% confident)
#     * 'quantity': ''(96.3% confident)
#     * 'quantity': ''(90.2% confident)
#     * 'quantity': ''(96.9% confident)
#     * 'quantity': ''(97.8% confident)
#     * 'quantity': ''(97.9% confident)
#     * 'quantity': ''(96.3% confident)
#     * 'quantity': ''(90.7% confident)
#     * 'quantity': ''(96.2% confident)
#     * 'quantity': ''(98.0% confident)
#     * 'quantity': ''(95.3% confident)
#     * 'quantity': ''(95.7% confident)
#     * 'quantity': ''(97.5% confident)
#     * 'date_time': ''(18.1% confident)
#     * 'quantity': ''(97.2% confident)
#     * 'quantity': ''(98.0% confident)
#     * 'quantity': ''(61.9% confident)
#     * 'quantity': ''(65.5% confident)
#     * 'quantity': ''(40.2% confident)
#     * 'quantity': ''(40.4% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(93.7% confident)
#     * 'quantity': ''(95.6% confident)
#     * 'quantity': ''(95.1% confident)
#     * 'quantity': ''(95.7% confident)
#     * 'quantity': ''(84.5% confident)
#     * 'quantity': ''(99.2% confident)
#     * 'quantity': ''(99.3% confident)
#     * 'quantity': ''(99.2% confident)
#     * 'quantity': ''(96.5% confident)
#     * 'quantity': ''(39.1% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(74.6% confident)
#     * 'date_time': ''(94.8% confident)
#     * 'date_time': ''(29.1% confident)
#     * 'date_time': ''(27.2% confident)
#     * 'date_time': ''(9.1% confident)
#     * 'date_time': ''(28.3% confident)
#     * 'price': ''(25.2% confident)
#     * 'date_time': ''(99.3% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(79.8% confident)
#     * 'organization': ''(88.2% confident)
#     * 'date_time': ''(99.3% confident)
#     * 'date_time': ''(17.6% confident)
#     * 'person': ''(97.8% confident)
#     * 'person': ''(92.8% confident)
#     * 'person': ''(78.4% confident)
#     * 'person': ''(90.4% confident)
#     * 'quantity': ''(43.6% confident)
#     * 'organization': ''(77.5% confident)
#     * 'person': ''(43.7% confident)
#     * 'person': ''(94.5% confident)
#     * 'person': ''(44.1% confident)
#     * 'organization': ''(77.9% confident)
#     * 'person': ''(97.1% confident)
#     * 'organization': ''(25.9% confident)
#     * 'quantity': ''(90.1% confident)
#     * 'price': ''(22.1% confident)
#     * 'quantity': ''(90.4% confident)
#     * 'price': ''(22.6% confident)
#     * 'quantity': ''(88.9% confident)
#     * 'price': ''(38.5% confident)
#     * 'quantity': ''(90.6% confident)
#     * 'price': ''(47.1% confident)
#     * 'quantity': ''(91.0% confident)
#     * 'price': ''(19.6% confident)
#     * 'quantity': ''(89.9% confident)
#     * 'price': ''(56.6% confident)
#     * 'quantity': ''(89.2% confident)
#     * 'price': ''(40.6% confident)
#     * 'quantity': ''(91.5% confident)
#     * 'price': ''(19.2% confident)
#     * 'quantity': ''(90.4% confident)
#     * 'price': ''(44.7% confident)
#     * 'quantity': ''(90.1% confident)
#     * 'price': ''(52.5% confident)
#     * 'quantity': ''(63.8% confident)
#     * 'quantity': ''(87.3% confident)
#     * 'price': ''(33.1% confident)
#     * 'quantity': ''(89.7% confident)
#     * 'price': ''(31.4% confident)
#     * 'quantity': ''(87.2% confident)
#     * 'price': ''(21.3% confident)
#     * 'quantity': ''(86.4% confident)
#     * 'organization': ''(11.0% confident)
#     * 'organization': ''(30.6% confident)
#     * 'person': ''(96.8% confident)
#     * 'quantity': ''(89.4% confident)
#     * 'quantity': ''(92.8% confident)
#     * 'price': ''(26.8% confident)
#     * 'quantity': ''(92.5% confident)
#     * 'price': ''(33.5% confident)
#     * 'quantity': ''(92.9% confident)
#     * 'price': ''(36.9% confident)
#     * 'person': ''(98.0% confident)
#     * 'quantity': ''(87.0% confident)
#     * 'organization': ''(25.4% confident)
#     * 'person': ''(99.0% confident)
#     * 'quantity': ''(83.8% confident)
#     * 'person': ''(93.8% confident)
#     * 'quantity': ''(85.0% confident)
#     * 'price': ''(48.2% confident)
#     * 'person': ''(0.2% confident)
#     * 'quantity': ''(83.1% confident)
#     * 'quantity': ''(73.7% confident)
#     * 'quantity': ''(62.8% confident)
#     * 'price': ''(24.8% confident)
#     * 'quantity': ''(58.5% confident)
#     * 'price': ''(39.1% confident)
#     * 'person': ''(39.2% confident)
#     * 'person': ''(26.4% confident)
#     * 'quantity': ''(45.6% confident)
#     * 'price': ''(50.5% confident)
#     * 'organization': ''(82.7% confident)
#     * 'quantity': ''(45.9% confident)
#     * 'price': ''(46.6% confident)
#     * 'person': ''(96.7% confident)
#     * 'quantity': ''(60.8% confident)
#     * 'price': ''(39.5% confident)
#     * 'quantity': ''(50.9% confident)
#     * 'price': ''(45.0% confident)
#     * 'organization': ''(80.5% confident)
#     * 'quantity': ''(71.7% confident)
#     * 'price': ''(22.3% confident)
#     * 'person': ''(91.9% confident)
#     * 'quantity': ''(72.1% confident)
#     * 'person': ''(96.6% confident)
#     * 'quantity': ''(72.1% confident)
#     * 'quantity': ''(80.0% confident)
#     * 'quantity': ''(79.3% confident)
#     * 'price': ''(31.9% confident)
#     * 'quantity': ''(75.4% confident)
#     * 'quantity': ''(86.0% confident)
#     * 'organization': ''(37.9% confident)
#     * 'person': ''(92.6% confident)
#     * 'person': ''(33.2% confident)
#     * 'person': ''(94.2% confident)
#     * 'person': ''(37.7% confident)
#     * 'organization': ''(87.1% confident)
#     * 'person': ''(47.8% confident)
#     * 'person': ''(97.5% confident)
#     * 'person': ''(99.0% confident)
#     * 'quantity': ''(69.8% confident)
#     * 'price': ''(20.2% confident)
#     * 'quantity': ''(61.6% confident)
#     * 'price': ''(42.0% confident)
#     * 'person': ''(98.4% confident)
#     * 'quantity': ''(66.5% confident)
#     * 'person': ''(97.1% confident)
#     * 'quantity': ''(63.5% confident)
#     * 'person': ''(95.3% confident)
#     * 'quantity': ''(70.2% confident)
#     * 'price': ''(18.8% confident)
#     * 'quantity': ''(63.3% confident)
#     * 'quantity': ''(62.5% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(53.0% confident)
#     * 'quantity': ''(23.0% confident)
#     * 'quantity': ''(66.1% confident)
#     * 'quantity': ''(48.2% confident)
#     * 'quantity': ''(84.0% confident)
#     * 'quantity': ''(39.5% confident)
#     * 'quantity': ''(88.4% confident)
#     * 'quantity': ''(57.0% confident)
#     * 'quantity': ''(92.0% confident)
#     * 'quantity': ''(43.4% confident)
#     * 'quantity': ''(94.4% confident)
#     * 'quantity': ''(60.3% confident)
#     * 'quantity': ''(94.3% confident)
#     * 'quantity': ''(58.9% confident)
#     * 'quantity': ''(94.2% confident)
#     * 'quantity': ''(55.5% confident)
#     * 'quantity': ''(95.1% confident)
#     * 'quantity': ''(44.4% confident)
#     * 'quantity': ''(93.9% confident)
#     * 'quantity': ''(59.2% confident)
#     * 'quantity': ''(93.6% confident)
#     * 'quantity': ''(55.7% confident)
#     * 'quantity': ''(94.3% confident)
#     * 'quantity': ''(37.3% confident)
#     * 'quantity': ''(90.2% confident)
#     * 'quantity': ''(30.9% confident)
#     * 'quantity': ''(91.5% confident)
#     * 'quantity': ''(52.8% confident)
#     * 'quantity': ''(88.4% confident)
#     * 'quantity': ''(30.1% confident)
#     * 'quantity': ''(92.5% confident)
#     * 'quantity': ''(29.1% confident)
#     * 'quantity': ''(91.6% confident)
#     * 'quantity': ''(25.6% confident)
#     * 'quantity': ''(91.2% confident)
#     * 'quantity': ''(24.8% confident)
#     * 'quantity': ''(90.0% confident)
#     * 'quantity': ''(85.1% confident)
#     * 'quantity': ''(87.2% confident)
#     * 'quantity': ''(47.7% confident)
#     * 'quantity': ''(87.9% confident)
#     * 'quantity': ''(40.3% confident)
#     * 'quantity': ''(88.7% confident)
#     * 'quantity': ''(40.9% confident)
#     * 'quantity': ''(92.5% confident)
#     * 'quantity': ''(27.7% confident)
#     * 'quantity': ''(89.4% confident)
#     * 'quantity': ''(41.3% confident)
#     * 'quantity': ''(92.3% confident)
#     * 'quantity': ''(31.1% confident)
#     * 'quantity': ''(90.7% confident)
#     * 'quantity': ''(24.0% confident)
#     * 'quantity': ''(85.4% confident)
#     * 'quantity': ''(89.6% confident)
#     * 'quantity': ''(84.9% confident)
#     * 'quantity': ''(83.6% confident)
#     * 'quantity': ''(82.8% confident)
#     * 'quantity': ''(81.5% confident)
#     * 'quantity': ''(80.2% confident)
#     * 'quantity': ''(80.3% confident)
#     * 'quantity': ''(79.8% confident)
#     * 'quantity': ''(82.4% confident)
#     * 'quantity': ''(78.6% confident)
#     * 'quantity': ''(85.7% confident)
#     * 'quantity': ''(32.2% confident)
#     * 'quantity': ''(92.2% confident)
#     * 'quantity': ''(89.7% confident)
#     * 'quantity': ''(38.1% confident)
#     * 'quantity': ''(90.5% confident)
#     * 'quantity': ''(36.9% confident)
#     * 'quantity': ''(91.0% confident)
#     * 'quantity': ''(33.0% confident)
#     * 'quantity': ''(92.2% confident)
#     * 'quantity': ''(83.3% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(37.4% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(75.9% confident)
#     * 'organization': ''(83.2% confident)
#     * 'id': ''(97.1% confident)
#     * 'date_time': ''(99.6% confident)
#     * 'id': ''(62.4% confident)
#     * 'date_time': ''(95.3% confident)
#     * 'date_time': ''(20.4% confident)
#     * 'date_time': ''(15.7% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(68.6% confident)
#     * 'id': ''(83.4% confident)
#     * 'price': ''(98.4% confident)
#     * 'price': ''(98.1% confident)
#     * 'price': ''(46.9% confident)
#     * 'date_time': ''(61.4% confident)
#     * 'price': ''(98.6% confident)
#     * 'date_time': ''(53.4% confident)
#     * 'price': ''(98.7% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'url': ''(98.9% confident)
#     * 'organization': ''(91.5% confident)
#     * 'quantity': ''(96.9% confident)
#     * 'price': ''(98.3% confident)
#     * 'price': ''(98.1% confident)
#     * 'quantity': ''(97.0% confident)
#     * 'organization': ''(21.3% confident)
#     * 'date_time': ''(30.5% confident)
#     * 'price': ''(98.6% confident)
#     * 'date_time': ''(34.0% confident)
#     * 'price': ''(98.5% confident)
# Full document text: "ICICI Lombard\nMax Bupa\nApoll\nIhealth\nHeartbeat Gold\nOptin\nBasic sum insured\n10 lacs\n10 lacs\nPremium\n10,643\n22,696\n1\nHosptalization benefits\nPre-existing diseases:\nPre-existing diseases:\nPre-existi\n2 years\n2 years\n}Specifi\nSpecific illnesses/\nSpecificillnesses/treatments: None\n1 Waiting period\ntreatments: 2 years\ntreatme\nNo restriction\nNo restriction\nNo re\n2 Hospital accomodation\n/sub-limits\n/sub-limits\n/su\n3 Pre-hospitalization\n30 days\n30 days\n60\n4 Post hospitalization\n60 days after\n60 days after\n18\nOnly in c\naccon\nRs 800 per d\n5 Hospital cash/Daily Cash\nNo\nNot applicable\nof\nActual cost at Network\nRs. 1500 per\nhospital, Rs 2000 per\nRs 2\nhospitalization\nhosptalization otherwise\nhospi\nNot covered\nCovered\nCc\n6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible\nNot applicable\nNot applicable\nNot a\n140 day care procedures\nAll day care procedures\nAll day cal\ncovered\ncovered\nCO\n9 Day care procedures10 Domicilliary hospitalization\nNo\nYes, upto Rs 50,000\n11 Alternative treatments\nNo\nNo\nMaternity Benefits\nWaiting period of 24\nmonths. Expenses for 2\ndeliveries,upto Rs 50000 per year\nHusband and wife to be\nMaternity benefits\ncovered under the same\n12 (delivery expenses)\nWaiting period of 36 months\npolicy\nAutomatic covered (withoutadditional charge) till the\nexpiry of policy year inwhich the baby was born.\nVaccination expenses\nPREVERSIONS\nCORSNES\n13 | New born baby cover\nNone\ncovered\nRenewal benefits\nNo\nNo Claim:\nBonus of 51\nAdditional 10% sum insured\nSum\nIn cas\naccumulat\nat the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured\nre\nby 50% of\n14 Renewal benefits\nin\n15 Loading on claims\nNA\nΝΑ\n16 Health checkup\nYes\nYes (Annual)\n17 Claim settlement record\n96.9%\n82.2%\nSource: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim\nmonths)\nlo Munich\nTata AIG\nna Restore\nMediPrime\nStar Health Comprehensive\n.0 lacs\n10 lacs\n10 lacs\n13,607\n12,205\n17,483\ning diseases: 3\nPre-existing diseases:\nPre-existing diseases:\nyears\n4 years\n4 yearsSpecific illnesses/\nic illnesses/\nSpecific illnesses/\nents: 2 years\ntreatments: 2 years\ntreatments: 2 years\nestriction\nNo restriction\nNo restriction\nb-limits\n/sub-limits\n/sub-limits\n60 days if informed of\nhospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days\n6 days\n15000\nper occurrence\n2000 per\nRs 2500 per\nRs 3500 per\nitalization\nhospitalization\npolicy period\novered\nCovered\nNot covered\napplicable\nNot applicable\nNot applicable140 day care procedures\nre procedures\n101 day care\n>vered\ncovered\nprocedures covered\nYes\nYes\nNo\nNo\nUpto Rs 25000\nNo\nWaiting period of 36\nmonths.\nUpto Rs 40000 per delivery\nNone\nNone\nfor 2 deliveries\nAutomatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.\nVaccination expenses upto\nKRPERA\nBRESS\nNone\nNone\nRs 1000 covered\n> claim:\n0% of the Basic\nInsured\nNo claim: Sum insured\ne of claim,\nenhanced by 10% (bonus)\nNo claim: bonus sum\ned bonus to be\neach year.\ninsured at 100% of basic\neduced\nIn case of claim: Cumulative\nsum insured.\nthe basic sum\nbonus reduced by 10% of In case of claim: bonus sum\nsured.\nthe basic sum insured\ninsured becomes zero\nNA\nΝΑ\nNA\nOnce every four years\nOnce every three\nNo\nclaim free years\nclaim free years\n79.0%\n84.8%\n69.0%\nsettlement ratio calculated as 100% -(%claims repudiated + ...
# There are 12 page(s) in this document.
# Found 11 generic entities:
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(38.9% confident)
#     * 'organization': ''(90.5% confident)
#     * 'quantity': ''(72.7% confident)
#     * 'quantity': ''(89.5% confident)
#     * 'quantity': ''(35.0% confident)
#     * 'quantity': ''(51.2% confident)
#     * 'quantity': ''(31.1% confident)
#     * 'quantity': ''(97.0% confident)
#     * 'quantity': ''(98.1% confident)
#     * 'quantity': ''(97.6% confident)
#     * 'quantity': ''(96.4% confident)
#     * 'quantity': ''(97.9% confident)
#     * 'quantity': ''(97.3% confident)
#     * 'quantity': ''(97.4% confident)
#     * 'quantity': ''(88.7% confident)
#     * 'date_time': ''(45.4% confident)
#     * 'date_time': ''(24.8% confident)
#     * 'quantity': ''(47.3% confident)
#     * 'quantity': ''(95.7% confident)
#     * 'quantity': ''(96.8% confident)
#     * 'quantity': ''(23.6% confident)
#     * 'quantity': ''(59.4% confident)
#     * 'quantity': ''(88.9% confident)
#     * 'quantity': ''(46.1% confident)
#     * 'quantity': ''(96.4% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(76.8% confident)
#     * 'quantity': ''(96.5% confident)
#     * 'quantity': ''(96.9% confident)
#     * 'quantity': ''(97.6% confident)
#     * 'quantity': ''(96.0% confident)
#     * 'quantity': ''(97.2% confident)
#     * 'quantity': ''(99.2% confident)
#     * 'quantity': ''(99.4% confident)
#     * 'date_time': ''(90.1% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(84.9% confident)
#     * 'quantity': ''(42.2% confident)
#     * 'quantity': ''(89.6% confident)
#     * 'quantity': ''(89.5% confident)
#     * 'quantity': ''(32.1% confident)
#     * 'quantity': ''(37.3% confident)
#     * 'quantity': ''(84.4% confident)
#     * 'quantity': ''(97.6% confident)
#     * 'quantity': ''(98.1% confident)
#     * 'quantity': ''(95.3% confident)
#     * 'quantity': ''(97.1% confident)
#     * 'quantity': ''(97.7% confident)
#     * 'quantity': ''(95.8% confident)
#     * 'quantity': ''(96.3% confident)
#     * 'quantity': ''(90.2% confident)
#     * 'quantity': ''(96.9% confident)
#     * 'quantity': ''(97.8% confident)
#     * 'quantity': ''(97.9% confident)
#     * 'quantity': ''(96.3% confident)
#     * 'quantity': ''(90.7% confident)
#     * 'quantity': ''(96.2% confident)
#     * 'quantity': ''(98.0% confident)
#     * 'quantity': ''(95.3% confident)
#     * 'quantity': ''(95.7% confident)
#     * 'quantity': ''(97.5% confident)
#     * 'date_time': ''(18.1% confident)
#     * 'quantity': ''(97.2% confident)
#     * 'quantity': ''(98.0% confident)
#     * 'quantity': ''(61.9% confident)
#     * 'quantity': ''(65.5% confident)
#     * 'quantity': ''(40.2% confident)
#     * 'quantity': ''(40.4% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(93.7% confident)
#     * 'quantity': ''(95.6% confident)
#     * 'quantity': ''(95.1% confident)
#     * 'quantity': ''(95.7% confident)
#     * 'quantity': ''(84.5% confident)
#     * 'quantity': ''(99.2% confident)
#     * 'quantity': ''(99.3% confident)
#     * 'quantity': ''(99.2% confident)
#     * 'quantity': ''(96.5% confident)
#     * 'quantity': ''(39.1% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(74.6% confident)
#     * 'date_time': ''(94.8% confident)
#     * 'date_time': ''(29.1% confident)
#     * 'date_time': ''(27.2% confident)
#     * 'date_time': ''(9.1% confident)
#     * 'date_time': ''(28.3% confident)
#     * 'price': ''(25.2% confident)
#     * 'date_time': ''(99.3% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(79.8% confident)
#     * 'organization': ''(88.2% confident)
#     * 'date_time': ''(99.3% confident)
#     * 'date_time': ''(17.6% confident)
#     * 'person': ''(97.8% confident)
#     * 'person': ''(92.8% confident)
#     * 'person': ''(78.4% confident)
#     * 'person': ''(90.4% confident)
#     * 'quantity': ''(43.6% confident)
#     * 'organization': ''(77.5% confident)
#     * 'person': ''(43.7% confident)
#     * 'person': ''(94.5% confident)
#     * 'person': ''(44.1% confident)
#     * 'organization': ''(77.9% confident)
#     * 'person': ''(97.1% confident)
#     * 'organization': ''(25.9% confident)
#     * 'quantity': ''(90.1% confident)
#     * 'price': ''(22.1% confident)
#     * 'quantity': ''(90.4% confident)
#     * 'price': ''(22.6% confident)
#     * 'quantity': ''(88.9% confident)
#     * 'price': ''(38.5% confident)
#     * 'quantity': ''(90.6% confident)
#     * 'price': ''(47.1% confident)
#     * 'quantity': ''(91.0% confident)
#     * 'price': ''(19.6% confident)
#     * 'quantity': ''(89.9% confident)
#     * 'price': ''(56.6% confident)
#     * 'quantity': ''(89.2% confident)
#     * 'price': ''(40.6% confident)
#     * 'quantity': ''(91.5% confident)
#     * 'price': ''(19.2% confident)
#     * 'quantity': ''(90.4% confident)
#     * 'price': ''(44.7% confident)
#     * 'quantity': ''(90.1% confident)
#     * 'price': ''(52.5% confident)
#     * 'quantity': ''(63.8% confident)
#     * 'quantity': ''(87.3% confident)
#     * 'price': ''(33.1% confident)
#     * 'quantity': ''(89.7% confident)
#     * 'price': ''(31.4% confident)
#     * 'quantity': ''(87.2% confident)
#     * 'price': ''(21.3% confident)
#     * 'quantity': ''(86.4% confident)
#     * 'organization': ''(11.0% confident)
#     * 'organization': ''(30.6% confident)
#     * 'person': ''(96.8% confident)
#     * 'quantity': ''(89.4% confident)
#     * 'quantity': ''(92.8% confident)
#     * 'price': ''(26.8% confident)
#     * 'quantity': ''(92.5% confident)
#     * 'price': ''(33.5% confident)
#     * 'quantity': ''(92.9% confident)
#     * 'price': ''(36.9% confident)
#     * 'person': ''(98.0% confident)
#     * 'quantity': ''(87.0% confident)
#     * 'organization': ''(25.4% confident)
#     * 'person': ''(99.0% confident)
#     * 'quantity': ''(83.8% confident)
#     * 'person': ''(93.8% confident)
#     * 'quantity': ''(85.0% confident)
#     * 'price': ''(48.2% confident)
#     * 'person': ''(0.2% confident)
#     * 'quantity': ''(83.1% confident)
#     * 'quantity': ''(73.7% confident)
#     * 'quantity': ''(62.8% confident)
#     * 'price': ''(24.8% confident)
#     * 'quantity': ''(58.5% confident)
#     * 'price': ''(39.1% confident)
#     * 'person': ''(39.2% confident)
#     * 'person': ''(26.4% confident)
#     * 'quantity': ''(45.6% confident)
#     * 'price': ''(50.5% confident)
#     * 'organization': ''(82.7% confident)
#     * 'quantity': ''(45.9% confident)
#     * 'price': ''(46.6% confident)
#     * 'person': ''(96.7% confident)
#     * 'quantity': ''(60.8% confident)
#     * 'price': ''(39.5% confident)
#     * 'quantity': ''(50.9% confident)
#     * 'price': ''(45.0% confident)
#     * 'organization': ''(80.5% confident)
#     * 'quantity': ''(71.7% confident)
#     * 'price': ''(22.3% confident)
#     * 'person': ''(91.9% confident)
#     * 'quantity': ''(72.1% confident)
#     * 'person': ''(96.6% confident)
#     * 'quantity': ''(72.1% confident)
#     * 'quantity': ''(80.0% confident)
#     * 'quantity': ''(79.3% confident)
#     * 'price': ''(31.9% confident)
#     * 'quantity': ''(75.4% confident)
#     * 'quantity': ''(86.0% confident)
#     * 'organization': ''(37.9% confident)
#     * 'person': ''(92.6% confident)
#     * 'person': ''(33.2% confident)
#     * 'person': ''(94.2% confident)
#     * 'person': ''(37.7% confident)
#     * 'organization': ''(87.1% confident)
#     * 'person': ''(47.8% confident)
#     * 'person': ''(97.5% confident)
#     * 'person': ''(99.0% confident)
#     * 'quantity': ''(69.8% confident)
#     * 'price': ''(20.2% confident)
#     * 'quantity': ''(61.6% confident)
#     * 'price': ''(42.0% confident)
#     * 'person': ''(98.4% confident)
#     * 'quantity': ''(66.5% confident)
#     * 'person': ''(97.1% confident)
#     * 'quantity': ''(63.5% confident)
#     * 'person': ''(95.3% confident)
#     * 'quantity': ''(70.2% confident)
#     * 'price': ''(18.8% confident)
#     * 'quantity': ''(63.3% confident)
#     * 'quantity': ''(62.5% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'quantity': ''(53.0% confident)
#     * 'quantity': ''(23.0% confident)
#     * 'quantity': ''(66.1% confident)
#     * 'quantity': ''(48.2% confident)
#     * 'quantity': ''(84.0% confident)
#     * 'quantity': ''(39.5% confident)
#     * 'quantity': ''(88.4% confident)
#     * 'quantity': ''(57.0% confident)
#     * 'quantity': ''(92.0% confident)
#     * 'quantity': ''(43.4% confident)
#     * 'quantity': ''(94.4% confident)
#     * 'quantity': ''(60.3% confident)
#     * 'quantity': ''(94.3% confident)
#     * 'quantity': ''(58.9% confident)
#     * 'quantity': ''(94.2% confident)
#     * 'quantity': ''(55.5% confident)
#     * 'quantity': ''(95.1% confident)
#     * 'quantity': ''(44.4% confident)
#     * 'quantity': ''(93.9% confident)
#     * 'quantity': ''(59.2% confident)
#     * 'quantity': ''(93.6% confident)
#     * 'quantity': ''(55.7% confident)
#     * 'quantity': ''(94.3% confident)
#     * 'quantity': ''(37.3% confident)
#     * 'quantity': ''(90.2% confident)
#     * 'quantity': ''(30.9% confident)
#     * 'quantity': ''(91.5% confident)
#     * 'quantity': ''(52.8% confident)
#     * 'quantity': ''(88.4% confident)
#     * 'quantity': ''(30.1% confident)
#     * 'quantity': ''(92.5% confident)
#     * 'quantity': ''(29.1% confident)
#     * 'quantity': ''(91.6% confident)
#     * 'quantity': ''(25.6% confident)
#     * 'quantity': ''(91.2% confident)
#     * 'quantity': ''(24.8% confident)
#     * 'quantity': ''(90.0% confident)
#     * 'quantity': ''(85.1% confident)
#     * 'quantity': ''(87.2% confident)
#     * 'quantity': ''(47.7% confident)
#     * 'quantity': ''(87.9% confident)
#     * 'quantity': ''(40.3% confident)
#     * 'quantity': ''(88.7% confident)
#     * 'quantity': ''(40.9% confident)
#     * 'quantity': ''(92.5% confident)
#     * 'quantity': ''(27.7% confident)
#     * 'quantity': ''(89.4% confident)
#     * 'quantity': ''(41.3% confident)
#     * 'quantity': ''(92.3% confident)
#     * 'quantity': ''(31.1% confident)
#     * 'quantity': ''(90.7% confident)
#     * 'quantity': ''(24.0% confident)
#     * 'quantity': ''(85.4% confident)
#     * 'quantity': ''(89.6% confident)
#     * 'quantity': ''(84.9% confident)
#     * 'quantity': ''(83.6% confident)
#     * 'quantity': ''(82.8% confident)
#     * 'quantity': ''(81.5% confident)
#     * 'quantity': ''(80.2% confident)
#     * 'quantity': ''(80.3% confident)
#     * 'quantity': ''(79.8% confident)
#     * 'quantity': ''(82.4% confident)
#     * 'quantity': ''(78.6% confident)
#     * 'quantity': ''(85.7% confident)
#     * 'quantity': ''(32.2% confident)
#     * 'quantity': ''(92.2% confident)
#     * 'quantity': ''(89.7% confident)
#     * 'quantity': ''(38.1% confident)
#     * 'quantity': ''(90.5% confident)
#     * 'quantity': ''(36.9% confident)
#     * 'quantity': ''(91.0% confident)
#     * 'quantity': ''(33.0% confident)
#     * 'quantity': ''(92.2% confident)
#     * 'quantity': ''(83.3% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(37.4% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(75.9% confident)
#     * 'organization': ''(83.2% confident)
#     * 'id': ''(97.1% confident)
#     * 'date_time': ''(99.6% confident)
#     * 'id': ''(62.4% confident)
#     * 'date_time': ''(95.3% confident)
#     * 'date_time': ''(20.4% confident)
#     * 'date_time': ''(15.7% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'organization': ''(68.6% confident)
#     * 'id': ''(83.4% confident)
#     * 'price': ''(98.4% confident)
#     * 'price': ''(98.1% confident)
#     * 'price': ''(46.9% confident)
#     * 'date_time': ''(61.4% confident)
#     * 'price': ''(98.6% confident)
#     * 'date_time': ''(53.4% confident)
#     * 'price': ''(98.7% confident)
#     * 'generic_entities': ''(0.0% confident)
#     * 'url': ''(98.9% confident)
#     * 'organization': ''(91.5% confident)
#     * 'quantity': ''(96.9% confident)
#     * 'price': ''(98.3% confident)
#     * 'price': ''(98.1% confident)
#     * 'quantity': ''(97.0% confident)
#     * 'organization': ''(21.3% confident)
#     * 'date_time': ''(30.5% confident)
#     * 'price': ''(98.6% confident)
#     * 'date_time': ''(34.0% confident)
#     * 'price': ''(98.5% confident)

# %%
from typing import Optional, Sequence

from google.api_core.client_options import ClientOptions
from google.cloud import documentai

# Replace the placeholder values with your actual project and processor information
project_id = 'balmy-outcome-412805'
location = "us"  # Format is "us" or "eu"
processor_id = '1c327dd87f42b98b'  # Create processor before running sample
processor_version = "rc"  # Refer to https://cloud.google.com/document-ai/docs/manage-processor-versions for more information
file_path = "C:/Users/Shreshtha/Downloads/4F82B400.pdf"
mime_type = "application/pdf"  # Refer to https://cloud.google.com/document-ai/docs/file-types for supported file types

def process_document_ocr_sample(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
) -> None:
    # Optional: Additional configurations for Document OCR Processor.
    # For more information: https://cloud.google.com/document-ai/docs/enterprise-document-ocr
    process_options = documentai.ProcessOptions(
        ocr_config=documentai.OcrConfig(
            enable_native_pdf_parsing=True,
            enable_image_quality_scores=True,
            enable_symbol=True,
            # Comment out the premium_features section to disable premium OCR features
            # premium_features=documentai.OcrConfig.PremiumFeatures(
            #     compute_style_info=True,
            #     enable_math_ocr=False,  # Enable to use Math OCR Model
            #     enable_selection_mark_detection=True,
            # ),
        )
    )
    # Online processing request to Document AI
    document = process_document(
        project_id,
        location,
        processor_id,
        processor_version,
        file_path,
        mime_type,
        process_options=process_options,
    )

    text = document.text
    print(f"Full document text: {text}\n")
    print(f"There are {len(document.pages)} page(s) in this document.\n")

    for page in document.pages:
        print(f"Page {page.page_number}:")
        print_page_dimensions(page.dimension)
        print_detected_languages(page.detected_languages)

        print_blocks(page.blocks, text)
        print_paragraphs(page.paragraphs, text)
        print_lines(page.lines, text)
        print_tokens(page.tokens, text)

        if page.symbols:
            print_symbols(page.symbols, text)

        if page.image_quality_scores:
            print_image_quality_scores(page.image_quality_scores)

        if page.visual_elements:
            print_visual_elements(page.visual_elements, text)


def print_page_dimensions(dimension: documentai.Document.Page.Dimension) -> None:
    print(f"    Width: {str(dimension.width)}")
    print(f"    Height: {str(dimension.height)}")


def print_detected_languages(
    detected_languages: Sequence[documentai.Document.Page.DetectedLanguage],
) -> None:
    print("    Detected languages:")
    for lang in detected_languages:
        print(f"        {lang.language_code} ({lang.confidence:.1%} confidence)")


def print_blocks(blocks: Sequence[documentai.Document.Page.Block], text: str) -> None:
    print(f"    {len(blocks)} blocks detected:")
    first_block_text = layout_to_text(blocks[0].layout, text)
    print(f"        First text block: {repr(first_block_text)}")
    last_block_text = layout_to_text(blocks[-1].layout, text)
    print(f"        Last text block: {repr(last_block_text)}")


def print_paragraphs(
    paragraphs: Sequence[documentai.Document.Page.Paragraph], text: str
) -> None:
    print(f"    {len(paragraphs)} paragraphs detected:")
    first_paragraph_text = layout_to_text(paragraphs[0].layout, text)
    print(f"        First paragraph text: {repr(first_paragraph_text)}")
    last_paragraph_text = layout_to_text(paragraphs[-1].layout, text)
    print(f"        Last paragraph text: {repr(last_paragraph_text)}")


def print_lines(lines: Sequence[documentai.Document.Page.Line], text: str) -> None:
    print(f"    {len(lines)} lines detected:")
    first_line_text = layout_to_text(lines[0].layout, text)
    print(f"        First line text: {repr(first_line_text)}")
    last_line_text = layout_to_text(lines[-1].layout, text)
    print(f"        Last line text: {repr(last_line_text)}")


def print_tokens(tokens: Sequence[documentai.Document.Page.Token], text: str) -> None:
    print(f"    {len(tokens)} tokens detected:")
    first_token_text = layout_to_text(tokens[0].layout, text)
    first_token_break_type = tokens[0].detected_break.type_.name
    print(f"        First token text: {repr(first_token_text)}")
    print(f"        First token break type: {repr(first_token_break_type)}")
    if tokens[0].style_info:
        print_style_info(tokens[0].style_info)

    last_token_text = layout_to_text(tokens[-1].layout, text)
    last_token_break_type = tokens[-1].detected_break.type_.name
    print(f"        Last token text: {repr(last_token_text)}")
    print(f"        Last token break type: {repr(last_token_break_type)}")
    if tokens[-1].style_info:
        print_style_info(tokens[-1].style_info)


def print_symbols(
    symbols: Sequence[documentai.Document.Page.Symbol], text: str
) -> None:
    print(f"    {len(symbols)} symbols detected:")
    first_symbol_text = layout_to_text(symbols[0].layout, text)
    print(f"        First symbol text: {repr(first_symbol_text)}")
    last_symbol_text = layout_to_text(symbols[-1].layout, text)
    print(f"        Last symbol text: {repr(last_symbol_text)}")


def print_image_quality_scores(
    image_quality_scores: documentai.Document.Page.ImageQualityScores,
) -> None:
    print(f"    Quality score: {image_quality_scores.quality_score:.1%}")
    print("    Detected defects:")

    for detected_defect in image_quality_scores.detected_defects:
        print(f"        {detected_defect.type_}: {detected_defect.confidence:.1%}")


def print_style_info(style_info: documentai.Document.Page.Token.StyleInfo) -> None:
    """
    Only supported in version `pretrained-ocr-v2.0-2023-06-02`
    """
    print(f"           Font Size: {style_info.font_size}pt")
    print(f"           Font Type: {style_info.font_type}")
    print(f"           Bold: {style_info.bold}")
    print(f"           Italic: {style_info.italic}")
    print(f"           Underlined: {style_info.underlined}")
    print(f"           Handwritten: {style_info.handwritten}")
    print(
        f"           Text Color (RGBa): {style_info.text_color.red}, {style_info.text_color.green}, {style_info.text_color.blue}, {style_info.text_color.alpha}"
    )


def print_visual_elements(
    visual_elements: Sequence[documentai.Document.Page.VisualElement], text: str
) -> None:
    """
    Only supported in version `pretrained-ocr-v2.0-2023-06-02`
    """
    checkboxes = [x for x in visual_elements if "checkbox" in x.type]
    math_symbols = [x for x in visual_elements if x.type == "math_formula"]

    if checkboxes:
        print(f"    {len(checkboxes)} checkboxes detected:")
        print(f"        First checkbox: {repr(checkboxes[0].type)}")
        print(f"        Last checkbox: {repr(checkboxes[-1].type)}")

    if math_symbols:
        print(f"    {len(math_symbols)} math symbols detected:")
        first_math_symbol_text = layout_to_text(math_symbols[0].layout, text)
        print(f"        First math symbol: {repr(first_math_symbol_text)}")


def process_document(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
    process_options: Optional[documentai.ProcessOptions] = None,
) -> documentai.Document:
    # You must set the `api_endpoint` if you use a location other than "us".
    client = documentai.DocumentProcessorServiceClient(
        client_options=ClientOptions(
            api_endpoint=f"{location}-documentai.googleapis.com"
        )
    )

    # The full resource name of the processor version, e.g.:
    # `projects/{project_id}/locations/{location}/processors/{processor_id}/processorVersions/{processor_version_id}`
    # You must create a processor before running this sample.
    name = client.processor_version_path(
        project_id, location, processor_id, processor_version
    )

    # Read the file into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    # Configure the process request
    request = documentai.ProcessRequest(
        name=name,
        raw_document=documentai.RawDocument(content=image_content, mime_type=mime_type),
        # Only supported for Document OCR processor
        process_options=process_options,
    )

    result = client.process_document(request=request)

    # For a full list of `Document` object attributes, reference this page:
    # https://cloud.google.com/document-ai/docs/reference/rest/v1/Document
    return result.document


def layout_to_text(layout: documentai.Document.Page.Layout, text: str) -> str:
    """
    Document AI identifies text in different parts of the document by their
    offsets in the entirety of the document"s text. This function converts
    offsets to a string.
    """
    # If a text segment spans several lines, it will
    # be stored in different text segments.
    return "".join(
        text[int(segment.start_index) : int(segment.end_index)]
        for segment in layout.text_anchor.text_segments
    )


# Call the function and capture the results
process_document_ocr_sample(project_id, location, processor_id, processor_version, file_path, mime_type)
# Out:
# Full document text: ICICI Lombard
# Max Bupa
# Apoll
# Ihealth
# Heartbeat Gold
# Optin
# Basic sum insured
# 10 lacs
# 10 lacs
# Premium
# 10,643
# 22,696
# 1
# Hosptalization benefits
# Pre-existing diseases:
# Pre-existing diseases:
# Pre-existi
# 2 years
# 2 years
# }Specifi
# Specific illnesses/
# Specificillnesses/treatments: None
# 1 Waiting period
# treatments: 2 years
# treatme
# No restriction
# No restriction
# No re
# 2 Hospital accomodation
# /sub-limits
# /sub-limits
# /su
# 3 Pre-hospitalization
# 30 days
# 30 days
# 60
# 4 Post hospitalization
# 60 days after
# 60 days after
# 18
# Only in c
# accon
# Rs 800 per d
# 5 Hospital cash/Daily Cash
# No
# Not applicable
# of
# Actual cost at Network
# Rs. 1500 per
# hospital, Rs 2000 per
# Rs 2
# hospitalization
# hosptalization otherwise
# hospi
# Not covered
# Covered
# Cc
# 6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible
# Not applicable
# Not applicable
# Not a
# 140 day care procedures
# All day care procedures
# All day cal
# covered
# covered
# CO
# 9 Day care procedures10 Domicilliary hospitalization
# No
# Yes, upto Rs 50,000
# 11 Alternative treatments
# No
# No
# Maternity Benefits
# Waiting period of 24
# months. Expenses for 2
# deliveries,upto Rs 50000 per year
# Husband and wife to be
# Maternity benefits
# covered under the same
# 12 (delivery expenses)
# Waiting period of 36 months
# policy
# Automatic covered (withoutadditional charge) till the
# expiry of policy year inwhich the baby was born.
# Vaccination expenses
# PREVERSIONS
# CORSNES
# 13 | New born baby cover
# None
# covered
# Renewal benefits
# No
# No Claim:
# Bonus of 51
# Additional 10% sum insured
# Sum
# In cas
# accumulat
# at the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured
# re
# by 50% of
# 14 Renewal benefits
# in
# 15 Loading on claims
# NA
# ΝΑ
# 16 Health checkup
# Yes
# Yes (Annual)
# 17 Claim settlement record
# 96.9%
# 82.2%
# Source: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim
# months)
# lo Munich
# Tata AIG
# na Restore
# MediPrime
# Star Health Comprehensive
# .0 lacs
# 10 lacs
# 10 lacs
# 13,607
# 12,205
# 17,483
# ing diseases: 3
# Pre-existing diseases:
# Pre-existing diseases:
# years
# 4 years
# 4 yearsSpecific illnesses/
# ic illnesses/
# Specific illnesses/
# ents: 2 years
# treatments: 2 years
# treatments: 2 years
# estriction
# No restriction
# No restriction
# b-limits
# /sub-limits
# /sub-limits
# 60 days if informed of
# hospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days
# 6 days
# 15000
# per occurrence
# 2000 per
# Rs 2500 per
# Rs 3500 per
# italization
# hospitalization
# policy period
# overed
# Covered
# Not covered
# applicable
# Not applicable
# Not applicable140 day care procedures
# re procedures
# 101 day care
# >vered
# covered
# procedures covered
# Yes
# Yes
# No
# No
# Upto Rs 25000
# No
# Waiting period of 36
# months.
# Upto Rs 40000 per delivery
# None
# None
# for 2 deliveries
# Automatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.
# Vaccination expenses upto
# KRPERA
# BRESS
# None
# None
# Rs 1000 covered
# > claim:
# 0% of the Basic
# Insured
# No claim: Sum insured
# e of claim,
# enhanced by 10% (bonus)
# No claim: bonus sum
# ed bonus to be
# each year.
# insured at 100% of basic
# educed
# In case of claim: Cumulative
# sum insured.
# the basic sum
# bonus reduced by 10% of In case of claim: bonus sum
# sured.
# the basic sum insured
# insured becomes zero
# NA
# ΝΑ
# NA
# Once every four years
# Once every three
# No
# claim free years
# claim free years
# 79.0%
# 84.8%
# 69.0%
# settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six
# Group Name
# ABC Ltd
# Group Number
# Renewal Date
# No of employees enrolled
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# OON Deductible
# 100/0
# 2500/5000
# 123
# 01-01-2024
# 20
# Name
# 10-Day Green Smoothie Cleanse
# 11/22/63: A Novel
# 12 Rules for Life: An Antidote to Chaos
# 1984 (Signet Classics)
# Author
# JJ Smith
# Stephen King
# Jordan B. Peterson
# George Orwell
# 5,000 Awesome Facts (About Everything!) (National
# National
# Geographic Kids) Kids
# A Dance with Dragons (A Song of Ice and Fire) George R. R. Martin
# A Game of Thrones / A Clash of Kings / A Storm
# A Gentleman in Moscow: A Novel
# A Higher Loyalty: Truth, Lies, and Leadership
# A Man Called Ove: A Novel
# A Man Called Ove: A Novel
# of Swords / A Feast o
# Amor Towles
# James Comey
# Fredrik Backman
# Fredrik Backman
# A Patriot's History of the United States: From Columbus's Great D
# A Stolen Life: A Memoir
# A Wrinkle in Time (Time Quintet)
# Jaycee Dugard
# Act Like a Lady, Think Like a Man: What Men
# Madeleine L'Engle
# Really Think Abo
# User RatingReviews
# 4.7
# 17350
# 4.6
# 2052
# 4.7
# 18979
# 4.7
# 21424
# 4.8
# 7665
# 4.4
# 12643
# h Drs
# 19735
# 4.7
# 19699
# 4.7
# 5983
# 4.6
# 23848
# 4.6
# 23848
# rror4.6
# 460
# 4.6
# 4149
# 4.5
# 5153
# cy,
# 4.6
# omm
# 5013
# Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, M
# Adult Coloring Book: Stress Relieving Animal DesignsBlue
# Star Coloring
# Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring
# Adult Coloring Books: A Coloring Book for Adults
# Alexander Hamilton
# All the Light We Cannot See
# 4.5ls
# , a
# aisley
# 4.6
# 2925
# 4.4
# 2951
# Featuring Mandalas and
# Ron Chernow
# owe nimals
# 4.8
# 9198
# Anthony Doerr
# 4.6
# 36348
# All the Light We Cannot See
# Allegiant
# Anthony Doerr
# 4.6
# 36348
# Veronica Roth
# 3.9
# 6310
# American Sniper: The Autobiography of the Most Lethal SnChris Kyle
# 4.6
# 15921
# And the Mountains Echoed
# Khaled Hosseini
# 4.3
# 12159
# Arguing with Idiots: How to Stop Small Minds and Big GoverGlenn Beck
# 4.6
# 798
# Astrophysics for People in a Hurry
# Neil deGrasse Tyson
# 4.7
# 9374
# Autobiography of Mark Twain, Vol. 1
# Mark Twain
# 4.2
# 491
# Balance (Angie's Extreme Stress Menders)
# Baby Touch and Feel: Animals
# Barefoot Contessa Foolproof: Recipes You Can Trust: A CooIna Garten
# DK
# 4.6
# 5360
# Angie Grace
# 4.6
# 1909
# 4.8
# 1296
# Barefoot Contessa, How Easy Is That?: Fabulous Recipes &Ina Garten
# 4.7
# 615
# Becoming
# Michelle Obama
# 4.8
# 61133
# Becoming
# Michelle Obama
# 4.8
# 61133
# Being Mortal: Medicine and What Matters in the EndAtul
# Gawande
# 4.8
# 11113
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Born to Run
# Bruce Springsteen
# 4.7
# 3729
# Breaking Dawn (The Twilight Saga, Book 4)
# Broke: The Plan to Restore Our Trust, Truth and
# Brown Bear, Brown Bear, What Do You See?
# Brown Bear, Brown Bear, What Do You See?
# Cabin Fever (Diary of a Wimpy Kid, Book 6)
# Calm the F*ck Down: An Irreverent Adult Coloring Book (IrrevSasha O'Hara
# Can't Hurt Me: Master Your Mind and Defy the OddsDavid
# Goggins
# Stephenie Meyer
# 4.6
# 9769
# TreasureGlenn
# Beck
# 4.5
# 471
# Bill Martin Jr.
# 4.9
# 14344
# Bill Martin Jr.
# 4.9
# 14344
# Jeff Kinney
# 4.8
# 4505
# 4.6
# 10369
# 4.8
# 16244
# Price
# Year
# Genre
# 8
# 2016 Non Fiction
# 22
# 2011 Fiction
# 15
# 2018 Non Fiction
# 6
# 2017 Fiction
# 12
# 2019 Non Fiction
# 11
# 2011 Fiction
# 30
# 2014 Fiction
# 15
# 2017 Fiction
# 3
# 2018 Non Fiction
# 8
# 2016 Fiction
# 8
# 2017 Fiction
# 2
# 2010 Non Fiction
# 32
# 2011 Non Fiction
# 5
# 2018 Fiction
# 17
# 2009 Non Fiction
# 4
# 2016 Non Fiction
# 6
# 2015 Non Fiction
# 6
# 2015 Non Fiction
# 8
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 14
# 2014 Fiction
# 14
# 2015 Fiction
# 13
# 2013 Fiction
# 9
# 2015 Non Fiction
# 13
# 2013 Fiction
# 5
# 2009 Non Fiction
# 9
# 2017 Non Fiction
# 14
# 2010 Non Fiction
# 5
# 2015 Non Fiction
# 11
# 2015 Non Fiction
# 24
# 2012 Non Fiction
# 21
# 2010 Non Fiction
# 11
# 2018 Non Fiction
# 11
# 2019 Non Fiction
# 15
# 2015 Non Fiction
# 13
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 18
# 2016 Non Fiction
# 13
# 2009 Fiction
# 8
# 2010 Non Fiction
# 5
# 2017 Fiction
# 5
# 2019 Fiction
# 0
# 2011 Fiction
# 4
# 2016 Non Fiction
# 18
# 2019 Non Fiction
# ▬▬İ
# --
# K
# C:\Users\Shreshtha\Downloads\AmazonBooks.xlsx
# C:\Users\Shreshtha\Downloads\honeypr
# C:\Users\Shreshtha\Downloads\OrderDetails.csv
# &
# PDF
# C:\Users\Shreshtha\Downloads\Problem Statement
# Company Name- ABC Ltd.
# Source- Google
# ABC Ltd
# Group NameGroup Number
# 123
# Renewal Date
# 01-01-2024
# No of employees enrolled
# 20
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# 100/0
# OON Deductible
# 2500/5000
# Group Financial
# Please see Rate Model for a
# Plan Design:
# KACTOHP63RD
# In-Network
# Office Copay:
# PCP:
# No Charge after Deductible
# Specialist:
# No Charge after Deductible
# ER Copay:
# No Charge after Deductible
# Hospital Copay
# Inpatient:
# No Charge after Deductible
# Outpatient Freestanding:
# No Charge after Deductible
# Outpatient Hospital Setting:
# No Charge after Deductible
# Modified Cost Share
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# Coinsurance:
# None
# JOULU
# Single M.O.O.P.
# $4,000
# Family M.O.O.P.
# $8,000
# Financial Accumulation Period:
# Calendar Year
# Prescriptio
# Please see Rate Model for available plan combinations
# Information
# Link to PDML:
# http://pdml/
# vailable plan combinations
# Out-of-Network
# Modified UCR:Standard
# UCR:
# 100% of Medicare
# Modified Cost Share:
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# ПППП
# Coinsurance:
# 30%
# Ain
# Single M.O.O.P.
# $5,850
# Family M.O.O.P.
# $11,700
# on Plan
# Rx Tracking ID:
#
#
# There are 12 page(s) in this document.
#
# Page 1:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     88 blocks detected:
#         First text block: 'ICICI Lombard\n'
#         Last text block: 'CORSNES\n'
#     88 paragraphs detected:
#         First paragraph text: 'ICICI Lombard\n'
#         Last paragraph text: 'CORSNES\n'
#     88 lines detected:
#         First line text: 'ICICI Lombard\n'
#         Last line text: 'CORSNES\n'
#     254 tokens detected:
#         First token text: 'ICICI '
#         First token break type: 'SPACE'
#         Last token text: 'CORSNES\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     1175 symbols detected:
#         First symbol text: 'I'
#         Last symbol text: 'S'
#     Quality score: 89.5%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 66.6%
#         quality/defect_text_cutoff: 50.0%
#     3 checkboxes detected:
#         First checkbox: 'unfilled_checkbox'
#         Last checkbox: 'unfilled_checkbox'
# Page 2:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     27 blocks detected:
#         First text block: '13 | New born baby cover\n'
#         Last text block: 'months)\n'
#     27 paragraphs detected:
#         First paragraph text: '13 | New born baby cover\n'
#         Last paragraph text: 'months)\n'
#     27 lines detected:
#         First line text: '13 | New born baby cover\n'
#         Last line text: 'months)\n'
#     132 tokens detected:
#         First token text: '13 '
#         First token break type: 'SPACE'
#         Last token text: ')\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     528 symbols detected:
#         First symbol text: '1'
#         Last symbol text: ')'
#     Quality score: 92.7%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 68.1%
#         quality/defect_text_cutoff: 50.0%
# Page 3:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     66 blocks detected:
#         First text block: 'lo Munich\n'
#         Last text block: 'BRESS\n'
#     66 paragraphs detected:
#         First paragraph text: 'lo Munich\n'
#         Last paragraph text: 'BRESS\n'
#     66 lines detected:
#         First line text: 'lo Munich\n'
#         Last line text: 'BRESS\n'
#     241 tokens detected:
#         First token text: 'lo '
#         First token break type: 'SPACE'
#         Last token text: 'BRESS\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     1044 symbols detected:
#         First symbol text: 'l'
#         Last symbol text: 'S'
#     Quality score: 90.9%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 62.8%
#         quality/defect_text_cutoff: 50.0%
# Page 4:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     33 blocks detected:
#         First text block: 'None\n'
#         Last text block: 'settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six\n'
#     33 paragraphs detected:
#         First paragraph text: 'None\n'
#         Last paragraph text: 'settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six\n'
#     33 lines detected:
#         First line text: 'None\n'
#         Last line text: 'settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six\n'
#     124 tokens detected:
#         First token text: 'None\n'
#         First token break type: 'TYPE_UNSPECIFIED'
#         Last token text: 'six\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     443 symbols detected:
#         First symbol text: 'N'
#         Last symbol text: 'x'
#     Quality score: 91.4%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 66.6%
#         quality/defect_text_cutoff: 50.0%
# Page 5:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     21 blocks detected:
#         First text block: 'Group Name\n'
#         Last text block: '20\n'
#     21 paragraphs detected:
#         First paragraph text: 'Group Name\n'
#         Last paragraph text: '20\n'
#     24 lines detected:
#         First line text: 'Group Name\n'
#         Last line text: '20\n'
#     49 tokens detected:
#         First token text: 'Group '
#         First token break type: 'SPACE'
#         Last token text: '20\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     220 symbols detected:
#         First symbol text: 'G'
#         Last symbol text: '0'
#     Quality score: 95.1%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 70.1%
#         quality/defect_text_cutoff: 50.0%
#     1 checkboxes detected:
#         First checkbox: 'unfilled_checkbox'
#         Last checkbox: 'unfilled_checkbox'
# Page 6:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     141 blocks detected:
#         First text block: 'Name\n'
#         Last text block: '16244\n'
#     141 paragraphs detected:
#         First paragraph text: 'Name\n'
#         Last paragraph text: '16244\n'
#     178 lines detected:
#         First line text: 'Name\n'
#         Last line text: '16244\n'
#     569 tokens detected:
#         First token text: 'Name\n'
#         First token break type: 'TYPE_UNSPECIFIED'
#         Last token text: '16244\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     2346 symbols detected:
#         First symbol text: 'N'
#         Last symbol text: '4'
#     Quality score: 96.2%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 60.7%
#         quality/defect_text_cutoff: 50.0%
# Page 7:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     93 blocks detected:
#         First text block: 'Price\n'
#         Last text block: '2019 Non Fiction\n'
#     93 paragraphs detected:
#         First paragraph text: 'Price\n'
#         Last paragraph text: '2019 Non Fiction\n'
#     93 lines detected:
#         First line text: 'Price\n'
#         Last line text: '2019 Non Fiction\n'
#     167 tokens detected:
#         First token text: 'Price\n'
#         First token break type: 'TYPE_UNSPECIFIED'
#         Last token text: 'Fiction\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     666 symbols detected:
#         First symbol text: 'P'
#         Last symbol text: 'n'
#     Quality score: 96.0%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 64.7%
#         quality/defect_text_cutoff: 50.0%
#     1 checkboxes detected:
#         First checkbox: 'unfilled_checkbox'
#         Last checkbox: 'unfilled_checkbox'
# Page 8:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     6 blocks detected:
#         First text block: '▬▬İ\n'
#         Last text block: 'C:\\Users\\Shreshtha\\Downloads\\OrderDetails.csv\n'
#     6 paragraphs detected:
#         First paragraph text: '▬▬İ\n'
#         Last paragraph text: 'C:\\Users\\Shreshtha\\Downloads\\OrderDetails.csv\n'
#     6 lines detected:
#         First line text: '▬▬İ\n'
#         Last line text: 'C:\\Users\\Shreshtha\\Downloads\\OrderDetails.csv\n'
#     34 tokens detected:
#         First token text: '▬▬İ\n'
#         First token break type: 'TYPE_UNSPECIFIED'
#         Last token text: 'Details.csv\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     132 symbols detected:
#         First symbol text: '▬'
#         Last symbol text: 'v'
#     Quality score: 0.7%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 69.0%
#         quality/defect_text_cutoff: 50.0%
#         quality/defect_noisy: 21.9%
#         quality/defect_faint: 14.7%
#         quality/defect_text_too_small: 7.2%
#         quality/defect_blurry: 4.6%
#         quality/defect_dark: 0.3%
#     1 checkboxes detected:
#         First checkbox: 'filled_checkbox'
#         Last checkbox: 'filled_checkbox'
# Page 9:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     3 blocks detected:
#         First text block: '&\n'
#         Last text block: 'C:\\Users\\Shreshtha\\Downloads\\Problem Statement\n'
#     3 paragraphs detected:
#         First paragraph text: '&\n'
#         Last paragraph text: 'C:\\Users\\Shreshtha\\Downloads\\Problem Statement\n'
#     3 lines detected:
#         First line text: '&\n'
#         Last line text: 'C:\\Users\\Shreshtha\\Downloads\\Problem Statement\n'
#     13 tokens detected:
#         First token text: '&\n'
#         First token break type: 'TYPE_UNSPECIFIED'
#         Last token text: 'Statement\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     49 symbols detected:
#         First symbol text: '&'
#         Last symbol text: 't'
#     Quality score: 2.1%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 68.3%
#         quality/defect_text_cutoff: 50.0%
#         quality/defect_noisy: 27.1%
#         quality/defect_faint: 19.3%
#         quality/defect_text_too_small: 7.8%
#         quality/defect_blurry: 3.7%
#         quality/defect_dark: 0.2%
# Page 10:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     24 blocks detected:
#         First text block: 'Company Name- ABC Ltd.\nSource- Google\n'
#         Last text block: '2500/5000\n'
#     24 paragraphs detected:
#         First paragraph text: 'Company Name- ABC Ltd.\nSource- Google\n'
#         Last paragraph text: '2500/5000\n'
#     25 lines detected:
#         First line text: 'Company Name- ABC Ltd.\n'
#         Last line text: '2500/5000\n'
#     55 tokens detected:
#         First token text: 'Company '
#         First token break type: 'SPACE'
#         Last token text: '2500/5000\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     252 symbols detected:
#         First symbol text: 'C'
#         Last symbol text: '0'
#     Quality score: 93.2%
#     Detected defects:
#         quality/defect_document_cutoff: 100.0%
#         quality/defect_glare: 66.0%
#         quality/defect_text_cutoff: 50.0%
# Page 11:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     35 blocks detected:
#         First text block: 'Group Financial\n'
#         Last text block: 'Please see Rate Model for available plan combinations\n'
#     35 paragraphs detected:
#         First paragraph text: 'Group Financial\n'
#         Last paragraph text: 'Please see Rate Model for available plan combinations\n'
#     35 lines detected:
#         First line text: 'Group Financial\n'
#         Last line text: 'Please see Rate Model for available plan combinations\n'
#     100 tokens detected:
#         First token text: 'Group '
#         First token break type: 'SPACE'
#         Last token text: 'combinations\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     534 symbols detected:
#         First symbol text: 'G'
#         Last symbol text: 's'
#     Quality score: 93.9%
#     Detected defects:
#         quality/defect_glare: 50.2%
#         quality/defect_document_cutoff: 0.0%
# Page 12:
#     Width: 1758.0
#     Height: 2275.0
#     Detected languages:
#     23 blocks detected:
#         First text block: 'Information\n'
#         Last text block: 'Rx Tracking ID:\n'
#     23 paragraphs detected:
#         First paragraph text: 'Information\n'
#         Last paragraph text: 'Rx Tracking ID:\n'
#     23 lines detected:
#         First line text: 'Information\n'
#         Last line text: 'Rx Tracking ID:\n'
#     62 tokens detected:
#         First token text: 'Information\n'
#         First token break type: 'TYPE_UNSPECIFIED'
#         Last token text: ':\n'
#         Last token break type: 'TYPE_UNSPECIFIED'
#     256 symbols detected:
#         First symbol text: 'I'
#         Last symbol text: ':'
#     Quality score: 79.0%
#     Detected defects:
#         quality/defect_glare: 55.2%
#         quality/defect_document_cutoff: 0.0%
#     5 checkboxes detected:
#         First checkbox: 'unfilled_checkbox'
#         Last checkbox: 'unfilled_checkbox'

# %%
from typing import Optional, Sequence
from google.api_core.client_options import ClientOptions
from google.cloud import documentai

# Replace the placeholder values with your actual project and processor information
project_id = 'balmy-outcome-412805'
location = "us"  # Format is "us" or "eu"
processor_id = '1c327dd87f42b98b'  # Create processor before running sample
processor_version = "rc"  # Refer to https://cloud.google.com/document-ai/docs/manage-processor-versions for more information
file_path = "C:/Users/Shreshtha/Downloads/4F82B400.pdf"
mime_type = "application/pdf"  # Refer to https://cloud.google.com/document-ai/docs/file-types for supported file types

def process_document_ocr_sample(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
) -> None:
    # Optional: Additional configurations for Document OCR Processor.
    # For more information: https://cloud.google.com/document-ai/docs/enterprise-document-ocr
    process_options = documentai.ProcessOptions(
        ocr_config=documentai.OcrConfig(
            enable_native_pdf_parsing=True,
            enable_image_quality_scores=True,
            enable_symbol=True,
            # Comment out the premium_features section to disable premium OCR features
            # premium_features=documentai.OcrConfig.PremiumFeatures(
            #     compute_style_info=True,
            #     enable_math_ocr=False,  # Enable to use Math OCR Model
            #     enable_selection_mark_detection=True,
            # ),
        )
    )
    # Online processing request to Document AI
    document = process_document(
        project_id,
        location,
        processor_id,
        processor_version,
        file_path,
        mime_type,
        process_options=process_options,
    )

    text = document.text
    print(f"Full document text: {text}\n")
    print(f"There are {len(document.pages)} page(s) in this document.\n")

    for page in document.pages:
        print(f"Page {page.page_number} text:")
        print(layout_to_text(page.layout, text))


def process_document(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
    process_options: Optional[documentai.ProcessOptions] = None,
) -> documentai.Document:
    # You must set the `api_endpoint` if you use a location other than "us".
    client = documentai.DocumentProcessorServiceClient(
        client_options=ClientOptions(
            api_endpoint=f"{location}-documentai.googleapis.com"
        )
    )

    # The full resource name of the processor version, e.g.:
    # `projects/{project_id}/locations/{location}/processors/{processor_id}/processorVersions/{processor_version_id}`
    # You must create a processor before running this sample.
    name = client.processor_version_path(
        project_id, location, processor_id, processor_version
    )

    # Read the file into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    # Configure the process request
    request = documentai.ProcessRequest(
        name=name,
        raw_document=documentai.RawDocument(content=image_content, mime_type=mime_type),
        # Only supported for Document OCR processor
        process_options=process_options,
    )

    result = client.process_document(request=request)

    # For a full list of `Document` object attributes, reference this page:
    # https://cloud.google.com/document-ai/docs/reference/rest/v1/Document
    return result.document


def layout_to_text(layout: documentai.Document.Page.Layout, text: str) -> str:
    """
    Document AI identifies text in different parts of the document by their
    offsets in the entirety of the document"s text. This function converts
    offsets to a string.
    """
    # If a text segment spans several lines, it will
    # be stored in different text segments.
    return "".join(
        text[int(segment.start_index) : int(segment.end_index)]
        for segment in layout.text_anchor.text_segments
    )


# Call the function and capture the results
process_document_ocr_sample(project_id, location, processor_id, processor_version, file_path, mime_type)
# Out:
# Full document text: ICICI Lombard
# Max Bupa
# Apoll
# Ihealth
# Heartbeat Gold
# Optin
# Basic sum insured
# 10 lacs
# 10 lacs
# Premium
# 10,643
# 22,696
# 1
# Hosptalization benefits
# Pre-existing diseases:
# Pre-existing diseases:
# Pre-existi
# 2 years
# 2 years
# }Specifi
# Specific illnesses/
# Specificillnesses/treatments: None
# 1 Waiting period
# treatments: 2 years
# treatme
# No restriction
# No restriction
# No re
# 2 Hospital accomodation
# /sub-limits
# /sub-limits
# /su
# 3 Pre-hospitalization
# 30 days
# 30 days
# 60
# 4 Post hospitalization
# 60 days after
# 60 days after
# 18
# Only in c
# accon
# Rs 800 per d
# 5 Hospital cash/Daily Cash
# No
# Not applicable
# of
# Actual cost at Network
# Rs. 1500 per
# hospital, Rs 2000 per
# Rs 2
# hospitalization
# hosptalization otherwise
# hospi
# Not covered
# Covered
# Cc
# 6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible
# Not applicable
# Not applicable
# Not a
# 140 day care procedures
# All day care procedures
# All day cal
# covered
# covered
# CO
# 9 Day care procedures10 Domicilliary hospitalization
# No
# Yes, upto Rs 50,000
# 11 Alternative treatments
# No
# No
# Maternity Benefits
# Waiting period of 24
# months. Expenses for 2
# deliveries,upto Rs 50000 per year
# Husband and wife to be
# Maternity benefits
# covered under the same
# 12 (delivery expenses)
# Waiting period of 36 months
# policy
# Automatic covered (withoutadditional charge) till the
# expiry of policy year inwhich the baby was born.
# Vaccination expenses
# PREVERSIONS
# CORSNES
# 13 | New born baby cover
# None
# covered
# Renewal benefits
# No
# No Claim:
# Bonus of 51
# Additional 10% sum insured
# Sum
# In cas
# accumulat
# at the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured
# re
# by 50% of
# 14 Renewal benefits
# in
# 15 Loading on claims
# NA
# ΝΑ
# 16 Health checkup
# Yes
# Yes (Annual)
# 17 Claim settlement record
# 96.9%
# 82.2%
# Source: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim
# months)
# lo Munich
# Tata AIG
# na Restore
# MediPrime
# Star Health Comprehensive
# .0 lacs
# 10 lacs
# 10 lacs
# 13,607
# 12,205
# 17,483
# ing diseases: 3
# Pre-existing diseases:
# Pre-existing diseases:
# years
# 4 years
# 4 yearsSpecific illnesses/
# ic illnesses/
# Specific illnesses/
# ents: 2 years
# treatments: 2 years
# treatments: 2 years
# estriction
# No restriction
# No restriction
# b-limits
# /sub-limits
# /sub-limits
# 60 days if informed of
# hospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days
# 6 days
# 15000
# per occurrence
# 2000 per
# Rs 2500 per
# Rs 3500 per
# italization
# hospitalization
# policy period
# overed
# Covered
# Not covered
# applicable
# Not applicable
# Not applicable140 day care procedures
# re procedures
# 101 day care
# >vered
# covered
# procedures covered
# Yes
# Yes
# No
# No
# Upto Rs 25000
# No
# Waiting period of 36
# months.
# Upto Rs 40000 per delivery
# None
# None
# for 2 deliveries
# Automatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.
# Vaccination expenses upto
# KRPERA
# BRESS
# None
# None
# Rs 1000 covered
# > claim:
# 0% of the Basic
# Insured
# No claim: Sum insured
# e of claim,
# enhanced by 10% (bonus)
# No claim: bonus sum
# ed bonus to be
# each year.
# insured at 100% of basic
# educed
# In case of claim: Cumulative
# sum insured.
# the basic sum
# bonus reduced by 10% of In case of claim: bonus sum
# sured.
# the basic sum insured
# insured becomes zero
# NA
# ΝΑ
# NA
# Once every four years
# Once every three
# No
# claim free years
# claim free years
# 79.0%
# 84.8%
# 69.0%
# settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six
# Group Name
# ABC Ltd
# Group Number
# Renewal Date
# No of employees enrolled
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# OON Deductible
# 100/0
# 2500/5000
# 123
# 01-01-2024
# 20
# Name
# 10-Day Green Smoothie Cleanse
# 11/22/63: A Novel
# 12 Rules for Life: An Antidote to Chaos
# 1984 (Signet Classics)
# Author
# JJ Smith
# Stephen King
# Jordan B. Peterson
# George Orwell
# 5,000 Awesome Facts (About Everything!) (National
# National
# Geographic Kids) Kids
# A Dance with Dragons (A Song of Ice and Fire) George R. R. Martin
# A Game of Thrones / A Clash of Kings / A Storm
# A Gentleman in Moscow: A Novel
# A Higher Loyalty: Truth, Lies, and Leadership
# A Man Called Ove: A Novel
# A Man Called Ove: A Novel
# of Swords / A Feast o
# Amor Towles
# James Comey
# Fredrik Backman
# Fredrik Backman
# A Patriot's History of the United States: From Columbus's Great D
# A Stolen Life: A Memoir
# A Wrinkle in Time (Time Quintet)
# Jaycee Dugard
# Act Like a Lady, Think Like a Man: What Men
# Madeleine L'Engle
# Really Think Abo
# User RatingReviews
# 4.7
# 17350
# 4.6
# 2052
# 4.7
# 18979
# 4.7
# 21424
# 4.8
# 7665
# 4.4
# 12643
# h Drs
# 19735
# 4.7
# 19699
# 4.7
# 5983
# 4.6
# 23848
# 4.6
# 23848
# rror4.6
# 460
# 4.6
# 4149
# 4.5
# 5153
# cy,
# 4.6
# omm
# 5013
# Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, M
# Adult Coloring Book: Stress Relieving Animal DesignsBlue
# Star Coloring
# Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring
# Adult Coloring Books: A Coloring Book for Adults
# Alexander Hamilton
# All the Light We Cannot See
# 4.5ls
# , a
# aisley
# 4.6
# 2925
# 4.4
# 2951
# Featuring Mandalas and
# Ron Chernow
# owe nimals
# 4.8
# 9198
# Anthony Doerr
# 4.6
# 36348
# All the Light We Cannot See
# Allegiant
# Anthony Doerr
# 4.6
# 36348
# Veronica Roth
# 3.9
# 6310
# American Sniper: The Autobiography of the Most Lethal SnChris Kyle
# 4.6
# 15921
# And the Mountains Echoed
# Khaled Hosseini
# 4.3
# 12159
# Arguing with Idiots: How to Stop Small Minds and Big GoverGlenn Beck
# 4.6
# 798
# Astrophysics for People in a Hurry
# Neil deGrasse Tyson
# 4.7
# 9374
# Autobiography of Mark Twain, Vol. 1
# Mark Twain
# 4.2
# 491
# Balance (Angie's Extreme Stress Menders)
# Baby Touch and Feel: Animals
# Barefoot Contessa Foolproof: Recipes You Can Trust: A CooIna Garten
# DK
# 4.6
# 5360
# Angie Grace
# 4.6
# 1909
# 4.8
# 1296
# Barefoot Contessa, How Easy Is That?: Fabulous Recipes &Ina Garten
# 4.7
# 615
# Becoming
# Michelle Obama
# 4.8
# 61133
# Becoming
# Michelle Obama
# 4.8
# 61133
# Being Mortal: Medicine and What Matters in the EndAtul
# Gawande
# 4.8
# 11113
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Born to Run
# Bruce Springsteen
# 4.7
# 3729
# Breaking Dawn (The Twilight Saga, Book 4)
# Broke: The Plan to Restore Our Trust, Truth and
# Brown Bear, Brown Bear, What Do You See?
# Brown Bear, Brown Bear, What Do You See?
# Cabin Fever (Diary of a Wimpy Kid, Book 6)
# Calm the F*ck Down: An Irreverent Adult Coloring Book (IrrevSasha O'Hara
# Can't Hurt Me: Master Your Mind and Defy the OddsDavid
# Goggins
# Stephenie Meyer
# 4.6
# 9769
# TreasureGlenn
# Beck
# 4.5
# 471
# Bill Martin Jr.
# 4.9
# 14344
# Bill Martin Jr.
# 4.9
# 14344
# Jeff Kinney
# 4.8
# 4505
# 4.6
# 10369
# 4.8
# 16244
# Price
# Year
# Genre
# 8
# 2016 Non Fiction
# 22
# 2011 Fiction
# 15
# 2018 Non Fiction
# 6
# 2017 Fiction
# 12
# 2019 Non Fiction
# 11
# 2011 Fiction
# 30
# 2014 Fiction
# 15
# 2017 Fiction
# 3
# 2018 Non Fiction
# 8
# 2016 Fiction
# 8
# 2017 Fiction
# 2
# 2010 Non Fiction
# 32
# 2011 Non Fiction
# 5
# 2018 Fiction
# 17
# 2009 Non Fiction
# 4
# 2016 Non Fiction
# 6
# 2015 Non Fiction
# 6
# 2015 Non Fiction
# 8
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 14
# 2014 Fiction
# 14
# 2015 Fiction
# 13
# 2013 Fiction
# 9
# 2015 Non Fiction
# 13
# 2013 Fiction
# 5
# 2009 Non Fiction
# 9
# 2017 Non Fiction
# 14
# 2010 Non Fiction
# 5
# 2015 Non Fiction
# 11
# 2015 Non Fiction
# 24
# 2012 Non Fiction
# 21
# 2010 Non Fiction
# 11
# 2018 Non Fiction
# 11
# 2019 Non Fiction
# 15
# 2015 Non Fiction
# 13
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 18
# 2016 Non Fiction
# 13
# 2009 Fiction
# 8
# 2010 Non Fiction
# 5
# 2017 Fiction
# 5
# 2019 Fiction
# 0
# 2011 Fiction
# 4
# 2016 Non Fiction
# 18
# 2019 Non Fiction
# ▬▬İ
# --
# K
# C:\Users\Shreshtha\Downloads\AmazonBooks.xlsx
# C:\Users\Shreshtha\Downloads\honeypr
# C:\Users\Shreshtha\Downloads\OrderDetails.csv
# &
# PDF
# C:\Users\Shreshtha\Downloads\Problem Statement
# Company Name- ABC Ltd.
# Source- Google
# ABC Ltd
# Group NameGroup Number
# 123
# Renewal Date
# 01-01-2024
# No of employees enrolled
# 20
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# 100/0
# OON Deductible
# 2500/5000
# Group Financial
# Please see Rate Model for a
# Plan Design:
# KACTOHP63RD
# In-Network
# Office Copay:
# PCP:
# No Charge after Deductible
# Specialist:
# No Charge after Deductible
# ER Copay:
# No Charge after Deductible
# Hospital Copay
# Inpatient:
# No Charge after Deductible
# Outpatient Freestanding:
# No Charge after Deductible
# Outpatient Hospital Setting:
# No Charge after Deductible
# Modified Cost Share
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# Coinsurance:
# None
# JOULU
# Single M.O.O.P.
# $4,000
# Family M.O.O.P.
# $8,000
# Financial Accumulation Period:
# Calendar Year
# Prescriptio
# Please see Rate Model for available plan combinations
# Information
# Link to PDML:
# http://pdml/
# vailable plan combinations
# Out-of-Network
# Modified UCR:Standard
# UCR:
# 100% of Medicare
# Modified Cost Share:
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# ПППП
# Coinsurance:
# 30%
# Ain
# Single M.O.O.P.
# $5,850
# Family M.O.O.P.
# $11,700
# on Plan
# Rx Tracking ID:
#
#
# There are 12 page(s) in this document.
#
# Page 1 text:
# ICICI Lombard
# Max Bupa
# Apoll
# Ihealth
# Heartbeat Gold
# Optin
# Basic sum insured
# 10 lacs
# 10 lacs
# Premium
# 10,643
# 22,696
# 1
# Hosptalization benefits
# Pre-existing diseases:
# Pre-existing diseases:
# Pre-existi
# 2 years
# 2 years
# }Specifi
# Specific illnesses/
# Specificillnesses/treatments: None
# 1 Waiting period
# treatments: 2 years
# treatme
# No restriction
# No restriction
# No re
# 2 Hospital accomodation
# /sub-limits
# /sub-limits
# /su
# 3 Pre-hospitalization
# 30 days
# 30 days
# 60
# 4 Post hospitalization
# 60 days after
# 60 days after
# 18
# Only in c
# accon
# Rs 800 per d
# 5 Hospital cash/Daily Cash
# No
# Not applicable
# of
# Actual cost at Network
# Rs. 1500 per
# hospital, Rs 2000 per
# Rs 2
# hospitalization
# hosptalization otherwise
# hospi
# Not covered
# Covered
# Cc
# 6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible
# Not applicable
# Not applicable
# Not a
# 140 day care procedures
# All day care procedures
# All day cal
# covered
# covered
# CO
# 9 Day care procedures10 Domicilliary hospitalization
# No
# Yes, upto Rs 50,000
# 11 Alternative treatments
# No
# No
# Maternity Benefits
# Waiting period of 24
# months. Expenses for 2
# deliveries,upto Rs 50000 per year
# Husband and wife to be
# Maternity benefits
# covered under the same
# 12 (delivery expenses)
# Waiting period of 36 months
# policy
# Automatic covered (withoutadditional charge) till the
# expiry of policy year inwhich the baby was born.
# Vaccination expenses
# PREVERSIONS
# CORSNES
#
# Page 2 text:
# 13 | New born baby cover
# None
# covered
# Renewal benefits
# No
# No Claim:
# Bonus of 51
# Additional 10% sum insured
# Sum
# In cas
# accumulat
# at the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured
# re
# by 50% of
# 14 Renewal benefits
# in
# 15 Loading on claims
# NA
# ΝΑ
# 16 Health checkup
# Yes
# Yes (Annual)
# 17 Claim settlement record
# 96.9%
# 82.2%
# Source: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim
# months)
#
# Page 3 text:
# lo Munich
# Tata AIG
# na Restore
# MediPrime
# Star Health Comprehensive
# .0 lacs
# 10 lacs
# 10 lacs
# 13,607
# 12,205
# 17,483
# ing diseases: 3
# Pre-existing diseases:
# Pre-existing diseases:
# years
# 4 years
# 4 yearsSpecific illnesses/
# ic illnesses/
# Specific illnesses/
# ents: 2 years
# treatments: 2 years
# treatments: 2 years
# estriction
# No restriction
# No restriction
# b-limits
# /sub-limits
# /sub-limits
# 60 days if informed of
# hospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days
# 6 days
# 15000
# per occurrence
# 2000 per
# Rs 2500 per
# Rs 3500 per
# italization
# hospitalization
# policy period
# overed
# Covered
# Not covered
# applicable
# Not applicable
# Not applicable140 day care procedures
# re procedures
# 101 day care
# >vered
# covered
# procedures covered
# Yes
# Yes
# No
# No
# Upto Rs 25000
# No
# Waiting period of 36
# months.
# Upto Rs 40000 per delivery
# None
# None
# for 2 deliveries
# Automatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.
# Vaccination expenses upto
# KRPERA
# BRESS
#
# Page 4 text:
# None
# None
# Rs 1000 covered
# > claim:
# 0% of the Basic
# Insured
# No claim: Sum insured
# e of claim,
# enhanced by 10% (bonus)
# No claim: bonus sum
# ed bonus to be
# each year.
# insured at 100% of basic
# educed
# In case of claim: Cumulative
# sum insured.
# the basic sum
# bonus reduced by 10% of In case of claim: bonus sum
# sured.
# the basic sum insured
# insured becomes zero
# NA
# ΝΑ
# NA
# Once every four years
# Once every three
# No
# claim free years
# claim free years
# 79.0%
# 84.8%
# 69.0%
# settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six
#
# Page 5 text:
# Group Name
# ABC Ltd
# Group Number
# Renewal Date
# No of employees enrolled
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# OON Deductible
# 100/0
# 2500/5000
# 123
# 01-01-2024
# 20
#
# Page 6 text:
# Name
# 10-Day Green Smoothie Cleanse
# 11/22/63: A Novel
# 12 Rules for Life: An Antidote to Chaos
# 1984 (Signet Classics)
# Author
# JJ Smith
# Stephen King
# Jordan B. Peterson
# George Orwell
# 5,000 Awesome Facts (About Everything!) (National
# National
# Geographic Kids) Kids
# A Dance with Dragons (A Song of Ice and Fire) George R. R. Martin
# A Game of Thrones / A Clash of Kings / A Storm
# A Gentleman in Moscow: A Novel
# A Higher Loyalty: Truth, Lies, and Leadership
# A Man Called Ove: A Novel
# A Man Called Ove: A Novel
# of Swords / A Feast o
# Amor Towles
# James Comey
# Fredrik Backman
# Fredrik Backman
# A Patriot's History of the United States: From Columbus's Great D
# A Stolen Life: A Memoir
# A Wrinkle in Time (Time Quintet)
# Jaycee Dugard
# Act Like a Lady, Think Like a Man: What Men
# Madeleine L'Engle
# Really Think Abo
# User RatingReviews
# 4.7
# 17350
# 4.6
# 2052
# 4.7
# 18979
# 4.7
# 21424
# 4.8
# 7665
# 4.4
# 12643
# h Drs
# 19735
# 4.7
# 19699
# 4.7
# 5983
# 4.6
# 23848
# 4.6
# 23848
# rror4.6
# 460
# 4.6
# 4149
# 4.5
# 5153
# cy,
# 4.6
# omm
# 5013
# Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, M
# Adult Coloring Book: Stress Relieving Animal DesignsBlue
# Star Coloring
# Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring
# Adult Coloring Books: A Coloring Book for Adults
# Alexander Hamilton
# All the Light We Cannot See
# 4.5ls
# , a
# aisley
# 4.6
# 2925
# 4.4
# 2951
# Featuring Mandalas and
# Ron Chernow
# owe nimals
# 4.8
# 9198
# Anthony Doerr
# 4.6
# 36348
# All the Light We Cannot See
# Allegiant
# Anthony Doerr
# 4.6
# 36348
# Veronica Roth
# 3.9
# 6310
# American Sniper: The Autobiography of the Most Lethal SnChris Kyle
# 4.6
# 15921
# And the Mountains Echoed
# Khaled Hosseini
# 4.3
# 12159
# Arguing with Idiots: How to Stop Small Minds and Big GoverGlenn Beck
# 4.6
# 798
# Astrophysics for People in a Hurry
# Neil deGrasse Tyson
# 4.7
# 9374
# Autobiography of Mark Twain, Vol. 1
# Mark Twain
# 4.2
# 491
# Balance (Angie's Extreme Stress Menders)
# Baby Touch and Feel: Animals
# Barefoot Contessa Foolproof: Recipes You Can Trust: A CooIna Garten
# DK
# 4.6
# 5360
# Angie Grace
# 4.6
# 1909
# 4.8
# 1296
# Barefoot Contessa, How Easy Is That?: Fabulous Recipes &Ina Garten
# 4.7
# 615
# Becoming
# Michelle Obama
# 4.8
# 61133
# Becoming
# Michelle Obama
# 4.8
# 61133
# Being Mortal: Medicine and What Matters in the EndAtul
# Gawande
# 4.8
# 11113
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Born to Run
# Bruce Springsteen
# 4.7
# 3729
# Breaking Dawn (The Twilight Saga, Book 4)
# Broke: The Plan to Restore Our Trust, Truth and
# Brown Bear, Brown Bear, What Do You See?
# Brown Bear, Brown Bear, What Do You See?
# Cabin Fever (Diary of a Wimpy Kid, Book 6)
# Calm the F*ck Down: An Irreverent Adult Coloring Book (IrrevSasha O'Hara
# Can't Hurt Me: Master Your Mind and Defy the OddsDavid
# Goggins
# Stephenie Meyer
# 4.6
# 9769
# TreasureGlenn
# Beck
# 4.5
# 471
# Bill Martin Jr.
# 4.9
# 14344
# Bill Martin Jr.
# 4.9
# 14344
# Jeff Kinney
# 4.8
# 4505
# 4.6
# 10369
# 4.8
# 16244
#
# Page 7 text:
# Price
# Year
# Genre
# 8
# 2016 Non Fiction
# 22
# 2011 Fiction
# 15
# 2018 Non Fiction
# 6
# 2017 Fiction
# 12
# 2019 Non Fiction
# 11
# 2011 Fiction
# 30
# 2014 Fiction
# 15
# 2017 Fiction
# 3
# 2018 Non Fiction
# 8
# 2016 Fiction
# 8
# 2017 Fiction
# 2
# 2010 Non Fiction
# 32
# 2011 Non Fiction
# 5
# 2018 Fiction
# 17
# 2009 Non Fiction
# 4
# 2016 Non Fiction
# 6
# 2015 Non Fiction
# 6
# 2015 Non Fiction
# 8
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 14
# 2014 Fiction
# 14
# 2015 Fiction
# 13
# 2013 Fiction
# 9
# 2015 Non Fiction
# 13
# 2013 Fiction
# 5
# 2009 Non Fiction
# 9
# 2017 Non Fiction
# 14
# 2010 Non Fiction
# 5
# 2015 Non Fiction
# 11
# 2015 Non Fiction
# 24
# 2012 Non Fiction
# 21
# 2010 Non Fiction
# 11
# 2018 Non Fiction
# 11
# 2019 Non Fiction
# 15
# 2015 Non Fiction
# 13
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 18
# 2016 Non Fiction
# 13
# 2009 Fiction
# 8
# 2010 Non Fiction
# 5
# 2017 Fiction
# 5
# 2019 Fiction
# 0
# 2011 Fiction
# 4
# 2016 Non Fiction
# 18
# 2019 Non Fiction
#
# Page 8 text:
# ▬▬İ
# --
# K
# C:\Users\Shreshtha\Downloads\AmazonBooks.xlsx
# C:\Users\Shreshtha\Downloads\honeypr
# C:\Users\Shreshtha\Downloads\OrderDetails.csv
#
# Page 9 text:
# &
# PDF
# C:\Users\Shreshtha\Downloads\Problem Statement
#
# Page 10 text:
# Company Name- ABC Ltd.
# Source- Google
# ABC Ltd
# Group NameGroup Number
# 123
# Renewal Date
# 01-01-2024
# No of employees enrolled
# 20
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# 100/0
# OON Deductible
# 2500/5000
#
# Page 11 text:
# Group Financial
# Please see Rate Model for a
# Plan Design:
# KACTOHP63RD
# In-Network
# Office Copay:
# PCP:
# No Charge after Deductible
# Specialist:
# No Charge after Deductible
# ER Copay:
# No Charge after Deductible
# Hospital Copay
# Inpatient:
# No Charge after Deductible
# Outpatient Freestanding:
# No Charge after Deductible
# Outpatient Hospital Setting:
# No Charge after Deductible
# Modified Cost Share
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# Coinsurance:
# None
# JOULU
# Single M.O.O.P.
# $4,000
# Family M.O.O.P.
# $8,000
# Financial Accumulation Period:
# Calendar Year
# Prescriptio
# Please see Rate Model for available plan combinations
#
# Page 12 text:
# Information
# Link to PDML:
# http://pdml/
# vailable plan combinations
# Out-of-Network
# Modified UCR:Standard
# UCR:
# 100% of Medicare
# Modified Cost Share:
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# ПППП
# Coinsurance:
# 30%
# Ain
# Single M.O.O.P.
# $5,850
# Family M.O.O.P.
# $11,700
# on Plan
# Rx Tracking ID:

# %%
from typing import Optional, Sequence
from google.api_core.client_options import ClientOptions
from google.cloud import documentai

# Replace the placeholder values with your actual project and processor information
project_id = 'balmy-outcome-412805'
location = "us"  # Format is "us" or "eu"
processor_id = '1c327dd87f42b98b'  # Create processor before running sample
processor_version = "rc"  # Refer to https://cloud.google.com/document-ai/docs/manage-processor-versions for more information
file_path = "C:/Users/Shreshtha/Downloads/4F82B400.pdf"
mime_type = "application/pdf"  # Refer to https://cloud.google.com/document-ai/docs/file-types for supported file types

def process_document_ocr_sample(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
) -> None:
    # Optional: Additional configurations for Document OCR Processor.
    # For more information: https://cloud.google.com/document-ai/docs/enterprise-document-ocr
    process_options = documentai.ProcessOptions(
        ocr_config=documentai.OcrConfig(
            enable_native_pdf_parsing=True,
            enable_image_quality_scores=True,
            enable_symbol=True,
            # Comment out the premium_features section to disable premium OCR features
            # premium_features=documentai.OcrConfig.PremiumFeatures(
            #     compute_style_info=True,
            #     enable_math_ocr=False,  # Enable to use Math OCR Model
            #     enable_selection_mark_detection=True,
            # ),
        )
    )
    # Online processing request to Document AI
    document = process_document(
        project_id,
        location,
        processor_id,
        processor_version,
        file_path,
        mime_type,
        process_options=process_options,
    )

    text = document.text
    print(f"Full document text: {text}\n")
    print(f"There are {len(document.pages)} page(s) in this document.\n")

    for page_num, page in enumerate(document.pages, start=1):
        print(f"Page {page_num} text:")
        print(layout_to_text(page.layout, text))
        print("\n" + "="*50 + "\n")  # Adding a separator for better visibility


def process_document(
    project_id: str,
    location: str,
    processor_id: str,
    processor_version: str,
    file_path: str,
    mime_type: str,
    process_options: Optional[documentai.ProcessOptions] = None,
) -> documentai.Document:
    # You must set the `api_endpoint` if you use a location other than "us".
    client = documentai.DocumentProcessorServiceClient(
        client_options=ClientOptions(
            api_endpoint=f"{location}-documentai.googleapis.com"
        )
    )

    # The full resource name of the processor version, e.g.:
    # `projects/{project_id}/locations/{location}/processors/{processor_id}/processorVersions/{processor_version_id}`
    # You must create a processor before running this sample.
    name = client.processor_version_path(
        project_id, location, processor_id, processor_version
    )

    # Read the file into memory
    with open(file_path, "rb") as image:
        image_content = image.read()

    # Configure the process request
    request = documentai.ProcessRequest(
        name=name,
        raw_document=documentai.RawDocument(content=image_content, mime_type=mime_type),
        # Only supported for Document OCR processor
        process_options=process_options,
    )

    result = client.process_document(request=request)

    # For a full list of `Document` object attributes, reference this page:
    # https://cloud.google.com/document-ai/docs/reference/rest/v1/Document
    return result.document


def layout_to_text(layout: documentai.Document.Page.Layout, text: str) -> str:
    """
    Document AI identifies text in different parts of the document by their
    offsets in the entirety of the document"s text. This function converts
    offsets to a string.
    """
    # If a text segment spans several lines, it will
    # be stored in different text segments.
    return "".join(
        text[int(segment.start_index) : int(segment.end_index)]
        for segment in layout.text_anchor.text_segments
    )


# Call the function and capture the results
process_document_ocr_sample(project_id, location, processor_id, processor_version, file_path, mime_type)
# Out:
# Full document text: ICICI Lombard
# Max Bupa
# Apoll
# Ihealth
# Heartbeat Gold
# Optin
# Basic sum insured
# 10 lacs
# 10 lacs
# Premium
# 10,643
# 22,696
# 1
# Hosptalization benefits
# Pre-existing diseases:
# Pre-existing diseases:
# Pre-existi
# 2 years
# 2 years
# }Specifi
# Specific illnesses/
# Specificillnesses/treatments: None
# 1 Waiting period
# treatments: 2 years
# treatme
# No restriction
# No restriction
# No re
# 2 Hospital accomodation
# /sub-limits
# /sub-limits
# /su
# 3 Pre-hospitalization
# 30 days
# 30 days
# 60
# 4 Post hospitalization
# 60 days after
# 60 days after
# 18
# Only in c
# accon
# Rs 800 per d
# 5 Hospital cash/Daily Cash
# No
# Not applicable
# of
# Actual cost at Network
# Rs. 1500 per
# hospital, Rs 2000 per
# Rs 2
# hospitalization
# hosptalization otherwise
# hospi
# Not covered
# Covered
# Cc
# 6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible
# Not applicable
# Not applicable
# Not a
# 140 day care procedures
# All day care procedures
# All day cal
# covered
# covered
# CO
# 9 Day care procedures10 Domicilliary hospitalization
# No
# Yes, upto Rs 50,000
# 11 Alternative treatments
# No
# No
# Maternity Benefits
# Waiting period of 24
# months. Expenses for 2
# deliveries,upto Rs 50000 per year
# Husband and wife to be
# Maternity benefits
# covered under the same
# 12 (delivery expenses)
# Waiting period of 36 months
# policy
# Automatic covered (withoutadditional charge) till the
# expiry of policy year inwhich the baby was born.
# Vaccination expenses
# PREVERSIONS
# CORSNES
# 13 | New born baby cover
# None
# covered
# Renewal benefits
# No
# No Claim:
# Bonus of 51
# Additional 10% sum insured
# Sum
# In cas
# accumulat
# at the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured
# re
# by 50% of
# 14 Renewal benefits
# in
# 15 Loading on claims
# NA
# ΝΑ
# 16 Health checkup
# Yes
# Yes (Annual)
# 17 Claim settlement record
# 96.9%
# 82.2%
# Source: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim
# months)
# lo Munich
# Tata AIG
# na Restore
# MediPrime
# Star Health Comprehensive
# .0 lacs
# 10 lacs
# 10 lacs
# 13,607
# 12,205
# 17,483
# ing diseases: 3
# Pre-existing diseases:
# Pre-existing diseases:
# years
# 4 years
# 4 yearsSpecific illnesses/
# ic illnesses/
# Specific illnesses/
# ents: 2 years
# treatments: 2 years
# treatments: 2 years
# estriction
# No restriction
# No restriction
# b-limits
# /sub-limits
# /sub-limits
# 60 days if informed of
# hospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days
# 6 days
# 15000
# per occurrence
# 2000 per
# Rs 2500 per
# Rs 3500 per
# italization
# hospitalization
# policy period
# overed
# Covered
# Not covered
# applicable
# Not applicable
# Not applicable140 day care procedures
# re procedures
# 101 day care
# >vered
# covered
# procedures covered
# Yes
# Yes
# No
# No
# Upto Rs 25000
# No
# Waiting period of 36
# months.
# Upto Rs 40000 per delivery
# None
# None
# for 2 deliveries
# Automatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.
# Vaccination expenses upto
# KRPERA
# BRESS
# None
# None
# Rs 1000 covered
# > claim:
# 0% of the Basic
# Insured
# No claim: Sum insured
# e of claim,
# enhanced by 10% (bonus)
# No claim: bonus sum
# ed bonus to be
# each year.
# insured at 100% of basic
# educed
# In case of claim: Cumulative
# sum insured.
# the basic sum
# bonus reduced by 10% of In case of claim: bonus sum
# sured.
# the basic sum insured
# insured becomes zero
# NA
# ΝΑ
# NA
# Once every four years
# Once every three
# No
# claim free years
# claim free years
# 79.0%
# 84.8%
# 69.0%
# settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six
# Group Name
# ABC Ltd
# Group Number
# Renewal Date
# No of employees enrolled
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# OON Deductible
# 100/0
# 2500/5000
# 123
# 01-01-2024
# 20
# Name
# 10-Day Green Smoothie Cleanse
# 11/22/63: A Novel
# 12 Rules for Life: An Antidote to Chaos
# 1984 (Signet Classics)
# Author
# JJ Smith
# Stephen King
# Jordan B. Peterson
# George Orwell
# 5,000 Awesome Facts (About Everything!) (National
# National
# Geographic Kids) Kids
# A Dance with Dragons (A Song of Ice and Fire) George R. R. Martin
# A Game of Thrones / A Clash of Kings / A Storm
# A Gentleman in Moscow: A Novel
# A Higher Loyalty: Truth, Lies, and Leadership
# A Man Called Ove: A Novel
# A Man Called Ove: A Novel
# of Swords / A Feast o
# Amor Towles
# James Comey
# Fredrik Backman
# Fredrik Backman
# A Patriot's History of the United States: From Columbus's Great D
# A Stolen Life: A Memoir
# A Wrinkle in Time (Time Quintet)
# Jaycee Dugard
# Act Like a Lady, Think Like a Man: What Men
# Madeleine L'Engle
# Really Think Abo
# User RatingReviews
# 4.7
# 17350
# 4.6
# 2052
# 4.7
# 18979
# 4.7
# 21424
# 4.8
# 7665
# 4.4
# 12643
# h Drs
# 19735
# 4.7
# 19699
# 4.7
# 5983
# 4.6
# 23848
# 4.6
# 23848
# rror4.6
# 460
# 4.6
# 4149
# 4.5
# 5153
# cy,
# 4.6
# omm
# 5013
# Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, M
# Adult Coloring Book: Stress Relieving Animal DesignsBlue
# Star Coloring
# Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring
# Adult Coloring Books: A Coloring Book for Adults
# Alexander Hamilton
# All the Light We Cannot See
# 4.5ls
# , a
# aisley
# 4.6
# 2925
# 4.4
# 2951
# Featuring Mandalas and
# Ron Chernow
# owe nimals
# 4.8
# 9198
# Anthony Doerr
# 4.6
# 36348
# All the Light We Cannot See
# Allegiant
# Anthony Doerr
# 4.6
# 36348
# Veronica Roth
# 3.9
# 6310
# American Sniper: The Autobiography of the Most Lethal SnChris Kyle
# 4.6
# 15921
# And the Mountains Echoed
# Khaled Hosseini
# 4.3
# 12159
# Arguing with Idiots: How to Stop Small Minds and Big GoverGlenn Beck
# 4.6
# 798
# Astrophysics for People in a Hurry
# Neil deGrasse Tyson
# 4.7
# 9374
# Autobiography of Mark Twain, Vol. 1
# Mark Twain
# 4.2
# 491
# Balance (Angie's Extreme Stress Menders)
# Baby Touch and Feel: Animals
# Barefoot Contessa Foolproof: Recipes You Can Trust: A CooIna Garten
# DK
# 4.6
# 5360
# Angie Grace
# 4.6
# 1909
# 4.8
# 1296
# Barefoot Contessa, How Easy Is That?: Fabulous Recipes &Ina Garten
# 4.7
# 615
# Becoming
# Michelle Obama
# 4.8
# 61133
# Becoming
# Michelle Obama
# 4.8
# 61133
# Being Mortal: Medicine and What Matters in the EndAtul
# Gawande
# 4.8
# 11113
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Born to Run
# Bruce Springsteen
# 4.7
# 3729
# Breaking Dawn (The Twilight Saga, Book 4)
# Broke: The Plan to Restore Our Trust, Truth and
# Brown Bear, Brown Bear, What Do You See?
# Brown Bear, Brown Bear, What Do You See?
# Cabin Fever (Diary of a Wimpy Kid, Book 6)
# Calm the F*ck Down: An Irreverent Adult Coloring Book (IrrevSasha O'Hara
# Can't Hurt Me: Master Your Mind and Defy the OddsDavid
# Goggins
# Stephenie Meyer
# 4.6
# 9769
# TreasureGlenn
# Beck
# 4.5
# 471
# Bill Martin Jr.
# 4.9
# 14344
# Bill Martin Jr.
# 4.9
# 14344
# Jeff Kinney
# 4.8
# 4505
# 4.6
# 10369
# 4.8
# 16244
# Price
# Year
# Genre
# 8
# 2016 Non Fiction
# 22
# 2011 Fiction
# 15
# 2018 Non Fiction
# 6
# 2017 Fiction
# 12
# 2019 Non Fiction
# 11
# 2011 Fiction
# 30
# 2014 Fiction
# 15
# 2017 Fiction
# 3
# 2018 Non Fiction
# 8
# 2016 Fiction
# 8
# 2017 Fiction
# 2
# 2010 Non Fiction
# 32
# 2011 Non Fiction
# 5
# 2018 Fiction
# 17
# 2009 Non Fiction
# 4
# 2016 Non Fiction
# 6
# 2015 Non Fiction
# 6
# 2015 Non Fiction
# 8
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 14
# 2014 Fiction
# 14
# 2015 Fiction
# 13
# 2013 Fiction
# 9
# 2015 Non Fiction
# 13
# 2013 Fiction
# 5
# 2009 Non Fiction
# 9
# 2017 Non Fiction
# 14
# 2010 Non Fiction
# 5
# 2015 Non Fiction
# 11
# 2015 Non Fiction
# 24
# 2012 Non Fiction
# 21
# 2010 Non Fiction
# 11
# 2018 Non Fiction
# 11
# 2019 Non Fiction
# 15
# 2015 Non Fiction
# 13
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 18
# 2016 Non Fiction
# 13
# 2009 Fiction
# 8
# 2010 Non Fiction
# 5
# 2017 Fiction
# 5
# 2019 Fiction
# 0
# 2011 Fiction
# 4
# 2016 Non Fiction
# 18
# 2019 Non Fiction
# ▬▬İ
# --
# K
# C:\Users\Shreshtha\Downloads\AmazonBooks.xlsx
# C:\Users\Shreshtha\Downloads\honeypr
# C:\Users\Shreshtha\Downloads\OrderDetails.csv
# &
# PDF
# C:\Users\Shreshtha\Downloads\Problem Statement
# Company Name- ABC Ltd.
# Source- Google
# ABC Ltd
# Group NameGroup Number
# 123
# Renewal Date
# 01-01-2024
# No of employees enrolled
# 20
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# 100/0
# OON Deductible
# 2500/5000
# Group Financial
# Please see Rate Model for a
# Plan Design:
# KACTOHP63RD
# In-Network
# Office Copay:
# PCP:
# No Charge after Deductible
# Specialist:
# No Charge after Deductible
# ER Copay:
# No Charge after Deductible
# Hospital Copay
# Inpatient:
# No Charge after Deductible
# Outpatient Freestanding:
# No Charge after Deductible
# Outpatient Hospital Setting:
# No Charge after Deductible
# Modified Cost Share
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# Coinsurance:
# None
# JOULU
# Single M.O.O.P.
# $4,000
# Family M.O.O.P.
# $8,000
# Financial Accumulation Period:
# Calendar Year
# Prescriptio
# Please see Rate Model for available plan combinations
# Information
# Link to PDML:
# http://pdml/
# vailable plan combinations
# Out-of-Network
# Modified UCR:Standard
# UCR:
# 100% of Medicare
# Modified Cost Share:
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# ПППП
# Coinsurance:
# 30%
# Ain
# Single M.O.O.P.
# $5,850
# Family M.O.O.P.
# $11,700
# on Plan
# Rx Tracking ID:
#
#
# There are 12 page(s) in this document.
#
# Page 1 text:
# ICICI Lombard
# Max Bupa
# Apoll
# Ihealth
# Heartbeat Gold
# Optin
# Basic sum insured
# 10 lacs
# 10 lacs
# Premium
# 10,643
# 22,696
# 1
# Hosptalization benefits
# Pre-existing diseases:
# Pre-existing diseases:
# Pre-existi
# 2 years
# 2 years
# }Specifi
# Specific illnesses/
# Specificillnesses/treatments: None
# 1 Waiting period
# treatments: 2 years
# treatme
# No restriction
# No restriction
# No re
# 2 Hospital accomodation
# /sub-limits
# /sub-limits
# /su
# 3 Pre-hospitalization
# 30 days
# 30 days
# 60
# 4 Post hospitalization
# 60 days after
# 60 days after
# 18
# Only in c
# accon
# Rs 800 per d
# 5 Hospital cash/Daily Cash
# No
# Not applicable
# of
# Actual cost at Network
# Rs. 1500 per
# hospital, Rs 2000 per
# Rs 2
# hospitalization
# hosptalization otherwise
# hospi
# Not covered
# Covered
# Cc
# 6 Emergency ambulance7 Organ donor expenseCo-payment feature8/Annual deductible
# Not applicable
# Not applicable
# Not a
# 140 day care procedures
# All day care procedures
# All day cal
# covered
# covered
# CO
# 9 Day care procedures10 Domicilliary hospitalization
# No
# Yes, upto Rs 50,000
# 11 Alternative treatments
# No
# No
# Maternity Benefits
# Waiting period of 24
# months. Expenses for 2
# deliveries,upto Rs 50000 per year
# Husband and wife to be
# Maternity benefits
# covered under the same
# 12 (delivery expenses)
# Waiting period of 36 months
# policy
# Automatic covered (withoutadditional charge) till the
# expiry of policy year inwhich the baby was born.
# Vaccination expenses
# PREVERSIONS
# CORSNES
#
#
# ==================================================
#
# Page 2 text:
# 13 | New born baby cover
# None
# covered
# Renewal benefits
# No
# No Claim:
# Bonus of 51
# Additional 10% sum insured
# Sum
# In cas
# accumulat
# at the time of renewal for Irrespective of whether theevery claim free year.claim was made:In case of a claim,Gift rewards worth 10% ofcumulative additional sum last paid premium orinsured to go down by 50% additional 10% sum insured
# re
# by 50% of
# 14 Renewal benefits
# in
# 15 Loading on claims
# NA
# ΝΑ
# 16 Health checkup
# Yes
# Yes (Annual)
# 17 Claim settlement record
# 96.9%
# 82.2%
# Source: Policy documents for the respective policies (December 2014). For claim settlement data: Mint Mediclaim ratings, Claim
# months)
#
#
# ==================================================
#
# Page 3 text:
# lo Munich
# Tata AIG
# na Restore
# MediPrime
# Star Health Comprehensive
# .0 lacs
# 10 lacs
# 10 lacs
# 13,607
# 12,205
# 17,483
# ing diseases: 3
# Pre-existing diseases:
# Pre-existing diseases:
# years
# 4 years
# 4 yearsSpecific illnesses/
# ic illnesses/
# Specific illnesses/
# ents: 2 years
# treatments: 2 years
# treatments: 2 years
# estriction
# No restriction
# No restriction
# b-limits
# /sub-limits
# /sub-limits
# 60 days if informed of
# hospitalization 5 days in0 daysadvance, else 30 days30 days90 days if informed ofhospitalization 5 days in10 daysadvance, else 60 days60 daysase of sharedOnly for accompanyingnodation.insured child. Rs 500 per day Rs 750 per day upto 120 dayslay for maximum subject to a maximum of Rs with a maximum of 7 days
# 6 days
# 15000
# per occurrence
# 2000 per
# Rs 2500 per
# Rs 3500 per
# italization
# hospitalization
# policy period
# overed
# Covered
# Not covered
# applicable
# Not applicable
# Not applicable140 day care procedures
# re procedures
# 101 day care
# >vered
# covered
# procedures covered
# Yes
# Yes
# No
# No
# Upto Rs 25000
# No
# Waiting period of 36
# months.
# Upto Rs 40000 per delivery
# None
# None
# for 2 deliveries
# Automatically covered uptoRs 1 lac (without additionalcharge) till the expiry ofpolicy year in which thebaby was born.
# Vaccination expenses upto
# KRPERA
# BRESS
#
#
# ==================================================
#
# Page 4 text:
# None
# None
# Rs 1000 covered
# > claim:
# 0% of the Basic
# Insured
# No claim: Sum insured
# e of claim,
# enhanced by 10% (bonus)
# No claim: bonus sum
# ed bonus to be
# each year.
# insured at 100% of basic
# educed
# In case of claim: Cumulative
# sum insured.
# the basic sum
# bonus reduced by 10% of In case of claim: bonus sum
# sured.
# the basic sum insured
# insured becomes zero
# NA
# ΝΑ
# NA
# Once every four years
# Once every three
# No
# claim free years
# claim free years
# 79.0%
# 84.8%
# 69.0%
# settlement ratio calculated as 100% -(%claims repudiated +% claims pending for over six
#
#
# ==================================================
#
# Page 5 text:
# Group Name
# ABC Ltd
# Group Number
# Renewal Date
# No of employees enrolled
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# OON Deductible
# 100/0
# 2500/5000
# 123
# 01-01-2024
# 20
#
#
# ==================================================
#
# Page 6 text:
# Name
# 10-Day Green Smoothie Cleanse
# 11/22/63: A Novel
# 12 Rules for Life: An Antidote to Chaos
# 1984 (Signet Classics)
# Author
# JJ Smith
# Stephen King
# Jordan B. Peterson
# George Orwell
# 5,000 Awesome Facts (About Everything!) (National
# National
# Geographic Kids) Kids
# A Dance with Dragons (A Song of Ice and Fire) George R. R. Martin
# A Game of Thrones / A Clash of Kings / A Storm
# A Gentleman in Moscow: A Novel
# A Higher Loyalty: Truth, Lies, and Leadership
# A Man Called Ove: A Novel
# A Man Called Ove: A Novel
# of Swords / A Feast o
# Amor Towles
# James Comey
# Fredrik Backman
# Fredrik Backman
# A Patriot's History of the United States: From Columbus's Great D
# A Stolen Life: A Memoir
# A Wrinkle in Time (Time Quintet)
# Jaycee Dugard
# Act Like a Lady, Think Like a Man: What Men
# Madeleine L'Engle
# Really Think Abo
# User RatingReviews
# 4.7
# 17350
# 4.6
# 2052
# 4.7
# 18979
# 4.7
# 21424
# 4.8
# 7665
# 4.4
# 12643
# h Drs
# 19735
# 4.7
# 19699
# 4.7
# 5983
# 4.6
# 23848
# 4.6
# 23848
# rror4.6
# 460
# 4.6
# 4149
# 4.5
# 5153
# cy,
# 4.6
# omm
# 5013
# Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, M
# Adult Coloring Book: Stress Relieving Animal DesignsBlue
# Star Coloring
# Adult Coloring Book: Stress Relieving Patterns Blue Star Coloring
# Adult Coloring Books: A Coloring Book for Adults
# Alexander Hamilton
# All the Light We Cannot See
# 4.5ls
# , a
# aisley
# 4.6
# 2925
# 4.4
# 2951
# Featuring Mandalas and
# Ron Chernow
# owe nimals
# 4.8
# 9198
# Anthony Doerr
# 4.6
# 36348
# All the Light We Cannot See
# Allegiant
# Anthony Doerr
# 4.6
# 36348
# Veronica Roth
# 3.9
# 6310
# American Sniper: The Autobiography of the Most Lethal SnChris Kyle
# 4.6
# 15921
# And the Mountains Echoed
# Khaled Hosseini
# 4.3
# 12159
# Arguing with Idiots: How to Stop Small Minds and Big GoverGlenn Beck
# 4.6
# 798
# Astrophysics for People in a Hurry
# Neil deGrasse Tyson
# 4.7
# 9374
# Autobiography of Mark Twain, Vol. 1
# Mark Twain
# 4.2
# 491
# Balance (Angie's Extreme Stress Menders)
# Baby Touch and Feel: Animals
# Barefoot Contessa Foolproof: Recipes You Can Trust: A CooIna Garten
# DK
# 4.6
# 5360
# Angie Grace
# 4.6
# 1909
# 4.8
# 1296
# Barefoot Contessa, How Easy Is That?: Fabulous Recipes &Ina Garten
# 4.7
# 615
# Becoming
# Michelle Obama
# 4.8
# 61133
# Becoming
# Michelle Obama
# 4.8
# 61133
# Being Mortal: Medicine and What Matters in the EndAtul
# Gawande
# 4.8
# 11113
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Between the World and Me
# Ta-Nehisi Coates
# 4.7
# 10070
# Born to Run
# Bruce Springsteen
# 4.7
# 3729
# Breaking Dawn (The Twilight Saga, Book 4)
# Broke: The Plan to Restore Our Trust, Truth and
# Brown Bear, Brown Bear, What Do You See?
# Brown Bear, Brown Bear, What Do You See?
# Cabin Fever (Diary of a Wimpy Kid, Book 6)
# Calm the F*ck Down: An Irreverent Adult Coloring Book (IrrevSasha O'Hara
# Can't Hurt Me: Master Your Mind and Defy the OddsDavid
# Goggins
# Stephenie Meyer
# 4.6
# 9769
# TreasureGlenn
# Beck
# 4.5
# 471
# Bill Martin Jr.
# 4.9
# 14344
# Bill Martin Jr.
# 4.9
# 14344
# Jeff Kinney
# 4.8
# 4505
# 4.6
# 10369
# 4.8
# 16244
#
#
# ==================================================
#
# Page 7 text:
# Price
# Year
# Genre
# 8
# 2016 Non Fiction
# 22
# 2011 Fiction
# 15
# 2018 Non Fiction
# 6
# 2017 Fiction
# 12
# 2019 Non Fiction
# 11
# 2011 Fiction
# 30
# 2014 Fiction
# 15
# 2017 Fiction
# 3
# 2018 Non Fiction
# 8
# 2016 Fiction
# 8
# 2017 Fiction
# 2
# 2010 Non Fiction
# 32
# 2011 Non Fiction
# 5
# 2018 Fiction
# 17
# 2009 Non Fiction
# 4
# 2016 Non Fiction
# 6
# 2015 Non Fiction
# 6
# 2015 Non Fiction
# 8
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 14
# 2014 Fiction
# 14
# 2015 Fiction
# 13
# 2013 Fiction
# 9
# 2015 Non Fiction
# 13
# 2013 Fiction
# 5
# 2009 Non Fiction
# 9
# 2017 Non Fiction
# 14
# 2010 Non Fiction
# 5
# 2015 Non Fiction
# 11
# 2015 Non Fiction
# 24
# 2012 Non Fiction
# 21
# 2010 Non Fiction
# 11
# 2018 Non Fiction
# 11
# 2019 Non Fiction
# 15
# 2015 Non Fiction
# 13
# 2015 Non Fiction
# 13
# 2016 Non Fiction
# 18
# 2016 Non Fiction
# 13
# 2009 Fiction
# 8
# 2010 Non Fiction
# 5
# 2017 Fiction
# 5
# 2019 Fiction
# 0
# 2011 Fiction
# 4
# 2016 Non Fiction
# 18
# 2019 Non Fiction
#
#
# ==================================================
#
# Page 8 text:
# ▬▬İ
# --
# K
# C:\Users\Shreshtha\Downloads\AmazonBooks.xlsx
# C:\Users\Shreshtha\Downloads\honeypr
# C:\Users\Shreshtha\Downloads\OrderDetails.csv
#
#
# ==================================================
#
# Page 9 text:
# &
# PDF
# C:\Users\Shreshtha\Downloads\Problem Statement
#
#
# ==================================================
#
# Page 10 text:
# Company Name- ABC Ltd.
# Source- Google
# ABC Ltd
# Group NameGroup Number
# 123
# Renewal Date
# 01-01-2024
# No of employees enrolled
# 20
# Group State
# CT
# Market
# Large
# In Network (IN):
# Copay
# 30/45
# IN Coinsurance %
# 100/0
# IN Deductible
# 2500/5000
# Out of Network (OON):
# OON Coinsurance %
# 100/0
# OON Deductible
# 2500/5000
#
#
# ==================================================
#
# Page 11 text:
# Group Financial
# Please see Rate Model for a
# Plan Design:
# KACTOHP63RD
# In-Network
# Office Copay:
# PCP:
# No Charge after Deductible
# Specialist:
# No Charge after Deductible
# ER Copay:
# No Charge after Deductible
# Hospital Copay
# Inpatient:
# No Charge after Deductible
# Outpatient Freestanding:
# No Charge after Deductible
# Outpatient Hospital Setting:
# No Charge after Deductible
# Modified Cost Share
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# Coinsurance:
# None
# JOULU
# Single M.O.O.P.
# $4,000
# Family M.O.O.P.
# $8,000
# Financial Accumulation Period:
# Calendar Year
# Prescriptio
# Please see Rate Model for available plan combinations
#
#
# ==================================================
#
# Page 12 text:
# Information
# Link to PDML:
# http://pdml/
# vailable plan combinations
# Out-of-Network
# Modified UCR:Standard
# UCR:
# 100% of Medicare
# Modified Cost Share:
# Single Deductible:
# $2,850
# Family Deductible:
# $5,700
# ПППП
# Coinsurance:
# 30%
# Ain
# Single M.O.O.P.
# $5,850
# Family M.O.O.P.
# $11,700
# on Plan
# Rx Tracking ID:
#
#
# ==================================================
