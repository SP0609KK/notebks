# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
openai.api_key = "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"

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
text = f"""
You should express what you want a model to do by \ 
providing instructions that are as clear and \ 
specific as you can possibly make them. \ 
This will guide the model towards the desired output, \ 
and reduce the chances of receiving irrelevant \ 
or incorrect responses. Don't confuse writing a \ 
clear prompt with writing a short prompt. \ 
In many cases, longer prompts provide more clarity \ 
and context for the model, which can lead to \ 
more detailed and relevant outputs.
"""
prompt = f"""
Summarize the text delimited by triple backticks \ 
into a single sentence.
```{text}```
"""
response = get_completion(prompt)
print(response)
# Out:
# To guide a model towards the desired output and reduce irrelevant or incorrect responses, it is important to provide clear and specific instructions, which can be achieved through longer prompts that offer more clarity and context.

# %%
text = f"""
**** Page 1 ****

Found 1 table(s):
Table with 2 columns and 6 rows:
'In Network (IN):' | '' | 
'Copay' | '30/45' | 
'IN Coinsurance %' | '100/0' | 
'IN Deductible' | '2500/5000' | 
'Out of Network (OON):' | '' | 
'OON Coinsurance %' | '100/0' | 
'OON Deductible' | '2500/5000' | 

Found 8 form field(s):
    * 'Copay': '30/45'
    * 'IN Deductible': '2500/5000'
    * 'Renewal Date': '1/1/2024'
    * 'Group Name': 'ABC Ltd'
    * 'IN Coinsurance %': '100/0'
    * 'OON Deductible': '2500/5000'
    * 'No of employees enrolled': '20'
    * 'Market\nEvaluation Warning :': 'The document was created with Spire.XLS Large'

**** Page 2 ****

Found 2 table(s):
Table with 2 columns and 5 rows:
'Evaluation Warning : The document was created State Group Market In Network (IN): Copay' | 'with Spire.XLS for Python CT Large 30/45' | 
'IN Coinsurance %' | '100/0' | 
'IN Deductible' | '2500/5000' | 
'Out of Network (OON):' | '' | 
'OON Coinsurance %' | '100/0' | 
'OON Deductible' | '2500/5000' | 
Table with 2 columns and 3 rows:
'Group Name' | 'ABC Ltd' | 
'Group Number' | '123' | 
'Renewal Date' | '01-01-2024' | 
'No  of  employees  enrolled' | '20' | 

Found 4 form field(s):
    * 'Market': 'Large\nIn Network (IN):\nCopay\n30/45\nIN Coinsurance %\n100/0\nIN Deductible\n2500/5000\nOut of Network (OON):'
    * 'Out of Network (OON):': 'OON Coinsurance %\n100/0\nOON Deductible\n2500/5000'
    * 'ABC Ltd': '123\n01-01-2024'
    * 'Renewal Date': 'Group Name\nGroup Number'
    
**** Page 3 ****

Group Name:

Aurora Products

Group Number (or TBD):

1264561

Request Date:

7214/2020

Effective Date of NSI

3/4/2020

Please Note: All items listed on this form are subject to review, Please highlight the NSB"

in yellow,

Benefits Currently in Place

Requested Benefits

Current Plan Current Plan 2: | Current Plan 3:
0100001 BUY UP Potoo02 core | 0100004 BASE
Base (Similar standard Plan) Tracking ID # (REQUIRED)
+ Reach out to your Underwriter
ia ta
# of Employees Enrolled: 39 2 25 28 26 18
Group State (NY, NJ, CT) cr cr ct cr cr cr
Market (Large or Small Group) Large Large Large Large Large Large
Product (e.g: HMO, POS, Classic, Access, Dect, OxUSA, Value Option
or EPO) HMO HMO HSA Wo HMO HSA
Access (Gated or Non-Gated) | Non-Gates Gated Non-Gated Non-Gated Gated Non-Gated
Network (Freedom, Liberty, or Choice Plus) Freedom Freedom Freedom Freedom Freedom Freedom
Current Carrier (Oxford or Competitor) Polaris Polaris Polaris Potaris Polaris Polaris
in Network (IN):
PCP/Specialist OV Copay 3050 3050 D8. 100%
ER Cost Share 4150 150 psc
IP: $260/Da9-$1800 Mae IP: $250/Day-$1500 Max
air deductible ‘ser deductible
OF: FSDed.then OP: FS-Ded, then
$250)vsit Hosp-Ded, the $250sk Hosp-Ded theo
Hospital Cost Share (inpatient/Outpatent ‘$500hst 500s psc.
For Direct, EPO or Value Option Products:
IN Deductible - Individual & Family 2500/5000 2500/5000 5000/1000 2500/5000 2500/5000 000/10000
IN Coinsurance % (100, 90/10, 80/20. 1000 00/0 onto +0070 10/0 0110
IN Coinsurance Limit ($Sk, $10k..) Indiv. & Fam.
IN Out-of-Pocket Maximum (include ded.) - Indiv. & Fam. 3000/6000 5000/10000 6250/1250 30006000 5000/1000 6250/2500
Out of Network (OON):.
OON Deductible - Individual & Family NA NA 5000/1000 NA NA 5000/1000
OON Coinsurance % (80/20, 70/30, 60/40) NA NA 60/40 NA Na 60140
OON Coinsurance Limit ($Sk, $10k, $254) - Indiv. & Fam.
OON Out-of-Pocket (include ded.) - Indiv. & Fam. NA NA 9000/1800 NA NA 9000/1000    
"""
prompt = f"""
You are a Healthcare Expert. Each page represents a group for a non standard health insurance plan. Return the values for all the fields.

{text}
"""
response = get_completion(prompt)
print(response)
# Out:
# On Page 1, the values for the fields are as follows:
#
# - Copay: 30/45
# - IN Deductible: 2500/5000
# - Renewal Date: 1/1/2024
# - Group Name: ABC Ltd
# - IN Coinsurance %: 100/0
# - OON Deductible: 2500/5000
# - No of employees enrolled: 20
#
# On Page 2, the values for the fields are as follows:
#
# - Market: Large
# - Out of Network (OON): OON Coinsurance % 100/0 OON Deductible 2500/5000
# - ABC Ltd: 123 01-01-2024
# - Renewal Date: Group Name Group Number
#
# On Page 3, the values for the fields are as follows:
#
# - Group Name: Aurora Products
# - Group Number (or TBD): 1264561
# - Request Date: 7214/2020
# - Effective Date of NSI: 3/4/2020
# - # of Employees Enrolled: 39 2 25 28 26 18
# - Group State (NY, NJ, CT): cr cr ct cr cr cr
# - Market (Large or Small Group): Large Large Large Large Large Large
# - Product (e.g: HMO, POS, Classic, Access, Dect, OxUSA, Value Option or EPO): HMO HMO HSA Wo HMO HSA
# - Access (Gated or Non-Gated): Non-Gates Gated Non-Gated Non-Gated Gated Non-Gated
# - Network (Freedom, Liberty, or Choice Plus): Freedom Freedom Freedom Freedom Freedom Freedom
# - Current Carrier (Oxford or Competitor): Polaris Polaris Polaris Potaris Polaris Polaris
# - IN Deductible - Individual & Family: 2500/5000 2500/5000 5000/1000 2500/5000 2500/5000 000/10000
# - IN Coinsurance % (100, 90/10, 80/20): 100% 100% 100% 100% 100% 100%
# - IN Coinsurance Limit ($Sk, $10k..) - Indiv. & Fam.: N/A N/A N/A N/A N/A N/A
# - IN Out-of-Pocket Maximum (include ded.) - Indiv. & Fam.: 3000/6000 5000/10000 6250/1250 3000/6000 5000/1000 6250/2500
# - OON Deductible - Individual & Family: N/A N/A 5000/1000 N/A N/A 5000/1000
# - OON Coinsurance % (80/20, 70/30, 60/40): N/A N/A 60/40 N/A N/A 60/40
# - OON Coinsurance Limit ($Sk, $10k, $254) - Indiv. & Fam.: N/A N/A N/A N/A N/A N/A
# - OON Out-of-Pocket (include ded.) - Indiv. & Fam.: N/A N/A 9000/1800 N/A N/A 9000/1000

# %%
text = f"""
Page 2 text:
Group Name
ABC Ltd
Group Number
Renewal Date
123
01-01-2024
Group State
Market
No of employees enrolled
20
Evaluation Warning : The document was created with Spire.XLS for Python
CT
Large
In Network (IN):
Copay
30/45
IN Coinsurance %
100/0
IN Deductible
2500/5000
Out of Network (OON):
OON Coinsurance %
OON Deductible
100/0
2500/5000


Page 6 text:
Company Name- ABC Ltd.
Source- Google
Evaluation Warning : The document was created with Spire.XLS for Python
No 
of 
Group 
State
CT
Group Name
ABC Ltd
Group Number
123
Renewal Date
01-01-2024
20
Market
Large
In Network (IN):
30/45
CopayIN Coinsurance %
100/0
IN Deductible
2500/5000
Out of Network (OON):OON Coinsurance %
100/0
OON Deductible
2500/5000

Page 7 text:
Evaluation Warning : The document was created with Spire.XLS for Python
Group Financial Information
Link to PDML:
http://pdml/
Please see Rate Model for available plan combinations
Plan Design:
KACTOHP63RD
In-Network
Out-of-Network
Office Copay:
Modified UCR:Standard
PCP:
No Charge after Deductible
UCR:
100% of Medicare
Specialist:
No Charge after Deductible
ER Copay:
No Charge after Deductible
Hospital Copay
Inpatient:
No Charge after Deductible
Outpatient Hospital Setting:
No Charge after Deductible
Modified Cost Share:
Modified Cost Share:
Single Deductible:
$2,850
Single Deductible:
$2,850
Family Deductible:
$5,700
Family Deductible:
$5,700
Coinsurance:
None
Coinsurance:
30%
Single M.O.O.P.
$4,000
Single M.O.O.P.
$5,850
Family M.O.O.P.
$8,000
Family M.O.O.P.
$11,700
Financial Accumulation Period:
Calendar Year
Prescription Plan
Please see Rate Model for available plan combinations
Rx Tracking ID:
"""

prompt = f"""
You are a Healthcare Expert. Each page represents a group for a non standard health insurance plan. Return the values for each page for the following fields:
1. Group Name
2. Group Number/ID
3. Renewal Date
4. IN Copay
5. IN Coinsurance
6. IN Deductible
7. OON Copay
8. OON Coinsurance
9. OON Deductible

{text}
"""
response = get_completion(prompt)
print(response)
# Out:
# Page 2:
# 1. Group Name: ABC Ltd
# 2. Group Number/ID: 123
# 3. Renewal Date: 01-01-2024
# 4. IN Copay: 30/45
# 5. IN Coinsurance: 100/0
# 6. IN Deductible: 2500/5000
# 7. OON Copay: Not provided
# 8. OON Coinsurance: 100/0
# 9. OON Deductible: 2500/5000
#
# Page 6:
# 1. Group Name: ABC Ltd
# 2. Group Number/ID: 123
# 3. Renewal Date: 01-01-2024
# 4. IN Copay: 30/45
# 5. IN Coinsurance: 100/0
# 6. IN Deductible: 2500/5000
# 7. OON Copay: Not provided
# 8. OON Coinsurance: 100/0
# 9. OON Deductible: 2500/5000
#
# Page 7:
# 1. Group Name: Not provided
# 2. Group Number/ID: Not provided
# 3. Renewal Date: Not provided
# 4. IN Copay: Not provided
# 5. IN Coinsurance: None
# 6. IN Deductible: $2,850 (Single Deductible), $5,700 (Family Deductible)
# 7. OON Copay: Not provided
# 8. OON Coinsurance: 30%
# 9. OON Deductible: $4,000 (Single M.O.O.P.), $8,000 (Family M.O.O.P.)
