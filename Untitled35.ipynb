# %%
import openai
openai.api_key = "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"

prompt = "Hello, my name is John and I am a software engineer."
model = "text-davinci-003"
response = openai.Completion.create(engine=model, prompt=prompt, max_tokens=50)

generated_text = response.choices[0].text
print(generated_text)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[1], line 6
#       4 prompt = "Hello, my name is John and I am a software engineer."
#       5 model = "text-davinci-003"
# ----> 6 response = openai.Completion.create(engine=model, prompt=prompt, max_tokens=50)
#       8 generated_text = response.choices[0].text
#       9 print(generated_text)
#
# File ~\anaconda3\Lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# ...

# %%
# old
import os
import openai

openai.api_key = os.environ['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']

# new
from openai import OpenAI

client = OpenAI(
  api_key=os.environ['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'],  # this is also the default, it can be omitted
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       2 import os
#       3 import openai
# ----> 5 openai.api_key = os.environ['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']
#       7 # new
#       8 from openai import OpenAI
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: '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'
