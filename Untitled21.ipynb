# %%
import cv2
import os
import shutil
from skimage.metrics import structural_similarity as ssim

def get_image_similarity(img1_path, img2_path):
    image1 = cv2.imread(img1_path)
    image2 = cv2.imread(img2_path)
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
    (_, similarity) = ssim(gray1, gray2, full=True)
    return similarity

def group_similar_images(input_folder, output_folder):
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

    for i, img_file1 in enumerate(image_files):
        group_folder = os.path.join(output_folder, f"Group_{i + 1}")
        os.makedirs(group_folder, exist_ok=True)

        for img_file2 in image_files:
            if img_file1 != img_file2:
                similarity = get_image_similarity(
                    os.path.join(input_folder, img_file1),
                    os.path.join(input_folder, img_file2)
                )

                # You can adjust this threshold based on your needs
                if similarity > 0.90:
                    shutil.move(os.path.join(input_folder, img_file2), group_folder)

if _name_ == "_main_":
    input_folder_path = "path/to/your/input/folder"
    output_folder_path = "path/to/your/output/folder"

    group_similar_images(input_folder_path, output_folder_path)

# %%
import cv2
import os
import shutil
from skimage.metrics import structural_similarity as ssim

def get_image_similarity(img1_path, img2_path):
    image1 = cv2.imread(img1_path)
    image2 = cv2.imread(img2_path)
    gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
    (_, similarity) = ssim(gray1, gray2, full=True)
    return similarity

def group_similar_images(input_folder, output_folder):
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

    for i, img_file1 in enumerate(image_files):
        group_folder = os.path.join(output_folder, f"Group_{i + 1}")
        os.makedirs(group_folder, exist_ok=True)

        for img_file2 in image_files:
            if img_file1 != img_file2:
                similarity = get_image_similarity(
                    os.path.join(input_folder, img_file1),
                    os.path.join(input_folder, img_file2)
                )

                # You can adjust this threshold based on your needs
                if similarity > 0.90:
                    shutil.move(os.path.join(input_folder, img_file2), group_folder)

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/"

# Call the function
group_similar_images(input_folder_path, output_folder_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 37
#      34 output_folder_path = "C:/Users/Shreshtha/Downloads/"
#      36 # Call the function
# ---> 37 group_similar_images(input_folder_path, output_folder_path)
#
# Cell In[1], line 23, in group_similar_images(input_folder, output_folder)
#      21 for img_file2 in image_files:
#      22     if img_file1 != img_file2:
# ---> 23         similarity = get_image_similarity(
#      24             os.path.join(input_folder, img_file1),
#      25             os.path.join(input_folder, img_file2)
#      26         )
#      28         # You can adjust this threshold based on your needs
#      29         if similarity > 0.90:
#
# Cell In[1], line 11, in get_image_similarity(img1_path, img2_path)
#       9 gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
#      10 gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)
# ...

# %%
import cv2
import os
import shutil
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    return cv2.resize(image, target_size)

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    image1 = cv2.imread(img1_path)
    image2 = cv2.imread(img2_path)

    # Resize images to a consistent size
    resized_image1 = resize_image(image1, target_size)
    resized_image2 = resize_image(image2, target_size)

    gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)
    
    (_, similarity) = ssim(gray1, gray2, full=True)
    return similarity

def group_similar_images(input_folder, output_folder):
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

    for i, img_file1 in enumerate(image_files):
        group_folder = os.path.join(output_folder, f"Group_{i + 1}")
        os.makedirs(group_folder, exist_ok=True)

        for img_file2 in image_files:
            if img_file1 != img_file2:
                similarity = get_image_similarity(
                    os.path.join(input_folder, img_file1),
                    os.path.join(input_folder, img_file2)
                )

                # You can adjust this threshold based on your needs
                if similarity > 0.90:
                    shutil.move(os.path.join(input_folder, img_file2), group_folder)

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/"

# Call the function
group_similar_images(input_folder_path, output_folder_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 46
#      43 output_folder_path = "C:/Users/Shreshtha/Downloads/"
#      45 # Call the function
# ---> 46 group_similar_images(input_folder_path, output_folder_path)
#
# Cell In[2], line 38, in group_similar_images(input_folder, output_folder)
#      32 similarity = get_image_similarity(
#      33     os.path.join(input_folder, img_file1),
#      34     os.path.join(input_folder, img_file2)
#      35 )
#      37 # You can adjust this threshold based on your needs
# ---> 38 if similarity > 0.90:
#      39     shutil.move(os.path.join(input_folder, img_file2), group_folder)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import cv2
import os
import shutil
import numpy as np
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    return cv2.resize(image, target_size)

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    image1 = cv2.imread(img1_path)
    image2 = cv2.imread(img2_path)

    # Resize images to a consistent size
    resized_image1 = resize_image(image1, target_size)
    resized_image2 = resize_image(image2, target_size)

    gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)
    
    (_, similarity) = ssim(gray1, gray2, full=True)
    return similarity

def group_similar_images(input_folder, output_folder):
    image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

    for i, img_file1 in enumerate(image_files):
        group_folder = os.path.join(output_folder, f"Group_{i + 1}")
        os.makedirs(group_folder, exist_ok=True)

        for img_file2 in image_files:
            if img_file1 != img_file2:
                similarity = get_image_similarity(
                    os.path.join(input_folder, img_file1),
                    os.path.join(input_folder, img_file2)
                )

                # Use np.any() to check if any element is greater than 0.90
                if np.any(similarity > 0.90):
                    shutil.move(os.path.join(input_folder, img_file2), group_folder)

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/"

# Call the function
group_similar_images(input_folder_path, output_folder_path)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 47
#      44 output_folder_path = "C:/Users/Shreshtha/Downloads/"
#      46 # Call the function
# ---> 47 group_similar_images(input_folder_path, output_folder_path)
#
# Cell In[3], line 33, in group_similar_images(input_folder, output_folder)
#      31 for img_file2 in image_files:
#      32     if img_file1 != img_file2:
# ---> 33         similarity = get_image_similarity(
#      34             os.path.join(input_folder, img_file1),
#      35             os.path.join(input_folder, img_file2)
#      36         )
#      38         # Use np.any() to check if any element is greater than 0.90
#      39         if np.any(similarity > 0.90):
#
# Cell In[3], line 15, in get_image_similarity(img1_path, img2_path, target_size)
#      12 image2 = cv2.imread(img2_path)
#      14 # Resize images to a consistent size
# ...

# %%
import cv2
import os
import shutil
import numpy as np
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            # Return original image if resizing is not possible
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    try:
        image1 = cv2.imread(img1_path)
        image2 = cv2.imread(img2_path)

        # Resize images to a consistent size
        resized_image1 = resize_image(image1, target_size)
        resized_image2 = resize_image(image2, target_size)

        if resized_image1 is not None and resized_image2 is not None:
            gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)

            (_, similarity) = ssim(gray1, gray2, full=True)
            return similarity
        else:
            # Handle case where resizing failed
            return 0.0
    except Exception as e:
        print(f"Error processing images: {e}")
        return 0.0

def group_similar_images(input_folder, output_folder):
    try:
        image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

        for i, img_file1 in enumerate(image_files):
            group_folder = os.path.join(output_folder, f"Group_{i + 1}")
            os.makedirs(group_folder, exist_ok=True)

            for img_file2 in image_files:
                if img_file1 != img_file2:
                    similarity = get_image_similarity(
                        os.path.join(input_folder, img_file1),
                        os.path.join(input_folder, img_file2)
                    )

                    # Use np.any() to check if any element is greater than 0.90
                    if np.any(similarity > 0.90):
                        shutil.move(os.path.join(input_folder, img_file2), group_folder)
    except Exception as e:
        print(f"Error grouping similar images: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/"

# Call the function
group_similar_images(input_folder_path, output_folder_path)

# %%
import cv2
import os
import shutil
import numpy as np
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    try:
        image1 = cv2.imread(img1_path)
        image2 = cv2.imread(img2_path)

        # Resize images to a consistent size
        resized_image1 = resize_image(image1, target_size)
        resized_image2 = resize_image(image2, target_size)

        if resized_image1 is not None and resized_image2 is not None:
            gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)

            (_, similarity) = ssim(gray1, gray2, full=True)
            return similarity
        else:
            return 0.0
    except Exception as e:
        print(f"Error processing images: {e}")
        return 0.0

def group_similar_images(input_folder, output_folder, similarity_threshold=0.90):
    try:
        image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

        for i, img_file1 in enumerate(image_files):
            group_folder = os.path.join(output_folder, f"Group_{i + 1}")
            os.makedirs(group_folder, exist_ok=True)

            for img_file2 in image_files:
                if img_file1 != img_file2:
                    similarity = get_image_similarity(
                        os.path.join(input_folder, img_file1),
                        os.path.join(input_folder, img_file2)
                    )

                    if similarity > similarity_threshold:
                        shutil.move(os.path.join(input_folder, img_file2), group_folder)
    except Exception as e:
        print(f"Error grouping similar images: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/"

# Call the function with a specified similarity threshold (adjust as needed)
group_similar_images(input_folder_path, output_folder_path, similarity_threshold=0.90)
# Out:
# Error grouping similar images: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import cv2
import os
import shutil
import numpy as np
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    try:
        image1 = cv2.imread(img1_path)
        image2 = cv2.imread(img2_path)

        # Resize images to a consistent size
        resized_image1 = resize_image(image1, target_size)
        resized_image2 = resize_image(image2, target_size)

        if resized_image1 is not None and resized_image2 is not None:
            gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)

            (_, similarity) = ssim(gray1, gray2, full=True)
            return similarity
        else:
            return 0.0
    except Exception as e:
        print(f"Error processing images: {e}")
        return 0.0

def group_similar_images(input_folder, output_folder, similarity_threshold=0.90):
    try:
        image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

        for i, img_file1 in enumerate(image_files):
            group_folder = os.path.join(output_folder, f"Group_{i + 1}")
            os.makedirs(group_folder, exist_ok=True)

            for img_file2 in image_files:
                if img_file1 != img_file2:
                    similarity = get_image_similarity(
                        os.path.join(input_folder, img_file1),
                        os.path.join(input_folder, img_file2)
                    )

                    # Use np.any() to check if any element in the array is greater than the threshold
                    if np.any(similarity > similarity_threshold):
                        shutil.move(os.path.join(input_folder, img_file2), group_folder)
    except Exception as e:
        print(f"Error grouping similar images: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/Project UHC"

# Call the function with a specified similarity threshold (adjust as needed)
group_similar_images(input_folder_path, output_folder_path, similarity_threshold=0.90)

# %%
import cv2
import os
import shutil
import numpy as np
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    try:
        image1 = cv2.imread(img1_path)
        image2 = cv2.imread(img2_path)

        # Resize images to a consistent size
        resized_image1 = resize_image(image1, target_size)
        resized_image2 = resize_image(image2, target_size)

        if resized_image1 is not None and resized_image2 is not None:
            gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)

            (_, similarity) = ssim(gray1, gray2, full=True)
            return similarity
        else:
            return 0.0
    except Exception as e:
        print(f"Error processing images: {e}")
        return 0.0

def group_similar_images(input_folder, output_folder, similarity_threshold=0.90):
    try:
        image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

        for i, img_file1 in enumerate(image_files):
            group_folder = os.path.join(output_folder, f"Group_{i + 1}")
            os.makedirs(group_folder, exist_ok=True)

            for img_file2 in image_files:
                if img_file1 != img_file2:
                    similarity = get_image_similarity(
                        os.path.join(input_folder, img_file1),
                        os.path.join(input_folder, img_file2)
                    )

                    if np.any(similarity > similarity_threshold):
                        # Move images to the group folder
                        shutil.move(os.path.join(input_folder, img_file2), group_folder)

                        # Update the list of image files
                        image_files.remove(img_file2)
    except Exception as e:
        print(f"Error grouping similar images: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/Output Folder 1"

# Call the function with a specified similarity threshold (adjust as needed)
group_similar_images(input_folder_path, output_folder_path, similarity_threshold=0.90)

# %%
import cv2
import os
import shutil
import numpy as np
from skimage.metrics import structural_similarity as ssim

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def get_image_similarity(img1_path, img2_path, target_size=(300, 300)):
    try:
        image1 = cv2.imread(img1_path)
        image2 = cv2.imread(img2_path)

        # Resize images to a consistent size
        resized_image1 = resize_image(image1, target_size)
        resized_image2 = resize_image(image2, target_size)

        if resized_image1 is not None and resized_image2 is not None:
            gray1 = cv2.cvtColor(resized_image1, cv2.COLOR_BGR2GRAY)
            gray2 = cv2.cvtColor(resized_image2, cv2.COLOR_BGR2GRAY)

            (_, similarity) = ssim(gray1, gray2, full=True)
            return similarity
        else:
            return 0.0
    except Exception as e:
        print(f"Error processing images: {e}")
        return 0.0

def group_similar_images(input_folder, output_folder, similarity_threshold=0.90):
    try:
        image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

        for i, img_file1 in enumerate(image_files):
            group_folder = os.path.join(output_folder, f"Group_{i + 1}")
            os.makedirs(group_folder, exist_ok=True)

            images_to_move = []

            for img_file2 in image_files:
                if img_file1 != img_file2:
                    similarity = get_image_similarity(
                        os.path.join(input_folder, img_file1),
                        os.path.join(input_folder, img_file2)
                    )

                    if np.any(similarity > similarity_threshold):
                        images_to_move.append(img_file2)

            # Move images to the group folder
            for img_file_to_move in images_to_move:
                shutil.move(os.path.join(input_folder, img_file_to_move), group_folder)
    except Exception as e:
        print(f"Error grouping similar images: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images varied"
output_folder_path = "C:/Users/Shreshtha/Downloads/Output Folder 1"

# Call the function with a specified similarity threshold (adjust as needed)
group_similar_images(input_folder_path, output_folder_path, similarity_threshold=0.90)

# %%
import cv2
import os
import shutil
import numpy as np
from sklearn.cluster import KMeans

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def extract_features(image_path, target_size=(300, 300)):
    try:
        image = cv2.imread(image_path)
        resized_image = resize_image(image, target_size)

        if resized_image is not None:
            # Convert the image to grayscale
            gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

            # Flatten the 2D array into a 1D array
            flattened = gray.flatten()

            return flattened
        else:
            return None
    except Exception as e:
        print(f"Error extracting features: {e}")
        return None

def group_similar_images_kmeans(input_folder, output_folder, num_clusters=5):
    try:
        image_files = [f for f in os.listdir(input_folder) if f.endswith(('.jpg', '.png', '.jpeg'))]

        feature_vectors = []

        for img_file in image_files:
            features = extract_features(os.path.join(input_folder, img_file))
            if features is not None:
                feature_vectors.append(features)

        if feature_vectors:
            feature_vectors = np.array(feature_vectors)

            # Apply k-means clustering
            kmeans = KMeans(n_clusters=num_clusters, random_state=42)
            cluster_labels = kmeans.fit_predict(feature_vectors)

            # Create output folders for each cluster
            for i in range(num_clusters):
                cluster_folder = os.path.join(output_folder, f"Cluster_{i + 1}")
                os.makedirs(cluster_folder, exist_ok=True)

            # Move images to their respective cluster folders
            for img_file, label in zip(image_files, cluster_labels):
                cluster_folder = os.path.join(output_folder, f"Cluster_{label + 1}")
                shutil.move(os.path.join(input_folder, img_file), cluster_folder)

    except Exception as e:
        print(f"Error grouping similar images: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images to Group"
output_folder_path = "C:/Users/Shreshtha/Downloads/Output Folder 1"

# Call the function with a specified number of clusters
group_similar_images_kmeans(input_folder_path, output_folder_path, num_clusters=5)
# Out:
# C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import cv2
import os
import shutil
import pytesseract
from PIL import Image
import pandas as pd

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def extract_text_from_image(image_path, target_size=(300, 300)):
    try:
        image = cv2.imread(image_path)
        resized_image = resize_image(image, target_size)

        if resized_image is not None:
            # Convert the image to grayscale
            gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

            # Use pytesseract to perform OCR on the image
            text = pytesseract.image_to_string(gray, config='--psm 6')  # psm 6 for sparse text

            return text.strip()
        else:
            return None
    except Exception as e:
        print(f"Error extracting text: {e}")
        return None

def process_cluster_images(cluster_folder):
    texts = []

    # Process each image in the cluster folder
    for img_file in os.listdir(cluster_folder):
        image_path = os.path.join(cluster_folder, img_file)
        text = extract_text_from_image(image_path)
        
        if text is not None and text != '':
            texts.append(text)

    return texts

def extract_and_store_texts(input_folder, output_excel_path):
    try:
        clusters = [f for f in os.listdir(input_folder) if f.startswith('Cluster_')]

        data = {'Cluster': [], 'Text': []}

        for cluster_folder in clusters:
            cluster_path = os.path.join(input_folder, cluster_folder)
            texts = process_cluster_images(cluster_path)

            if texts:
                data['Cluster'].extend([cluster_folder] * len(texts))
                data['Text'].extend(texts)

        df = pd.DataFrame(data)
        df.to_excel(output_excel_path, index=False)
        print(f"Texts extracted and stored in {output_excel_path}")

    except Exception as e:
        print(f"Error extracting and storing texts: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images to Group"
output_excel_path = "C:/Users/Shreshtha/Downloads/ClusterTexts.xlsx"

# Call the function to extract texts and store them in an Excel file
extract_and_store_texts(input_folder_path, output_excel_path)
# Out:
# Texts extracted and stored in C:/Users/Shreshtha/Downloads/ClusterTexts.xlsx

# %%
import cv2
import os
import shutil
import pytesseract
from PIL import Image
import pandas as pd

def resize_image(image, target_size=(300, 300)):
    try:
        if image is not None and image.size != 0:
            return cv2.resize(image, target_size)
        else:
            return image
    except Exception as e:
        print(f"Error resizing image: {e}")
        return None

def extract_text_from_image(image_path, target_size=(300, 300)):
    try:
        image = cv2.imread(image_path)
        resized_image = resize_image(image, target_size)

        if resized_image is not None:
            # Convert the image to grayscale
            gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)

            # Use pytesseract to perform OCR on the image
            text = pytesseract.image_to_string(gray, config='--psm 6')  # psm 6 for sparse text

            return text.strip()
        else:
            return None
    except Exception as e:
        print(f"Error extracting text: {e}")
        return None

def process_cluster_images(cluster_folder):
    texts = []

    # Process each image in the cluster folder
    for img_file in os.listdir(cluster_folder):
        image_path = os.path.join(cluster_folder, img_file)
        text = extract_text_from_image(image_path)
        
        if text is not None and text != '':
            texts.append(text)

    return texts

def extract_and_store_texts(input_folder, output_excel_path):
    try:
        clusters = [f for f in os.listdir(input_folder) if f.startswith('Cluster_')]

        data = {'Cluster': [], 'Text': []}

        for cluster_folder in clusters:
            cluster_path = os.path.join(input_folder, cluster_folder)
            texts = process_cluster_images(cluster_path)

            if texts:
                data['Cluster'].extend([cluster_folder] * len(texts))
                data['Text'].extend(texts)

        df = pd.DataFrame(data)
        df.to_excel(output_excel_path, index=False)
        print(f"Texts extracted and stored in {output_excel_path}")

    except Exception as e:
        print(f"Error extracting and storing texts: {e}")

# Specify your input and output folder paths
input_folder_path = "C:/Users/Shreshtha/Downloads/Images to Group"
output_excel_path = "C:/Users/Shreshtha/Downloads/ClusterTexts1.xlsx"

# Call the function to extract texts and store them in an Excel file
extract_and_store_texts(input_folder_path, output_excel_path)
# Out:
# Texts extracted and stored in C:/Users/Shreshtha/Downloads/ClusterTexts1.xlsx

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.utils import get_column_letter
from PIL import Image
import pytesseract
import cv2
import os
import pandas as pd

# Path to the directory containing the groups of images
groups_directory = "C:/Users/Shreshtha/Downloads/Output Folder 1"

# Path to the existing Excel workbook
existing_excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Path to the new Excel workbook
new_excel_file_path = "C:/Users/Shreshtha/Downloads/Combined Trial infinite.xlsx"

# Load the existing Excel data
existing_workbook = load_workbook(existing_excel_file_path, read_only=True)
existing_excel_data_dict = {}

# Iterate through each sheet in the existing workbook
for sheet_name in existing_workbook.sheetnames:
    existing_excel_data_df = pd.read_excel(existing_excel_file_path, sheet_name=sheet_name, header=None)
    existing_excel_data_dict[sheet_name] = existing_excel_data_df

# Create a new Excel workbook
new_workbook = Workbook()

# Function to extract text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Function to process a group of images and extract text for each image
def process_image_group(group_folder):
    group_text_dict = {}

    for filename in os.listdir(group_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(group_folder, filename)

            # Extract text from the image
            text_data = extract_text_from_image(image_path)

            # Store the extracted text for each image
            group_text_dict[filename] = text_data

    return group_text_dict

# Iterate through each group folder in the groups directory
for group_folder_name in os.listdir(groups_directory):
    group_folder = os.path.join(groups_directory, group_folder_name)

    if os.path.isdir(group_folder):
        # Process each group of images
        group_text_dict = process_image_group(group_folder)

        if group_text_dict:
            # Create a new sheet for each group's text data
            group_sheet = new_workbook.create_sheet(title=f"Group_{group_folder_name}")

            # Write the extracted text to the sheet
            for filename, text_data in group_text_dict.items():
                group_sheet.append([filename, text_data])

# Include existing Excel data in the new workbook
for sheet_name, df in existing_excel_data_dict.items():
    sheet = new_workbook.create_sheet(title=f"Existing_{sheet_name}")

    # Write the existing Excel data to the sheet
    for row in dataframe_to_rows(df, index=False, header=False):
        sheet.append(row)

# Save the new workbook
new_workbook.save(new_excel_file_path)
print(f"Texts extracted and stored in {new_excel_file_path}")
# Out:
# Texts extracted and stored in C:/Users/Shreshtha/Downloads/Combined Trial infinite.xlsx

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
from openpyxl.utils import get_column_letter
from PIL import Image
import pytesseract
import cv2
import os
import pandas as pd

# Path to the directory containing the groups of images
groups_directory = "C:/Users/Shreshtha/Downloads/Output Folder 1"

# Path to the existing Excel workbook
existing_excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Path to the new Excel workbook
new_excel_file_path = "C:/Users/Shreshtha/Downloads/Combined Trial infinite1.xlsx"

# Load the existing Excel data
existing_workbook = load_workbook(existing_excel_file_path, read_only=True)
existing_excel_data_dict = {}

# Iterate through each sheet in the existing workbook
for sheet_name in existing_workbook.sheetnames:
    existing_excel_data_df = pd.read_excel(existing_excel_file_path, sheet_name=sheet_name, header=None)
    existing_excel_data_dict[sheet_name] = existing_excel_data_df

# Create a new Excel workbook
new_workbook = Workbook()

# Function to extract text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Function to process a group of images and extract text for each image
def process_image_group(group_folder):
    group_text_dict = {}

    for filename in os.listdir(group_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(group_folder, filename)

            # Extract text from the image
            text_data = extract_text_from_image(image_path)

            # Store the extracted text for each image
            group_text_dict[filename] = text_data

    return group_text_dict

# Iterate through each group folder in the groups directory
for group_folder_name in os.listdir(groups_directory):
    group_folder = os.path.join(groups_directory, group_folder_name)

    if os.path.isdir(group_folder):
        # Process each group of images
        group_text_dict = process_image_group(group_folder)

        if group_text_dict:
            # Create a new sheet for each group's text data
            group_sheet = new_workbook.create_sheet(title=f"Group_{group_folder_name}")

            # Write the extracted text to the sheet
            for filename, text_data in group_text_dict.items():
                # Split the text into lines
                lines = text_data.split('\n')

                # Write each line to a separate row in the sheet
                for line in lines:
                    group_sheet.append([filename, line])

                # Add a blank row to create a gap between text of different images
                group_sheet.append([])

# Include existing Excel data in the new workbook
for sheet_name, df in existing_excel_data_dict.items():
    sheet = new_workbook.create_sheet(title=f"Existing_{sheet_name}")

    # Write the existing Excel data to the sheet
    for row in dataframe_to_rows(df, index=False, header=False):
        sheet.append(row)

# Save the new workbook
new_workbook.save(new_excel_file_path)
print(f"Texts extracted and stored in {new_excel_file_path}")
# Out:
# Texts extracted and stored in C:/Users/Shreshtha/Downloads/Combined Trial infinite1.xlsx
