# %%
# !git clone https://github.com/huggingface/transformers.git
# !cd transformers
# !pip install -e .
# Out:
# Cloning into 'transformers'...
# Updating files:  32% (1326/4045)
# Updating files:  33% (1335/4045)
# Updating files:  34% (1376/4045)
# Updating files:  35% (1416/4045)
# Updating files:  36% (1457/4045)
# Updating files:  37% (1497/4045)
# Updating files:  38% (1538/4045)
# Updating files:  39% (1578/4045)
# Updating files:  40% (1618/4045)
# Updating files:  41% (1659/4045)
# Updating files:  42% (1699/4045)
# Updating files:  43% (1740/4045)
# Updating files:  44% (1780/4045)
# Updating files:  45% (1821/4045)
# Updating files:  46% (1861/4045)
# Updating files:  47% (1902/4045)
# Updating files:  48% (1942/4045)
# Updating files:  49% (1983/4045)
# Updating files:  50% (2023/4045)
# Updating files:  51% (2063/4045)
# Updating files:  52% (2104/4045)
# Updating files:  53% (2144/4045)
# Updating files:  54% (2185/4045)
# Updating files:  54% (2222/4045)
# Updating files:  55% (2225/4045)
# Updating files:  56% (2266/4045)
# Updating files:  57% (2306/4045)
# ...
