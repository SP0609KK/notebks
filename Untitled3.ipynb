# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/Shreshtha/Downloads/Melbourne_housing_FULL.csv")

# %%
df.head()
# Out:
#          Suburb           Address  Rooms Type Method        SellerG      Date  \
# 0    Abbotsford     68 Studley St      2    h     SS         Jellis  3/9/2016
# 1  Airport West     154 Halsey Rd      3    t     PI         Nelson  3/9/2016
# 2   Albert Park    105 Kerferd Rd      2    h      S  hockingstuart  3/9/2016
# 3   Albert Park  85 Richardson St      2    h      S        Thomson  3/9/2016
# 4    Alphington      30 Austin St      3    h     SN        McGrath  3/9/2016
#
#    Distance  Postcode  Bedroom  ...  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0      2.0  ...     126.0           inf        NaN
# 1      13.5    3042.0      3.0  ...     303.0           225     2016.0
# 2       3.3    3206.0      2.0  ...     120.0            82     1900.0
# 3       3.3    3206.0      2.0  ...     159.0           inf        NaN
# 4       6.4    3078.0      3.0  ...     174.0           122     2003.0
#
# ...

# %%
df.shape
# Out:
# (34857, 22)

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom           8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21097
# YearBuilt        19306
# CouncilArea          3
# Latitude          7976
# Longtitude        7976
# Regionname           0
# Propertycount        3
# ParkingArea          0
# Price             7610
# dtype: int64

# %%
df.dropna()
# Out:
#                  Suburb           Address  Rooms Type Method        SellerG  \
# 1          Airport West     154 Halsey Rd      3    t     PI         Nelson
# 2           Albert Park    105 Kerferd Rd      2    h      S  hockingstuart
# 5            Alphington        6 Smith St      4    h      S          Brace
# 6            Alphington   5/6 Yarralea St      3    h      S         Jellis
# 7                Altona      158 Queen St      3    h     VB           Greg
# ...                 ...               ...    ...  ...    ...            ...
# 34838  Caroline Springs  29 Edgbaston Pde      3    h     SP          Crane
# 34846       Keysborough       3 Cobain St      3    h      S           Area
# 34848         Maidstone    15 Ballarat Rd      2    h     SP         Biggin
# 34851        Noble Park        5 Blaby St      3    h     PI            C21
# 34856       Westmeadows      42 Pascoe St      4    h      S          Barry
#
# ...

# %%
plt.hist(data=df, x='Distance')
# Out:
# (array([ 5024., 11026., 10860.,  4254.,  1927.,   852.,   395.,   392.,
#            27.,    99.]),
#  array([ 0.  ,  4.81,  9.62, 14.43, 19.24, 24.05, 28.86, 33.67, 38.48,
#         43.29, 48.1 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(data=df['Distance'])
# Out:
# <Axes: xlabel='Distance', ylabel='Density'>

# %%
sns.violinplot(df, x = 'Distance')
# Out:
# <Axes: xlabel='Distance'>

# %%
sns.ecdfplot(data = df, x= 'Distance')
# Out:
# <Axes: xlabel='Distance', ylabel='Proportion'>

# %%
sns.pairplot(df)

# %%
sns.scatterplot(data=df, x='Distance', y='Price')
# Out:
# <Axes: xlabel='Distance', ylabel='Price'>

# %%
correlation = df['Price'].corr(df['Distance'])
print(correlation)
# Out:
# -0.21138434279158308

# %%
df.corr()
# Out:
#                   Rooms  Distance  Postcode   Bedroom  Bathroom       Car  \
# Rooms          1.000000  0.271511  0.085890  0.946755  0.611826  0.393878
# Distance       0.271511  1.000000  0.481566  0.269524  0.126201  0.241835
# Postcode       0.085890  0.481566  1.000000  0.089292  0.120080  0.067886
# Bedroom        0.946755  0.269524  0.089292  1.000000  0.614892  0.388491
# Bathroom       0.611826  0.126201  0.120080  0.614892  1.000000  0.307518
# Car            0.393878  0.241835  0.067886  0.388491  0.307518  1.000000
# Landsize       0.037402  0.060862  0.040664  0.037019  0.036333  0.037829
# YearBuilt     -0.012749  0.323059  0.089805 -0.002022  0.167955  0.128702
# Latitude       0.004872 -0.100417 -0.231027  0.003447 -0.059183 -0.009020
# Longtitude     0.103235  0.200946  0.362895  0.106164  0.106531  0.047213
# Propertycount -0.071677 -0.018140  0.017108 -0.053451 -0.032887 -0.009617
# Price          0.465238 -0.211384  0.044950  0.430275  0.429878  0.201803
#
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
dummies = pd.get_dummies(df, 'ParkingArea')
dummies
# Out:
#        Rooms  Distance  Postcode  Bedroom  Bathroom  Car  Landsize  YearBuilt  \
# 0          2       2.5    3067.0      2.0       1.0  1.0     126.0        NaN
# 1          3      13.5    3042.0      3.0       2.0  1.0     303.0     2016.0
# 2          2       3.3    3206.0      2.0       1.0  0.0     120.0     1900.0
# 3          2       3.3    3206.0      2.0       1.0  0.0     159.0        NaN
# 4          3       6.4    3078.0      3.0       2.0  1.0     174.0     2003.0
# ...      ...       ...       ...      ...       ...  ...       ...        ...
# 34852      3      12.0    3073.0      3.0       1.0  1.0       NaN     1990.0
# 34853      4      20.6    3064.0      4.0       2.0  2.0       NaN     1995.0
# 34854      4      22.2    3172.0      4.0       2.0  2.0     534.0     1970.0
# 34855      3      22.2    3172.0      3.0       2.0  1.0     544.0        NaN
# 34856      4      16.5    3049.0      4.0       2.0  6.0     813.0     1960.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale= StandardScaler
scale
# Out:
# sklearn.preprocessing._data.StandardScaler

# %%
scale = StandardScaler()
df['Bedroom_StdScale'] = scale.fit_transform(df[['Bedroom']])
df
# Out:
#                  Suburb           Address  Rooms Type Method        SellerG  \
# 0            Abbotsford     68 Studley St      2    h     SS         Jellis
# 1          Airport West     154 Halsey Rd      3    t     PI         Nelson
# 2           Albert Park    105 Kerferd Rd      2    h      S  hockingstuart
# 3           Albert Park  85 Richardson St      2    h      S        Thomson
# 4            Alphington      30 Austin St      3    h     SN        McGrath
# ...                 ...               ...    ...  ...    ...            ...
# 34852         Reservoir      18 Elinda Pl      3    u     SP             RW
# 34853     Roxburgh Park    14 Stainsby Cr      4    h      S          Raine
# 34854  Springvale South     8 Bellbird Ct      4    h     PI          Barry
# 34855  Springvale South  30 Waddington Cr      3    h      S      Harcourts
# 34856       Westmeadows      42 Pascoe St      4    h      S          Barry
#
# ...

# %%
df['Bedroom_StdScale'].head()
# Out:
# 0   -1.106025
# 1   -0.086316
# 2   -1.106025
# 3   -1.106025
# 4   -0.086316
# Name: Bedroom_StdScale, dtype: float64
