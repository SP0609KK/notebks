# %%
from transformers import FuyuProcessor, FuyuForCausalLM
from PIL import Image
import requests

# load model and processor
model_id = "adept/fuyu-8b"
processor = FuyuProcessor.from_pretrained(model_id)
model = FuyuForCausalLM.from_pretrained(model_id, device_map="cuda:0")

# prepare inputs for the model
text_prompt = "Generate a coco-style caption.\n"
url = "https://huggingface.co/adept/fuyu-8b/resolve/main/bus.png"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=text_prompt, images=image, return_tensors="pt").to("cuda:0")

# autoregressively generate text
generation_output = model.generate(**inputs, max_new_tokens=7)
generation_text = processor.batch_decode(generation_output[:, -7:], skip_special_tokens=True)
assert generation_text == ['A blue bus parked on the side of a road.']
# Out:
# WARNING:tensorflow:From C:\Users\Shreshtha\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1364, in _LazyModule._get_module(self, module_name)
#    1363 try:
# -> 1364     return importlib.import_module("." + module_name, self.__name__)
#    1365 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\generation\utils.py:93
#      92 if is_accelerate_available():
# ---> 93     from accelerate.hooks import AlignDevicesHook, add_hook_to_module
#      96 @dataclass
#      97 class GenerateDecoderOnlyOutput(ModelOutput):
#
# File ~\anaconda3\Lib\site-packages\accelerate\__init__.py:3
#       1 __version__ = "0.27.0"
# ----> 3 from .accelerator import Accelerator
#       4 from .big_modeling import (
#       5     cpu_offload,
#       6     cpu_offload_with_hook,
#    (...)
#      11     load_checkpoint_and_dispatch,
#      12 )
#
# File ~\anaconda3\Lib\site-packages\accelerate\accelerator.py:35
#      33 import torch.utils.hooks as hooks
# ---> 35 from .checkpointing import load_accelerator_state, load_custom_state, save_accelerator_state, save_custom_state
#      36 from .data_loader import DataLoaderDispatcher, prepare_data_loader, skip_first_batches
#
# File ~\anaconda3\Lib\site-packages\accelerate\checkpointing.py:24
#      22 from torch.cuda.amp import GradScaler
# ---> 24 from .utils import (
#      25     MODEL_NAME,
#      26     OPTIMIZER_NAME,
#      27     RNG_STATE_NAME,
#      28     SAFE_MODEL_NAME,
#      29     SAFE_WEIGHTS_NAME,
#      30     SAMPLER_NAME,
#      31     SCALER_NAME,
#      32     SCHEDULER_NAME,
#      33     WEIGHTS_NAME,
#      34     get_pretty_name,
#      35     is_tpu_available,
#      36     is_xpu_available,
#      37     save,
#      38 )
#      41 if is_tpu_available(check_device=False):
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\__init__.py:157
#     148     from .deepspeed import (
#     149         DeepSpeedEngineWrapper,
#     150         DeepSpeedOptimizerWrapper,
#    (...)
#     154         HfDeepSpeedConfig,
#     155     )
# --> 157 from .bnb import has_4bit_bnb_layers, load_and_quantize_model
#     158 from .fsdp_utils import load_fsdp_model, load_fsdp_optimizer, save_fsdp_model, save_fsdp_optimizer
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\bnb.py:29
#      24 from accelerate.utils.imports import (
#      25     is_4bit_bnb_available,
#      26     is_8bit_bnb_available,
#      27 )
# ---> 29 from ..big_modeling import dispatch_model, init_empty_weights
#      30 from .dataclasses import BnbQuantizationConfig
#
# File ~\anaconda3\Lib\site-packages\accelerate\big_modeling.py:24
#      22 import torch.nn as nn
# ---> 24 from .hooks import (
#      25     AlignDevicesHook,
#      26     CpuOffload,
#      27     UserCpuOffloadHook,
#      28     add_hook_to_module,
#      29     attach_align_device_hook,
#      30     attach_align_device_hook_on_blocks,
#      31 )
#      32 from .utils import (
#      33     OffloadedWeightsLoader,
#      34     check_device_map,
#    (...)
#      45     retie_parameters,
#      46 )
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:30
#      29 from .utils.modeling import get_non_persistent_buffers
# ---> 30 from .utils.other import recursive_getattr
#      33 class ModelHook:
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\other.py:29
#      27 from safetensors.torch import save_file as safe_save_file
# ---> 29 from ..commands.config.default import write_basic_config  # noqa: F401
#      30 from ..logging import get_logger
#
# File ~\anaconda3\Lib\site-packages\accelerate\commands\config\__init__.py:19
#      17 import argparse
# ---> 19 from .config import config_command_parser
#      20 from .config_args import default_config_file, load_config_from_file  # noqa: F401
#
# File ~\anaconda3\Lib\site-packages\accelerate\commands\config\config.py:25
#      24 from .config_utils import _ask_field, _ask_options, _convert_compute_environment  # noqa: F401
# ---> 25 from .sagemaker import get_sagemaker_input
#      28 description = "Launches a series of prompts to create and save a `default_config.yaml` configuration file for your training system. Should always be ran first on your machine"
#
# File ~\anaconda3\Lib\site-packages\accelerate\commands\config\sagemaker.py:35
#      34 if is_boto3_available():
# ---> 35     import boto3  # noqa: F401
#      38 def _create_iam_role_for_sagemaker(role_name):
#
# File ~\anaconda3\Lib\site-packages\boto3\__init__.py:17
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      19 __author__ = 'Amazon Web Services'
#
# File ~\anaconda3\Lib\site-packages\boto3\session.py:17
#      15 import os
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#
# File ~\anaconda3\Lib\site-packages\botocore\session.py:26
#      24 import warnings
# ---> 26 import botocore.client
#      27 import botocore.configloader
#
# File ~\anaconda3\Lib\site-packages\botocore\client.py:15
#      13 import logging
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#
# File ~\anaconda3\Lib\site-packages\botocore\waiter.py:18
#      16 import jmespath
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\__init__.py:15
#      13 import os
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      18 def generate_docs(root_dir, session):
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\service.py:14
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\client.py:14
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#      17     document_model_driven_method,
#      18     get_instance_public_methods,
#      19 )
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\example.py:13
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\shape.py:19
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      22 class ShapeDocumenter:
#
# File ~\anaconda3\Lib\site-packages\botocore\utils.py:37
#      36 import botocore.awsrequest
# ---> 37 import botocore.httpsession
#      39 # IP Regexes retained for backwards compatibility
#
# File ~\anaconda3\Lib\site-packages\botocore\httpsession.py:22
#      21 from urllib3.util.retry import Retry
# ---> 22 from urllib3.util.ssl_ import (
#      23     DEFAULT_CIPHERS,
#      24     OP_NO_COMPRESSION,
#      25     PROTOCOL_TLS,
#      26     OP_NO_SSLv2,
#      27     OP_NO_SSLv3,
#      28     is_ipaddress,
#      29     ssl,
#      30 )
#      31 from urllib3.util.url import parse_url
#
# ImportError: cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\urllib3\util\ssl_.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1364, in _LazyModule._get_module(self, module_name)
#    1363 try:
# -> 1364     return importlib.import_module("." + module_name, self.__name__)
#    1365 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\fuyu\modeling_fuyu.py:23
#      22 from ...modeling_outputs import CausalLMOutputWithPast
# ---> 23 from ...modeling_utils import PreTrainedModel
#      24 from ...models.auto.modeling_auto import AutoModelForCausalLM
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\modeling_utils.py:44
#      43 from .dynamic_module_utils import custom_object_save
# ---> 44 from .generation import GenerationConfig, GenerationMixin
#      45 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1354, in _LazyModule.__getattr__(self, name)
#    1353 elif name in self._class_to_module.keys():
# -> 1354     module = self._get_module(self._class_to_module[name])
#    1355     value = getattr(module, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1366, in _LazyModule._get_module(self, module_name)
#    1365 except Exception as e:
# -> 1366     raise RuntimeError(
#    1367         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1368         f" traceback):\n{e}"
#    1369     ) from e
#
# RuntimeError: Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\urllib3\util\ssl_.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import FuyuProcessor, FuyuForCausalLM
#       2 from PIL import Image
#       3 import requests
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1355, in _LazyModule.__getattr__(self, name)
#    1353 elif name in self._class_to_module.keys():
#    1354     module = self._get_module(self._class_to_module[name])
# -> 1355     value = getattr(module, name)
#    1356 else:
#    1357     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1354, in _LazyModule.__getattr__(self, name)
#    1352     value = self._get_module(name)
#    1353 elif name in self._class_to_module.keys():
# -> 1354     module = self._get_module(self._class_to_module[name])
#    1355     value = getattr(module, name)
#    1356 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1366, in _LazyModule._get_module(self, module_name)
#    1364     return importlib.import_module("." + module_name, self.__name__)
#    1365 except Exception as e:
# -> 1366     raise RuntimeError(
#    1367         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1368         f" traceback):\n{e}"
#    1369     ) from e
#
# RuntimeError: Failed to import transformers.models.fuyu.modeling_fuyu because of the following error (look up to see its traceback):
# Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\urllib3\util\ssl_.py)

# %%
######################################################################################################
# In this section, we set the user authentication, user and app ID, model details, and the URL of 
# the text we want as an input. Change these strings to run your own example.
######################################################################################################

# Your PAT (Personal Access Token) can be found in the portal under Authentification
PAT = 'f7f840d3e00041d2880a334d1d2e94ed'
# Specify the correct user_id/app_id pairings
# Since you're making inferences outside your app's scope
USER_ID = 'adept'
APP_ID = 'fuyu'
# Change these to whatever model and text URL you want to use
MODEL_ID = 'fuyu-8b'
MODEL_VERSION_ID = '97370fc878a24901a50b307462ca90da'
RAW_TEXT = 'I love your product very much'
# To use a hosted text file, assign the url variable
# TEXT_FILE_URL = 'https://samples.clarifai.com/negative_sentence_12.txt'
# Or, to use a local text file, assign the url variable
# TEXT_FILE_LOCATION = 'YOUR_TEXT_FILE_LOCATION_HERE'

############################################################################
# YOU DO NOT NEED TO CHANGE ANYTHING BELOW THIS LINE TO RUN THIS EXAMPLE
############################################################################

from clarifai_grpc.channel.clarifai_channel import ClarifaiChannel
from clarifai_grpc.grpc.api import resources_pb2, service_pb2, service_pb2_grpc
from clarifai_grpc.grpc.api.status import status_code_pb2

channel = ClarifaiChannel.get_grpc_channel()
stub = service_pb2_grpc.V2Stub(channel)

metadata = (('authorization', 'Key ' + PAT),)

userDataObject = resources_pb2.UserAppIDSet(user_id=USER_ID, app_id=APP_ID)

# To use a local text file, uncomment the following lines
# with open(TEXT_FILE_LOCATION, "rb") as f:
#    file_bytes = f.read()

post_model_outputs_response = stub.PostModelOutputs(
    service_pb2.PostModelOutputsRequest(
        user_app_id=userDataObject,  # The userDataObject is created in the overview and is required when using a PAT
        model_id=MODEL_ID,
        version_id=MODEL_VERSION_ID,  # This is optional. Defaults to the latest model version
        inputs=[
            resources_pb2.Input(
                data=resources_pb2.Data(
                    text=resources_pb2.Text(
                        raw=RAW_TEXT
                        # url=TEXT_FILE_URL
                        # raw=file_bytes
                    )
                )
            )
        ]
    ),
    metadata=metadata
)
if post_model_outputs_response.status.code != status_code_pb2.SUCCESS:
    print(post_model_outputs_response.status)
    raise Exception("Post model outputs failed, status: " + post_model_outputs_response.status.description)

# Since we have one input, one output will exist here
output = post_model_outputs_response.outputs[0]

print("Predicted concepts:")
for concept in output.data.concepts:
    print("%s %.2f" % (concept.name, concept.value))

# Uncomment this line to print the full Response JSON
#print(output)
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting clarifai_grpc
#   Downloading clarifai_grpc-10.1.3-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: grpcio>=1.44.0 in c:\users\shreshtha\anaconda3\lib\site-packages (from clarifai_grpc) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.3 in c:\users\shreshtha\anaconda3\lib\site-packages (from clarifai_grpc) (4.23.4)
# Requirement already satisfied: googleapis-common-protos>=1.53.0 in c:\users\shreshtha\anaconda3\lib\site-packages (from clarifai_grpc) (1.62.0)
# Requirement already satisfied: requests>=2.25.1 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from clarifai_grpc) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests>=2.25.1->clarifai_grpc) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests>=2.25.1->clarifai_grpc) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests>=2.25.1->clarifai_grpc) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests>=2.25.1->clarifai_grpc) (2023.11.17)
# Downloading clarifai_grpc-10.1.3-py3-none-any.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/225.2 kB ? eta -:--:--
#    -------------------- ------------------- 112.6/225.2 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 225.2/225.2 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: clarifai_grpc
# Successfully installed clarifai_grpc-10.1.3
# code: MODEL_DEPLOYING
# description: "Model is deploying"
# details: "Model is currently deploying or scaling up."
# req_id: "a5cc29c9fa155fb822e2902fe14959bf"
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 62
#      60 if post_model_outputs_response.status.code != status_code_pb2.SUCCESS:
#      61     print(post_model_outputs_response.status)
# ---> 62     raise Exception("Post model outputs failed, status: " + post_model_outputs_response.status.description)
#      64 # Since we have one input, one output will exist here
#      65 output = post_model_outputs_response.outputs[0]
#
# Exception: Post model outputs failed, status: Model is deploying

# %%
from transformers import FuyuProcessor, FuyuForCausalLM
from PIL import Image
import requests

# load model and processor
model_id = "adept/fuyu-8b"
processor = FuyuProcessor.from_pretrained(model_id)
model = FuyuForCausalLM.from_pretrained(model_id, device_map="cuda:0")

# prepare inputs for the model
text_prompt = "Generate a coco-style caption.\n"
url = "https://huggingface.co/adept/fuyu-8b/resolve/main/bus.png"
image = Image.open(requests.get(url, stream=True).raw)

inputs = processor(text=text_prompt, images=image, return_tensors="pt").to("cuda:0")

# autoregressively generate text
generation_output = model.generate(**inputs, max_new_tokens=7)
generation_text = processor.batch_decode(generation_output[:, -7:], skip_special_tokens=True)
assert generation_text == ['A blue bus parked on the side of a road.']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1364, in _LazyModule._get_module(self, module_name)
#    1363 try:
# -> 1364     return importlib.import_module("." + module_name, self.__name__)
#    1365 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\generation\utils.py:93
#      92 if is_accelerate_available():
# ---> 93     from accelerate.hooks import AlignDevicesHook, add_hook_to_module
#      96 @dataclass
#      97 class GenerateDecoderOnlyOutput(ModelOutput):
#
# File ~\anaconda3\Lib\site-packages\accelerate\__init__.py:3
#       1 __version__ = "0.27.0"
# ----> 3 from .accelerator import Accelerator
#       4 from .big_modeling import (
#       5     cpu_offload,
#       6     cpu_offload_with_hook,
#    (...)
#      11     load_checkpoint_and_dispatch,
#      12 )
#
# File ~\anaconda3\Lib\site-packages\accelerate\accelerator.py:35
#      33 import torch.utils.hooks as hooks
# ---> 35 from .checkpointing import load_accelerator_state, load_custom_state, save_accelerator_state, save_custom_state
#      36 from .data_loader import DataLoaderDispatcher, prepare_data_loader, skip_first_batches
#
# File ~\anaconda3\Lib\site-packages\accelerate\checkpointing.py:24
#      22 from torch.cuda.amp import GradScaler
# ---> 24 from .utils import (
#      25     MODEL_NAME,
#      26     OPTIMIZER_NAME,
#      27     RNG_STATE_NAME,
#      28     SAFE_MODEL_NAME,
#      29     SAFE_WEIGHTS_NAME,
#      30     SAMPLER_NAME,
#      31     SCALER_NAME,
#      32     SCHEDULER_NAME,
#      33     WEIGHTS_NAME,
#      34     get_pretty_name,
#      35     is_tpu_available,
#      36     is_xpu_available,
#      37     save,
#      38 )
#      41 if is_tpu_available(check_device=False):
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\__init__.py:157
#     148     from .deepspeed import (
#     149         DeepSpeedEngineWrapper,
#     150         DeepSpeedOptimizerWrapper,
#    (...)
#     154         HfDeepSpeedConfig,
#     155     )
# --> 157 from .bnb import has_4bit_bnb_layers, load_and_quantize_model
#     158 from .fsdp_utils import load_fsdp_model, load_fsdp_optimizer, save_fsdp_model, save_fsdp_optimizer
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\bnb.py:29
#      24 from accelerate.utils.imports import (
#      25     is_4bit_bnb_available,
#      26     is_8bit_bnb_available,
#      27 )
# ---> 29 from ..big_modeling import dispatch_model, init_empty_weights
#      30 from .dataclasses import BnbQuantizationConfig
#
# File ~\anaconda3\Lib\site-packages\accelerate\big_modeling.py:24
#      22 import torch.nn as nn
# ---> 24 from .hooks import (
#      25     AlignDevicesHook,
#      26     CpuOffload,
#      27     UserCpuOffloadHook,
#      28     add_hook_to_module,
#      29     attach_align_device_hook,
#      30     attach_align_device_hook_on_blocks,
#      31 )
#      32 from .utils import (
#      33     OffloadedWeightsLoader,
#      34     check_device_map,
#    (...)
#      45     retie_parameters,
#      46 )
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:30
#      29 from .utils.modeling import get_non_persistent_buffers
# ---> 30 from .utils.other import recursive_getattr
#      33 class ModelHook:
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\other.py:29
#      27 from safetensors.torch import save_file as safe_save_file
# ---> 29 from ..commands.config.default import write_basic_config  # noqa: F401
#      30 from ..logging import get_logger
#
# File ~\anaconda3\Lib\site-packages\accelerate\commands\config\__init__.py:19
#      17 import argparse
# ---> 19 from .config import config_command_parser
#      20 from .config_args import default_config_file, load_config_from_file  # noqa: F401
#
# File ~\anaconda3\Lib\site-packages\accelerate\commands\config\config.py:25
#      24 from .config_utils import _ask_field, _ask_options, _convert_compute_environment  # noqa: F401
# ---> 25 from .sagemaker import get_sagemaker_input
#      28 description = "Launches a series of prompts to create and save a `default_config.yaml` configuration file for your training system. Should always be ran first on your machine"
#
# File ~\anaconda3\Lib\site-packages\accelerate\commands\config\sagemaker.py:35
#      34 if is_boto3_available():
# ---> 35     import boto3  # noqa: F401
#      38 def _create_iam_role_for_sagemaker(role_name):
#
# File ~\anaconda3\Lib\site-packages\boto3\__init__.py:17
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      19 __author__ = 'Amazon Web Services'
#
# File ~\anaconda3\Lib\site-packages\boto3\session.py:17
#      15 import os
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#
# File ~\anaconda3\Lib\site-packages\botocore\session.py:26
#      24 import warnings
# ---> 26 import botocore.client
#      27 import botocore.configloader
#
# File ~\anaconda3\Lib\site-packages\botocore\client.py:15
#      13 import logging
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#
# File ~\anaconda3\Lib\site-packages\botocore\waiter.py:18
#      16 import jmespath
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\__init__.py:15
#      13 import os
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      18 def generate_docs(root_dir, session):
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\service.py:14
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\client.py:14
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#      17     document_model_driven_method,
#      18     get_instance_public_methods,
#      19 )
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\example.py:13
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#
# File ~\anaconda3\Lib\site-packages\botocore\docs\shape.py:19
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      22 class ShapeDocumenter:
#
# File ~\anaconda3\Lib\site-packages\botocore\utils.py:37
#      36 import botocore.awsrequest
# ---> 37 import botocore.httpsession
#      39 # IP Regexes retained for backwards compatibility
#
# File ~\anaconda3\Lib\site-packages\botocore\httpsession.py:22
#      21 from urllib3.util.retry import Retry
# ---> 22 from urllib3.util.ssl_ import (
#      23     DEFAULT_CIPHERS,
#      24     OP_NO_COMPRESSION,
#      25     PROTOCOL_TLS,
#      26     OP_NO_SSLv2,
#      27     OP_NO_SSLv3,
#      28     is_ipaddress,
#      29     ssl,
#      30 )
#      31 from urllib3.util.url import parse_url
#
# ImportError: cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\urllib3\util\ssl_.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1364, in _LazyModule._get_module(self, module_name)
#    1363 try:
# -> 1364     return importlib.import_module("." + module_name, self.__name__)
#    1365 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\models\fuyu\modeling_fuyu.py:23
#      22 from ...modeling_outputs import CausalLMOutputWithPast
# ---> 23 from ...modeling_utils import PreTrainedModel
#      24 from ...models.auto.modeling_auto import AutoModelForCausalLM
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\modeling_utils.py:44
#      43 from .dynamic_module_utils import custom_object_save
# ---> 44 from .generation import GenerationConfig, GenerationMixin
#      45 from .integrations import PeftAdapterMixin, deepspeed_config, is_deepspeed_zero3_enabled
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1354, in _LazyModule.__getattr__(self, name)
#    1353 elif name in self._class_to_module.keys():
# -> 1354     module = self._get_module(self._class_to_module[name])
#    1355     value = getattr(module, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1366, in _LazyModule._get_module(self, module_name)
#    1365 except Exception as e:
# -> 1366     raise RuntimeError(
#    1367         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1368         f" traceback):\n{e}"
#    1369     ) from e
#
# RuntimeError: Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\urllib3\util\ssl_.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from transformers import FuyuProcessor, FuyuForCausalLM
#       2 from PIL import Image
#       3 import requests
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1355, in _LazyModule.__getattr__(self, name)
#    1353 elif name in self._class_to_module.keys():
#    1354     module = self._get_module(self._class_to_module[name])
# -> 1355     value = getattr(module, name)
#    1356 else:
#    1357     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1354, in _LazyModule.__getattr__(self, name)
#    1352     value = self._get_module(name)
#    1353 elif name in self._class_to_module.keys():
# -> 1354     module = self._get_module(self._class_to_module[name])
#    1355     value = getattr(module, name)
#    1356 else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\transformers\utils\import_utils.py:1366, in _LazyModule._get_module(self, module_name)
#    1364     return importlib.import_module("." + module_name, self.__name__)
#    1365 except Exception as e:
# -> 1366     raise RuntimeError(
#    1367         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1368         f" traceback):\n{e}"
#    1369     ) from e
#
# RuntimeError: Failed to import transformers.models.fuyu.modeling_fuyu because of the following error (look up to see its traceback):
# Failed to import transformers.generation.utils because of the following error (look up to see its traceback):
# cannot import name 'DEFAULT_CIPHERS' from 'urllib3.util.ssl_' (C:\Users\Shreshtha\AppData\Roaming\Python\Python311\site-packages\urllib3\util\ssl_.py)

# %%
# !pip install --upgrade transformers[deps]
# Out:
# Requirement already satisfied: transformers[deps] in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (4.37.2)
# Requirement already satisfied: filelock in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (2023.12.25)
# Requirement already satisfied: requests in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (0.15.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from transformers[deps]) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[deps]) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[deps]) (4.9.0)
# Requirement already satisfied: colorama in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from tqdm>=4.27->transformers[deps]) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests->transformers[deps]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests->transformers[deps]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests->transformers[deps]) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (from requests->transformers[deps]) (2023.11.17)
# WARNING: transformers 4.37.2 does not provide the extra 'deps'
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade urllib3
# Out:
# Requirement already satisfied: urllib3 in c:\users\shreshtha\appdata\roaming\python\python311\site-packages (2.2.0)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
