# %%
import shutil
import pathlib

# %%
import shutil
import pathlib

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension
    temp_file = path.parent / 'temp.xlsx'
    temp_zip = temp_file.with_suffix('.zip')

    shutil.copyfile(path, temp_file)
    temp_file.rename(temp_zip)

    extract_dir = temp_file.parent / 'temp'
    extract_dir.mkdir(exist_ok=True)

    shutil.unpack_archive(temp_zip, extract_dir)

    media_dir = extract_dir / 'xl' / 'media'
    paths_img = sorted(media_dir.glob('*.png'))

    if not paths_img:
        raise ValueError('No images found in the Excel file')

    move_paths = {path: dir_extract / (name + f'-{str(n)}.png') for n, path in enumerate(paths_img)}

    new_paths = [shutil.move(old, new) for old, new in move_paths.items()]

    shutil.rmtree(extract_dir)
    temp_zip.unlink()

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)

# %%
import shutil
import pathlib
from openpyxl import load_workbook
from openpyxl.drawing.image import Image

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension
    temp_file = path.parent / 'temp.xlsx'
    temp_zip = temp_file.with_suffix('.zip')

    shutil.copyfile(path, temp_file)
    temp_file.rename(temp_zip)

    extract_dir = temp_file.parent / 'temp'
    extract_dir.mkdir(exist_ok=True)

    shutil.unpack_archive(temp_zip, extract_dir)

    workbook = load_workbook(temp_file)

    image_index = 0
    new_paths = []

    for sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
        for image in sheet.images:
            image_index += 1
            image_data = image.image
            image_filename = f'{name}-{str(image_index)}.png'
            image_path = dir_extract / image_filename
            with open(image_path, 'wb') as img_file:
                img_file.write(image_data)

            new_paths.append(image_path)

    shutil.rmtree(extract_dir)
    temp_zip.unlink()

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
# ----> 2 extracted_image_paths = extract_images_from_excel(excel_file_path)
#
# Cell In[7], line 37, in extract_images_from_excel(path, dir_extract)
#      33 extract_dir.mkdir(exist_ok=True)
#      35 shutil.unpack_archive(temp_zip, extract_dir)
# ---> 37 workbook = load_workbook(temp_file)
#      39 image_index = 0
#      40 new_paths = []
#
# File ~\AppData\Roaming\Python\Python311\site-packages\openpyxl\reader\excel.py:344, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     314 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     315                   data_only=False, keep_links=True, rich_text=False):
#     316     """Open the given filename and return the workbook
#     317
# ...

# %%
import shutil
import pathlib
from openpyxl import load_workbook
from openpyxl.drawing.image import Image

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension

    # Use a unique temporary file name in the same directory as the Excel file
    temp_file = path.with_name(f'temp_{path.stem}.xlsx')
    temp_zip = temp_file.with_suffix('.zip')

    shutil.copyfile(path, temp_file)
    temp_file.rename(temp_zip)

    extract_dir = temp_file.parent / 'temp'
    extract_dir.mkdir(exist_ok=True)

    shutil.unpack_archive(temp_zip, extract_dir)

    workbook = load_workbook(temp_file)

    image_index = 0
    new_paths = []

    for sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]
        for image in sheet.images:
            image_index += 1
            image_data = image.image
            image_filename = f'{name}-{str(image_index)}.png'
            image_path = dir_extract / image_filename
            with open(image_path, 'wb') as img_file:
                img_file.write(image_data)

            new_paths.append(image_path)

    shutil.rmtree(extract_dir)
    temp_zip.unlink()

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
# ----> 2 extracted_image_paths = extract_images_from_excel(excel_file_path)
#
# Cell In[9], line 39, in extract_images_from_excel(path, dir_extract)
#      35 extract_dir.mkdir(exist_ok=True)
#      37 shutil.unpack_archive(temp_zip, extract_dir)
# ---> 39 workbook = load_workbook(temp_file)
#      41 image_index = 0
#      42 new_paths = []
#
# File ~\AppData\Roaming\Python\Python311\site-packages\openpyxl\reader\excel.py:344, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     314 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     315                   data_only=False, keep_links=True, rich_text=False):
#     316     """Open the given filename and return the workbook
#     317
# ...

# %%
import shutil
import pathlib
from openpyxl import load_workbook
from openpyxl.drawing.image import Image

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension

    # Create a temporary directory
    extract_dir = path.parent / 'temp'
    extract_dir.mkdir(exist_ok=True)

    try:
        # Load the Excel file
        workbook = load_workbook(path)

        image_index = 0
        new_paths = []

        for sheet_name in workbook.sheetnames:
            sheet = workbook[sheet_name]
            for image in sheet.images:
                image_index += 1
                image_data = image.image
                image_filename = f'{name}-{str(image_index)}.png'
                image_path = dir_extract / image_filename
                with open(image_path, 'wb') as img_file:
                    img_file.write(image_data)

                new_paths.append(image_path)

    finally:
        # Cleanup: Remove the temporary directory
        shutil.rmtree(extract_dir)

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
# ----> 2 extracted_image_paths = extract_images_from_excel(excel_file_path)
#
# Cell In[11], line 40, in extract_images_from_excel(path, dir_extract)
#      38 for sheet_name in workbook.sheetnames:
#      39     sheet = workbook[sheet_name]
# ---> 40     for image in sheet.images:
#      41         image_index += 1
#      42         image_data = image.image
#
# AttributeError: 'Worksheet' object has no attribute 'images'

# %%
# !pip install python-pptx
# Out:
# ...
#    ---------------------------------------- 0.0/471.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/471.6 kB ? eta -:--:--
#    --- ----------------------------------- 41.0/471.6 kB 653.6 kB/s eta 0:00:01
#    --------- ------------------------------ 112.6/471.6 kB 1.1 MB/s eta 0:00:01
#    --------- ------------------------------ 112.6/471.6 kB 1.1 MB/s eta 0:00:01
#    --------------- ---------------------- 194.6/471.6 kB 908.0 kB/s eta 0:00:01
#    ---------------- --------------------- 204.8/471.6 kB 831.5 kB/s eta 0:00:01
#    ---------------- --------------------- 204.8/471.6 kB 831.5 kB/s eta 0:00:01
#    ------------------ ------------------- 225.3/471.6 kB 689.2 kB/s eta 0:00:01
#    --------------------- ---------------- 266.2/471.6 kB 682.7 kB/s eta 0:00:01
#    ------------------------- ------------ 317.4/471.6 kB 728.0 kB/s eta 0:00:01
#    -------------------------- ----------- 327.7/471.6 kB 655.9 kB/s eta 0:00:01
# ...

# %%
import shutil
import pathlib
from pptx import Presentation
from io import BytesIO

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension

    presentation = Presentation(path)
    image_index = 0
    new_paths = []

    for slide_index, slide in enumerate(presentation.slides):
        for shape_index, shape in enumerate(slide.shapes):
            if shape.shape_type == 13:  # Check if the shape is an image
                image_index += 1
                image = shape.image
                image_data = image.blob
                image_filename = f'{name}-slide{slide_index + 1}-shape{shape_index + 1}-{str(image_index)}.png'
                image_path = dir_extract / image_filename
                with open(image_path, 'wb') as img_file:
                    img_file.write(image_data)

                new_paths.append(image_path)

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
# ----> 2 extracted_image_paths = extract_images_from_excel(excel_file_path)
#
# Cell In[14], line 27, in extract_images_from_excel(path, dir_extract)
#      23     raise ValueError('Path must be an xlsx file')
#      25 name = path.stem  # Using .stem to get the filename without the extension
# ---> 27 presentation = Presentation(path)
#      28 image_index = 0
#      29 new_paths = []
#
# File ~\anaconda3\Lib\site-packages\pptx\api.py:32, in Presentation(pptx)
#      30 if not _is_pptx_package(presentation_part):
#      31     tmpl = "file '%s' is not a PowerPoint file, content type is '%s'"
# ---> 32     raise ValueError(tmpl % (pptx, presentation_part.content_type))
#      34 return presentation_part.presentation
#
# ...

# %%
import shutil
import pathlib
from openpyxl import load_workbook
from PIL import Image

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension

    workbook = load_workbook(path, data_only=True)

    image_index = 0
    new_paths = []

    for sheet_name in workbook.sheetnames:
        sheet = workbook[sheet_name]

        for image_ref in sheet._images:
            image_index += 1
            image_data = image_ref.image
            image = Image.open(BytesIO(image_data))
            image_filename = f'{name}-{sheet_name}-image{image_index}.png'
            image_path = dir_extract / image_filename
            image.save(image_path)

            new_paths.append(image_path)

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
# ----> 2 extracted_image_paths = extract_images_from_excel(excel_file_path)
#
# Cell In[16], line 37, in extract_images_from_excel(path, dir_extract)
#      35 for image_ref in sheet._images:
#      36     image_index += 1
# ---> 37     image_data = image_ref.image
#      38     image = Image.open(BytesIO(image_data))
#      39     image_filename = f'{name}-{sheet_name}-image{image_index}.png'
#
# AttributeError: 'Image' object has no attribute 'image'

# %%
import shutil
import pathlib
import zipfile
import os

def extract_images_from_excel(path, dir_extract=None):
    """Extracts images from an Excel file and names them with enumerated filenames.

    Args:
        path (pathlib.Path or str): Excel file path.
        dir_extract (pathlib.Path or None): Directory to extract images to. Defaults to the same directory as the Excel file.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if dir_extract is None:
        dir_extract = path.parent

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension

    temp_dir = path.parent / 'temp'
    temp_dir.mkdir(exist_ok=True)

    try:
        # Unzip the Excel file
        with zipfile.ZipFile(path, 'r') as zip_ref:
            zip_ref.extractall(temp_dir)

        media_dir = temp_dir / 'xl' / 'media'

        image_index = 0
        new_paths = []

        for root, dirs, files in os.walk(media_dir):
            for file in files:
                image_index += 1
                image_path = pathlib.Path(root) / file
                new_path = dir_extract / f'{name}-{str(image_index)}.png'
                shutil.copy(image_path, new_path)
                new_paths.append(new_path)

    finally:
        # Cleanup: Remove the temporary directory
        shutil.rmtree(temp_dir)

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)

# %%
import shutil
import pathlib
import zipfile
import os

def extract_images_from_excel(path, output_folder_name='extracted_images'):
    """Extracts images from an Excel file and stores them in a single folder.

    Args:
        path (pathlib.Path or str): Excel file path.
        output_folder_name (str): Name of the folder to store the extracted images. 
            Defaults to 'extracted_images'.

    Returns:
        new_paths (list[pathlib.Path]): List of paths to the extracted images.
    """
    if isinstance(path, str):
        path = pathlib.Path(path)

    if path.suffix != '.xlsx':
        raise ValueError('Path must be an xlsx file')

    name = path.stem  # Using .stem to get the filename without the extension

    # Create a new folder for the extracted images
    output_folder = path.parent / output_folder_name
    output_folder.mkdir(exist_ok=True)

    temp_dir = path.parent / 'temp'
    temp_dir.mkdir(exist_ok=True)

    try:
        # Unzip the Excel file
        with zipfile.ZipFile(path, 'r') as zip_ref:
            zip_ref.extractall(temp_dir)

        media_dir = temp_dir / 'xl' / 'media'

        image_index = 0
        new_paths = []

        for root, dirs, files in os.walk(media_dir):
            for file in files:
                image_index += 1
                image_path = pathlib.Path(root) / file
                new_path = output_folder / f'{name}-{str(image_index)}.png'
                shutil.copy(image_path, new_path)
                new_paths.append(new_path)

    finally:
        # Cleanup: Remove the temporary directory
        shutil.rmtree(temp_dir)

    return new_paths

# %%
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"
extracted_image_paths = extract_images_from_excel(excel_file_path)

# %%
import cv2
import pytesseract
from PIL import Image
import os

# Set the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Path to the directory containing the images
images_directory = "C:/Users/Shreshtha/Downloads/extracted_images"

# Function to extract regular text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Function to extract tabular data from an image using OpenCV
def extract_tabular_data(image_path):
    # Read the image using OpenCV
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Use a simple thresholding technique to convert to binary image
    _, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV)

    # Use pytesseract to extract text from the binary image
    text_data = pytesseract.image_to_string(Image.fromarray(binary))

    return text_data.strip()

# Dictionary to store text with filenames as keys
text_dict = {}

# Iterate through each image in the directory
for filename in os.listdir(images_directory):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(images_directory, filename)
        
        # Extract regular text
        text_data_regular = extract_text_from_image(image_path)
        
        # Extract tabular data
        text_data_tabular = extract_tabular_data(image_path)

        # Combine the extracted text
        combined_text = f"Regular Text:\n{text_data_regular}\n\nTabular Data:\n{text_data_tabular}"

        text_dict[filename] = combined_text

# Print or further process the organized text data
for filename, text_data in text_dict.items():
    print(f"Text extracted from {filename}:\n{text_data}\n")
# Out:
# Text extracted from Trial 1-1.png:
# Regular Text:
# Group Heme: Aurora Products
# Group Number (or TBD): 1264561
# Request Date: 7214/2020
# Effective Date of NSB: 31/2020
#
# Please Note: All tems isied on this form are subject to review, Please highlight the NSB's in yellow,
#
# Benefits Currently in Place Requested Benefits
#
# Current Plan 4: Current Plan 2:
# 0100001 BUY UP 0100002 CORE
#
# Base (Similar standard Plan) Tracking ID # (REQUIRED)
# + Reach out to your Underwriter
#
# + 4 14
# # of Employees Enrolled: 39 2 25 % 26 15
# Group State (NY, NJ, CT) cr cr cr. cr cr cr
# Market (Large or Small Group) Large Large Large Large Large Large
# Product (e.9: HHO, POS, Classic, Access, Direct, OxUSA, Value Option
# or EPO) HMO Huo HSA Huo HMO HSA
# Access (Gated or Non-Gated) Non-Gated Gated Non-Gated Non-Gated Gates Non-Gated
# Network (Freedom, Liberty, or Choice Pius) Freedom Freedom Freedom Freedom Freedom Freedom
# ...

# %%
import pandas as pd
from openpyxl import load_workbook

# Path to the Excel workbook
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Load the Excel workbook
workbook = load_workbook(excel_file_path, read_only=True, data_only=True)

# Dictionary to store data frames with sheet names as keys
data_frames_dict = {}

# Iterate through each sheet in the workbook
for sheet_name in workbook.sheetnames:
    # Read the sheet into a DataFrame
    sheet_df = pd.read_excel(excel_file_path, sheet_name=sheet_name, header=None)
    
    # Store the DataFrame in the dictionary
    data_frames_dict[sheet_name] = sheet_df

# Access and print or further process the organized data
for sheet_name, df in data_frames_dict.items():
    print(f"Data from {sheet_name}:\n{df}\n")
# Out:
# Data from Sheet1:
#                                                     0  \
# 0                                         Group Name:
# 1                            2 Group Number (or TBD):
# 2                                     3 Request Date:
# 3                               Effective Date of NSB
# 4   Please Note: All tersisted on this form are su...
# 5                                                 NaN
# 6                                                 NaN
# 7                             $ General exformatiqued
# 8                                      CSP (Optional)
# 9   Base (Similar standard Plan) Tracking ID# (REQ...
# 10                            # of Employees Enrolled
# 11                           Group State (NY, NJ, CT)
# 12                      Market (Large or Small Group)
# 13  Product (eg HMO, POS, Classic Access, Drect, O...
# 14                        Access (Gated or Non-Gated)
# 15          Network Freedom, Liberty, or Choice Plus)
# ...

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows

# Path to the directory containing the images
images_directory = "C:/Users/Shreshtha/Downloads/extracted_images"

# Path to the Excel workbook
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Create a new Excel workbook
new_workbook = Workbook()

# Dictionary to store text data with filenames as keys
text_data_dict = {}

# Function to extract regular text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Function to extract tabular data from an image using OpenCV
def extract_tabular_data(image_path):
    # Read the image using OpenCV
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Use a simple thresholding technique to convert to binary image
    _, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV)

    # Use pytesseract to extract text from the binary image
    text_data = pytesseract.image_to_string(Image.fromarray(binary))

    return text_data.strip()

# Function to extract data from an Excel sheet
def extract_data_from_excel(excel_file_path, sheet_name):
    workbook = load_workbook(excel_file_path, read_only=True, data_only=True)
    sheet_df = pd.read_excel(excel_file_path, sheet_name=sheet_name, header=None)
    return sheet_df

# Load the existing Excel data (replace this with your actual text extraction code)
excel_data_dict = {}

# Iterate through each sheet in the original workbook
for sheet_name in workbook.sheetnames:
    # Extract data from the Excel sheet
    excel_data_df = extract_data_from_excel(excel_file_path, sheet_name)

    # Create a new sheet in the workbook for each Excel sheet
    excel_sheet = new_workbook.create_sheet(title=f"Excel_{sheet_name}")

    # Write the data to the sheet
    for row in dataframe_to_rows(excel_data_df, index=False, header=True):
        excel_sheet.append(row)

    # Store the DataFrame in the dictionary
    excel_data_dict[sheet_name] = excel_data_df

# Access and print or further process the organized data
for sheet_name, df in excel_data_dict.items():
    print(f"Data from {sheet_name}:\n{df}\n")

# Iterate through each image in the directory
for filename in os.listdir(images_directory):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(images_directory, filename)

        # Extract regular text
        text_data_regular = extract_text_from_image(image_path)

        # Extract tabular data
        text_data_tabular = extract_tabular_data(image_path)

        # Combine the extracted text
        combined_text = f"Regular Text:\n{text_data_regular}\n\nTabular Data:\n{text_data_tabular}"

        text_data_dict[filename] = combined_text

# Create a new sheet for each image's text data
for filename, text_data in text_data_dict.items():
    text_sheet = new_workbook.create_sheet(title=f"Image_{filename}")
    text_sheet['A1'] = text_data

# Save the new workbook
new_workbook.save("C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx")
# Out:
# Data from Sheet1:
#                                                     0  \
# 0                                         Group Name:
# 1                            2 Group Number (or TBD):
# 2                                     3 Request Date:
# 3                               Effective Date of NSB
# 4   Please Note: All tersisted on this form are su...
# 5                                                 NaN
# 6                                                 NaN
# 7                             $ General exformatiqued
# 8                                      CSP (Optional)
# 9   Base (Similar standard Plan) Tracking ID# (REQ...
# 10                            # of Employees Enrolled
# 11                           Group State (NY, NJ, CT)
# 12                      Market (Large or Small Group)
# 13  Product (eg HMO, POS, Classic Access, Drect, O...
# 14                        Access (Gated or Non-Gated)
# 15          Network Freedom, Liberty, or Choice Plus)
# ...

# %%
import pandas as pd

# Load data from both sheets
df1 = pd.read_excel("C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx", sheet_name="Excel_Sheet1")
df2 = pd.read_excel("C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx", sheet_name="Image_Trial 1-2.png", header=None)

# Assuming "Group Name" is the common identifier
common_data = pd.merge(df1, df2)

# Define the column name mapping based on the structure of the common data
column_name_mapping = {
    'Group Name': 'Group Name',
    'Group Number_x': 'Group Number',
    'Request Date_x': 'Request Date',
    'Effective Date of NSB_x': 'Effective Date of NSB',
    'CSP (Optional)_x': 'CSP (Optional)',
    'Base Tracking ID#_x': 'Base Tracking ID#',
    '# of Employees Enrolled_x': '# of Employees Enrolled',
    'Group State_x': 'Group State',
    'Market_x': 'Market',
    'Product_x': 'Product',
    'Access_x': 'Access',
    'Network_x': 'Network',
    'Current Carrier_x': 'Current Carrier',
}

# Extract relevant columns based on the mapping
common_data = common_data[list(column_name_mapping.keys())]

# Rename columns based on the mapping
common_data.rename(columns=column_name_mapping, inplace=True)

# Print or further process the common data
print(common_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 28
#      11 column_name_mapping = {
#      12     'Group Name': 'Group Name',
#      13     'Group Number_x': 'Group Number',
#    (...)
#      24     'Current Carrier_x': 'Current Carrier',
#      25 }
#      27 # Extract relevant columns based on the mapping
# ---> 28 common_data = common_data[list(column_name_mapping.keys())]
#      30 # Rename columns based on the mapping
#      31 common_data.rename(columns=column_name_mapping, inplace=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
# ...

# %%
import pandas as pd
import re

# Load data from Sheet 1 (Image)
image_sheet_path = "C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx"
df1 = pd.read_excel(image_sheet_path, sheet_name="Image_Trial 1-5.png")

# Load data from Sheet 2 (Excel)
excel_file_path = "C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx"
df2 = pd.read_excel(excel_file_path, sheet_name="Excel_Sheet1", dtype=str)

# Define a function to extract information from the text
def extract_info(text):
    # Use regular expressions to extract relevant information
    group_name_match = re.search(r"Group Name:\s*(\d+)", str(text))
    date_match = re.search(r"Date:\s*(\S+)", str(text))
    # Add more regex patterns for other information as needed

    # Return a dictionary with extracted information
    return {
        "Group Name": group_name_match.group(1) if group_name_match else None,
        "Date": date_match.group(1) if date_match else None,
        # Add more fields as needed
    }

# Apply the extract_info function to each row in Sheet 1
df1["Extracted Info"] = df1["Image_Trial 1-5.png"].apply(extract_info)

# Expand the dictionary into separate columns
df1_extracted_info = pd.json_normalize(df1["Extracted Info"])

# Combine the extracted information from Sheet 1 with Sheet 2 using the index
merged_data = pd.concat([df2, df1_extracted_info], axis=1)

# Print or further process the merged data
print(merged_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Image_Trial 1-5.png'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 27
#      20     return {
# ...

# %%
import pandas as pd
import re

# Load data from Sheet 1 (Image)
image_sheet_path = "C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx"
df1 = pd.read_excel(image_sheet_path, sheet_name="Image_Trial 1-5.png")

# Load data from Sheet 2 (Excel)
excel_file_path = "C:/Users/Shreshtha/Downloads/Combined Trial 1.xlsx"
df2 = pd.read_excel(excel_file_path, sheet_name="Excel_Sheet1", dtype=str)

# Define a function to extract information from the text
def extract_info(text):
    # Use regular expressions to extract relevant information
    group_name_match = re.search(r"Group Name:\s*(\d+)", str(text))
    date_match = re.search(r"Date:\s*(\S+)", str(text))
    # Add more regex patterns for other information as needed

    # Return a dictionary with extracted information
    return {
        "Group Name": group_name_match.group(1) if group_name_match else None,
        "Date": date_match.group(1) if date_match else None,
        # Add more fields as needed
    }

# Apply the extract_info function to each row in Sheet 1
df1["Extracted Info"] = df1.apply(lambda row: extract_info(row), axis=1)

# Expand the dictionary into separate columns
df1_extracted_info = pd.json_normalize(df1["Extracted Info"])

# Combine the extracted information from Sheet 1 with Sheet 2 using the index
merged_data = pd.concat([df2, df1_extracted_info], axis=1)

# Print or further process the merged data
merged_data
# Out:
#                                                     0  \
# 0                                         Group Name:
# 1                            2 Group Number (or TBD):
# 2                                     3 Request Date:
# 3                               Effective Date of NSB
# 4   Please Note: All tersisted on this form are su...
# 5                                                 NaN
# 6                                                 NaN
# 7                             $ General exformatiqued
# 8                                      CSP (Optional)
# 9   Base (Similar standard Plan) Tracking ID# (REQ...
# 10                            # of Employees Enrolled
# 11                           Group State (NY, NJ, CT)
# 12                      Market (Large or Small Group)
# 13  Product (eg HMO, POS, Classic Access, Drect, O...
# 14                        Access (Gated or Non-Gated)
# 15          Network Freedom, Liberty, or Choice Plus)
# ...

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
import os
import pandas as pd

# Path to the directory containing the images
images_directory = "C:/Users/Shreshtha/Downloads/extracted_images"

# Path to the Excel workbook
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Create a new Excel workbook
new_workbook = Workbook()

# Load the existing Excel data (replace this with your actual Excel data)
excel_data_dict = {}

# Iterate through each sheet in the original workbook
for sheet_name in load_workbook(excel_file_path, read_only=True).sheetnames:
    # Assuming you have already extracted data from Excel sheets
    # If not, you can include your extraction logic here

    # Create a new sheet in the workbook for each Excel sheet
    excel_sheet = new_workbook.create_sheet(title=f"Excel_{sheet_name}")

    # Assuming you have the DataFrame 'excel_data_df' extracted earlier
    # Write the data to the sheet
    for row in dataframe_to_rows(excel_data_df, index=False, header=True):
        excel_sheet.append(row)

    # Store the DataFrame in the dictionary (optional)
    excel_data_dict[sheet_name] = excel_data_df

# Access and print or further process the organized data (optional)
for sheet_name, df in excel_data_dict.items():
    print(f"Data from {sheet_name}:\n{df}\n")

# Create a new sheet for each image's text data
for filename in os.listdir(images_directory):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_sheet = new_workbook.create_sheet(title=f"Image_{filename}")
        # Assuming you have already extracted text_data from images
        text_data = "Replace this with your actual text_data"
        image_sheet['A1'] = text_data

# Save the new workbook
new_workbook.save("C:/Users/Shreshtha/Downloads/Combined Trial 11.xlsx")
# Out:
# Data from Sheet1:
# Empty DataFrame
# Columns: []
# Index: []
#
# Data from Sheet2:
# Empty DataFrame
# Columns: []
# Index: []
#
# Data from Sheet6:
# Empty DataFrame
# Columns: []
# Index: []
#
# Data from Sheet3:
# Empty DataFrame
# Columns: []
# Index: []
#
# Data from Sheet4:
# Empty DataFrame
# Columns: []
# Index: []
#
# Data from Sheet5:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import cv2
import pytesseract
from PIL import Image
import os

# Set the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Path to the directory containing the images
images_directory = "C:/Users/Shreshtha/Downloads/Project UHC/extracted_images"

# Function to extract regular text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Dictionary to store text with filenames as keys
text_dict = {}

# Iterate through each image in the directory
for filename in os.listdir(images_directory):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(images_directory, filename)
        
        # Extract regular text (both regular and tabular data)
        text_data = extract_text_from_image(image_path)

        text_dict[filename] = text_data

# Print or further process the organized text data
for filename, text_data in text_dict.items():
    print(f"Text extracted from {filename}:\n{text_data}\n")
# Out:
# Text extracted from Trial 2-1.png:
# Group Heme: Aurora Products
# Group Number (or TBD): 1264561
# Request Date: 7214/2020
# Effective Date of NSB: 31/2020
#
# Please Note: All tems isied on this form are subject to review, Please highlight the NSB's in yellow,
#
# Benefits Currently in Place Requested Benefits
#
# Current Plan 4: Current Plan 2:
# 0100001 BUY UP 0100002 CORE
#
# Base (Similar standard Plan) Tracking ID # (REQUIRED)
# + Reach out to your Underwriter
#
# + 4 14
# # of Employees Enrolled: 39 2 25 % 26 15
# Group State (NY, NJ, CT) cr cr cr. cr cr cr
# Market (Large or Small Group) Large Large Large Large Large Large
# Product (e.9: HHO, POS, Classic, Access, Direct, OxUSA, Value Option
# or EPO) HMO Huo HSA Huo HMO HSA
# Access (Gated or Non-Gated) Non-Gated Gated Non-Gated Non-Gated Gates Non-Gated
# Network (Freedom, Liberty, or Choice Pius) Freedom Freedom Freedom Freedom Freedom Freedom
# Current Carrier (Oxford or Competitor) Polaris Polaris Polaris Polaris
#
# ...

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
import os
import pandas as pd
from PIL import Image
import pytesseract

# Path to the directory containing the images
images_directory = "C:/Users/Shreshtha/Downloads/extracted_images"

# Path to the Excel workbook
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Create a new Excel workbook
new_workbook = Workbook()

# Dictionary to store text data with filenames as keys
text_data_dict = {}

# Function to extract regular text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Function to extract data from an Excel sheet
def extract_data_from_excel(excel_file_path, sheet_name):
    workbook = load_workbook(excel_file_path, read_only=True, data_only=True)
    sheet_df = pd.read_excel(excel_file_path, sheet_name=sheet_name, header=None)
    return sheet_df

# Load the existing Excel data
excel_data_dict = {}

# Iterate through each sheet in the original workbook
for sheet_name in load_workbook(excel_file_path, read_only=True).sheetnames:
    # Extract data from the Excel sheet
    excel_data_df = extract_data_from_excel(excel_file_path, sheet_name)

    # Print the Excel data
    print(f"Data from {sheet_name}:\n{excel_data_df}\n")

    # Create a new sheet in the workbook for each Excel sheet
    excel_sheet = new_workbook.create_sheet(title=f"Excel_{sheet_name}")

    # Write the data to the sheet
    for row in dataframe_to_rows(excel_data_df, index=False, header=True):
        excel_sheet.append(row)

    # Store the DataFrame in the dictionary
    excel_data_dict[sheet_name] = excel_data_df

# Iterate through each image in the directory
for filename in os.listdir(images_directory):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(images_directory, filename)

        # Extract regular text
        text_data_regular = extract_text_from_image(image_path)

        # Print the image data
        print(f"Data from Image {filename}:\n{text_data_regular}\n")

        text_data_dict[filename] = text_data_regular

# Create a new sheet for each image's text data
for filename, text_data in text_data_dict.items():
    text_sheet = new_workbook.create_sheet(title=f"Image_{filename}")
    text_sheet['A1'] = text_data

# Save the new workbook
new_workbook.save("C:/Users/Shreshtha/Downloads/Combined Trial 221.xlsx")
# Out:
# Data from Sheet1:
#                                                     0  \
# 0                                         Group Name:
# 1                            2 Group Number (or TBD):
# 2                                     3 Request Date:
# 3                               Effective Date of NSB
# 4   Please Note: All tersisted on this form are su...
# 5                                                 NaN
# 6                                                 NaN
# 7                             $ General exformatiqued
# 8                                      CSP (Optional)
# 9   Base (Similar standard Plan) Tracking ID# (REQ...
# 10                            # of Employees Enrolled
# 11                           Group State (NY, NJ, CT)
# 12                      Market (Large or Small Group)
# 13  Product (eg HMO, POS, Classic Access, Drect, O...
# 14                        Access (Gated or Non-Gated)
# 15          Network Freedom, Liberty, or Choice Plus)
# ...

# %%
from openpyxl import Workbook, load_workbook
from openpyxl.utils.dataframe import dataframe_to_rows
import os
import pandas as pd
import cv2
from PIL import Image
import pytesseract

# Path to the directory containing the images
images_directory = "C:/Users/Shreshtha/Downloads/extracted_images"

# Path to the Excel workbook
excel_file_path = "C:/Users/Shreshtha/Downloads/Trial 1.xlsx"

# Create a new Excel workbook
new_workbook = Workbook()

# Dictionary to store text data with filenames as keys
text_data_dict = {}

# Function to extract regular text from an image using OCR
def extract_text_from_image(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path))
        return text.strip()
    except Exception as e:
        print(f"Error extracting text from image {image_path}: {e}")
        return None

# Function to extract tabular data from an image using OpenCV
def extract_tabular_data(image_path):
    # Read the image using OpenCV
    img = cv2.imread(image_path)

    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Use a simple thresholding technique to convert to binary image
    _, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY_INV)

    # Use pytesseract to extract text from the binary image
    text_data = pytesseract.image_to_string(Image.fromarray(binary))

    return text_data.strip()

# Function to extract data from an Excel sheet
def extract_data_from_excel(excel_file_path, sheet_name):
    workbook = load_workbook(excel_file_path, read_only=True, data_only=True)
    sheet_df = pd.read_excel(excel_file_path, sheet_name=sheet_name, header=None)
    return sheet_df

# Load the existing Excel data
excel_data_dict = {}

# Iterate through each sheet in the original workbook
for sheet_name in load_workbook(excel_file_path, read_only=True).sheetnames:
    # Extract data from the Excel sheet
    excel_data_df = extract_data_from_excel(excel_file_path, sheet_name)

    # Print the Excel data
    print(f"Data from {sheet_name}:\n{excel_data_df}\n")

    # Create a new sheet in the workbook for each Excel sheet
    excel_sheet = new_workbook.create_sheet(title=f"Excel_{sheet_name}")

    # Write the data to the sheet
    for row in dataframe_to_rows(excel_data_df, index=False, header=True):
        excel_sheet.append(row)

    # Store the DataFrame in the dictionary
    excel_data_dict[sheet_name] = excel_data_df

# Iterate through each image in the directory
for filename in os.listdir(images_directory):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(images_directory, filename)

        # Extract regular text
        text_data_regular = extract_text_from_image(image_path)

        # Extract tabular data
        text_data_tabular = extract_tabular_data(image_path)

        # Combine the extracted text
        combined_text = f"Regular Text:\n{text_data_regular}\n\nTabular Data:\n{text_data_tabular}"

        # Split the combined text into lines
        lines = combined_text.split('\n')

        # Print the image data
        print(f"Data from Image {filename}:\n{combined_text}\n")

        # Create a new sheet for each image's text data
        text_sheet = new_workbook.create_sheet(title=f"Image_{filename}")

        # Write each line to a new row in the sheet
        for line in lines:
            text_sheet.append([line])

        text_data_dict[filename] = combined_text

# Save the new workbook
new_workbook.save("C:/Users/Shreshtha/Downloads/Combined Trial 121.xlsx")
# Out:
# Data from Sheet1:
#                                                     0  \
# 0                                         Group Name:
# 1                            2 Group Number (or TBD):
# 2                                     3 Request Date:
# 3                               Effective Date of NSB
# 4   Please Note: All tersisted on this form are su...
# 5                                                 NaN
# 6                                                 NaN
# 7                             $ General exformatiqued
# 8                                      CSP (Optional)
# 9   Base (Similar standard Plan) Tracking ID# (REQ...
# 10                            # of Employees Enrolled
# 11                           Group State (NY, NJ, CT)
# 12                      Market (Large or Small Group)
# 13  Product (eg HMO, POS, Classic Access, Drect, O...
# 14                        Access (Gated or Non-Gated)
# 15          Network Freedom, Liberty, or Choice Plus)
# ...
